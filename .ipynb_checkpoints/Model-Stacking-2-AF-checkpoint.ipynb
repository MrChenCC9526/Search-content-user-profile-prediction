# %%
import pandas as pd
import sys
import os
import pickle
import numpy as np
import h5py
import config # 自定义配置文件
import time
from datetime import datetime

# 不显示VisibleDeprecation警告
import warnings
warnings.filterwarnings("ignore", category=Warning)

# %%
# 导入自定义模块
sys.path.append(config.Py_path) # 添加路径
from SaveAndLoad import save_pkl,load_pkl # 数据文件持久化与加载
from BuildModel import get_train_test,BF_nn_Model,BF_XGB_Model
from ModelEvaluation import nnModel_ACC,Model_ACC

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.python.keras.utils import np_utils
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
import xgboost as xgb

# %%
data = pd.read_csv(config.AF_Data_path + "AFAfter.csv")
col_list = ["Education","age","gender"]

# %%
# 加载TFIDF词向量数据
TFIDF_HW_sp_toarray = load_pkl("TFIDF_HW_sp_toarray")

# %%
with h5py.File(config.WV_Data_path + "TFIDF_sp_toarray.hdf5", 'r') as f:  # 读取的时候是‘r’
    print(f.keys())
    TFIDF_sp_toarray = f.get("TFIDF_sp_toarray")[:]
# Out:
# KeysView(<HDF5 file "TFIDF_sp_toarray.hdf5" (mode r)>)

# %%
# 加载W2V词向量数据
W2V_X_sp = load_pkl("W2V_X_sp")
W2V_HW_sp = load_pkl("W2V_HW_sp")

# %%
# 加载D2V词向量数据
D2V_X_sp = load_pkl("D2V_X_sp")

# %%
X_col = ['SpaceNum', 'SpaceRATIO','LinkNum', 'LinkRATIO', 'TextSum', 'TextMax', 'TextMin', 'TextMedian','TextMean', 'SearchNum',]

# %%
pred_dict = {}
for y_col in col_list:
    # 构建特征与目标
    X = np.array(data[X_col])
    Y = data[y_col]
    num_class = len(Y.value_counts())
    if len(Y.unique()) > 2:
        Y[Y==6] = 0
    else:
        Y[Y==2] = 0
        
    y = np.array([Y]).T
    
    # 交叉检验
    KF = KFold(
    n_splits=3, # 折叠次数；拆分数量
    shuffle=True, # 是否在拆分成批之前对数据进行混洗
 )
    for k,(tr,te) in enumerate(KF.split(X,y)):
        # 构建训练集与测试集
        X_train = X.take(tr,axis = 0) # numpy按行取值
        X_test = X.take(te,axis = 0)
        y_train = Y.take(tr,axis = 0)
        y_test = Y.take(te,axis = 0)
        
        XG = BF_XGB_Model(X_train, X_test, y_train, y_test)
        print('{} {} stack:{}  XG'.format(datetime.now(),y_col,k+1),end="\t")
        Model_ACC(XG,X_train,X_test,y_train,y_test)
    XG_pred = XG.predict_proba(X)
    pred_dict[y_col] = XG_pred
# Out:
# 2023-03-07 15:40:06.653841 Education stack:1  XG	训练集准确度: 0.586471, 测试集准确度: 0.406866
# 2023-03-07 15:40:08.844978 Education stack:2  XG	训练集准确度: 0.593779, 测试集准确度: 0.396499
# 2023-03-07 15:40:10.993231 Education stack:3  XG	训练集准确度: 0.586676, 测试集准确度: 0.413225
# 2023-03-07 15:40:13.192347 age stack:1  XG	训练集准确度: 0.570239, 测试集准确度: 0.392080
# 2023-03-07 15:40:15.362540 age stack:2  XG	训练集准确度: 0.568369, 测试集准确度: 0.387661
# 2023-03-07 15:40:17.508798 age stack:3  XG	训练集准确度: 0.563307, 测试集准确度: 0.373279
# 2023-03-07 15:40:18.424348 gender stack:1  XG	训练集准确度: 0.731282, 测试集准确度: 0.565262
# 2023-03-07 15:40:19.310976 gender stack:2  XG	训练集准确度: 0.729498, 测试集准确度: 0.559313
# 2023-03-07 15:40:20.186633 gender stack:3  XG	训练集准确度: 0.723148, 测试集准确度: 0.562128

# %%
pred = np.hstack([pred_dict["Education"],pred_dict["age"],pred_dict["gender"]])

# %%
# 划分数据集
X_tr, X_te, Y_tr, Y_te = get_train_test(pred,data["Education"])

# %%
NN_Model = BF_nn_Model(X_tr, X_te, Y_tr, Y_te)
# Out:
# Train on 12355 samples, validate on 5296 samples
# Epoch 1/15
# 12355/12355 [==============================] - 1s 101us/step - loss: 1.2080 - acc: 0.4769 - val_loss: 1.1321 - val_acc: 0.5111
# Epoch 2/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 1.1142 - acc: 0.5201 - val_loss: 1.1087 - val_acc: 0.5183
# Epoch 3/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 1.0955 - acc: 0.5289 - val_loss: 1.1096 - val_acc: 0.5191
# Epoch 4/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 1.0875 - acc: 0.5357 - val_loss: 1.0978 - val_acc: 0.5274
# Epoch 5/15
# 12355/12355 [==============================] - 0s 20us/step - loss: 1.0818 - acc: 0.5352 - val_loss: 1.1105 - val_acc: 0.5147
# Epoch 6/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 1.0773 - acc: 0.5372 - val_loss: 1.0990 - val_acc: 0.5213
# Epoch 7/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 1.0756 - acc: 0.5356 - val_loss: 1.0877 - val_acc: 0.5240
# Epoch 8/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 1.0721 - acc: 0.5435 - val_loss: 1.0924 - val_acc: 0.5219
# Epoch 9/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 1.0715 - acc: 0.5423 - val_loss: 1.1004 - val_acc: 0.5172
# Epoch 10/15
# 12355/12355 [==============================] - 0s 20us/step - loss: 1.0698 - acc: 0.5412 - val_loss: 1.0805 - val_acc: 0.5317
# Epoch 11/15
# 12355/12355 [==============================] - 0s 21us/step - loss: 1.0688 - acc: 0.5416 - val_loss: 1.0826 - val_acc: 0.5325
# Epoch 12/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 1.0706 - acc: 0.5384 - val_loss: 1.1027 - val_acc: 0.5144
# Epoch 13/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 1.0702 - acc: 0.5375 - val_loss: 1.0843 - val_acc: 0.5315
# Epoch 14/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 1.0678 - acc: 0.5393 - val_loss: 1.0773 - val_acc: 0.5347
# Epoch 15/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 1.0660 - acc: 0.5438 - val_loss: 1.0767 - val_acc: 0.5336

# %%
NN_pred = NN_Model.predict_proba(pred) # 测试集预测

# %%
nn_pred_dict = {}
for y_col in col_list:
    print('{} {} stack: NN'.format(datetime.now(),y_col),end="\t")
    # 划分数据集
    X_tr, X_te, Y_tr, Y_te = get_train_test(pred,data[y_col])
    NN_Model = BF_nn_Model(X_tr, X_te, Y_tr, Y_te)
    NN_pred = NN_Model.predict_proba(pred) # 测试集预测
    nn_pred_dict[y_col] = NN_pred # 保存结果
# Out:
# 2023-03-08 10:16:08.516506 Education stack: NN	Train on 12355 samples, validate on 5296 samples
# Epoch 1/15
# 12355/12355 [==============================] - 1s 96us/step - loss: 1.2037 - acc: 0.4812 - val_loss: 1.1299 - val_acc: 0.5149
# Epoch 2/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 1.1109 - acc: 0.5289 - val_loss: 1.1094 - val_acc: 0.5227
# Epoch 3/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 1.0940 - acc: 0.5306 - val_loss: 1.0978 - val_acc: 0.5227
# Epoch 4/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 1.0866 - acc: 0.5317 - val_loss: 1.0886 - val_acc: 0.5315
# Epoch 5/15
# 12355/12355 [==============================] - 0s 20us/step - loss: 1.0809 - acc: 0.5350 - val_loss: 1.0952 - val_acc: 0.5223
# Epoch 6/15
# 12355/12355 [==============================] - 0s 20us/step - loss: 1.0742 - acc: 0.5395 - val_loss: 1.0879 - val_acc: 0.5302
# Epoch 7/15
# 12355/12355 [==============================] - 0s 20us/step - loss: 1.0745 - acc: 0.5396 - val_loss: 1.0827 - val_acc: 0.5312
# Epoch 8/15
# 12355/12355 [==============================] - 0s 20us/step - loss: 1.0733 - acc: 0.5370 - val_loss: 1.0843 - val_acc: 0.5319
# Epoch 9/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 1.0714 - acc: 0.5414 - val_loss: 1.0817 - val_acc: 0.5302
# Epoch 10/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 1.0731 - acc: 0.5381 - val_loss: 1.0863 - val_acc: 0.5291
# Epoch 11/15
# 12355/12355 [==============================] - 0s 20us/step - loss: 1.0676 - acc: 0.5408 - val_loss: 1.0784 - val_acc: 0.5306
# Epoch 12/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 1.0690 - acc: 0.5412 - val_loss: 1.0833 - val_acc: 0.5306
# Epoch 13/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 1.0697 - acc: 0.5386 - val_loss: 1.0831 - val_acc: 0.5293
# Epoch 14/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 1.0668 - acc: 0.5430 - val_loss: 1.0838 - val_acc: 0.5289
# Epoch 15/15
# 12355/12355 [==============================] - 0s 20us/step - loss: 1.0700 - acc: 0.5381 - val_loss: 1.0776 - val_acc: 0.5338
# 2023-03-08 10:16:13.836679 age stack: NN	Train on 12355 samples, validate on 5296 samples
# Epoch 1/15
# 12355/12355 [==============================] - 1s 77us/step - loss: 1.3209 - acc: 0.4456 - val_loss: 1.2344 - val_acc: 0.4692
# Epoch 2/15
# 12355/12355 [==============================] - 0s 20us/step - loss: 1.2186 - acc: 0.4962 - val_loss: 1.1907 - val_acc: 0.5077
# Epoch 3/15
# 12355/12355 [==============================] - 0s 20us/step - loss: 1.1985 - acc: 0.5069 - val_loss: 1.1936 - val_acc: 0.5051
# Epoch 4/15
# 12355/12355 [==============================] - 0s 21us/step - loss: 1.1943 - acc: 0.5066 - val_loss: 1.1816 - val_acc: 0.5077
# Epoch 5/15
# 12355/12355 [==============================] - 0s 20us/step - loss: 1.1872 - acc: 0.5052 - val_loss: 1.1770 - val_acc: 0.5142
# Epoch 6/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 1.1831 - acc: 0.5081 - val_loss: 1.1791 - val_acc: 0.5059
# Epoch 7/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 1.1801 - acc: 0.5095 - val_loss: 1.1816 - val_acc: 0.5104
# Epoch 8/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 1.1788 - acc: 0.5089 - val_loss: 1.1734 - val_acc: 0.5110
# Epoch 9/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 1.1781 - acc: 0.5090 - val_loss: 1.1793 - val_acc: 0.5051
# Epoch 10/15
# 12355/12355 [==============================] - 0s 20us/step - loss: 1.1744 - acc: 0.5093 - val_loss: 1.1673 - val_acc: 0.5160
# Epoch 11/15
# 12355/12355 [==============================] - 0s 20us/step - loss: 1.1753 - acc: 0.5106 - val_loss: 1.1687 - val_acc: 0.5142
# Epoch 12/15
# 12355/12355 [==============================] - 0s 20us/step - loss: 1.1740 - acc: 0.5127 - val_loss: 1.1774 - val_acc: 0.5181
# Epoch 13/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 1.1735 - acc: 0.5100 - val_loss: 1.1974 - val_acc: 0.4951
# Epoch 14/15
# 12355/12355 [==============================] - 0s 20us/step - loss: 1.1716 - acc: 0.5101 - val_loss: 1.1676 - val_acc: 0.5174
# Epoch 15/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 1.1714 - acc: 0.5123 - val_loss: 1.1812 - val_acc: 0.5057
# 2023-03-08 10:16:18.780885 gender stack: NN	Train on 12355 samples, validate on 5296 samples
# Epoch 1/15
# 12355/12355 [==============================] - 1s 94us/step - loss: 0.6293 - acc: 0.6399 - val_loss: 0.6237 - val_acc: 0.6562
# Epoch 2/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 0.6082 - acc: 0.6673 - val_loss: 0.6144 - val_acc: 0.6531
# Epoch 3/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 0.6074 - acc: 0.6668 - val_loss: 0.6312 - val_acc: 0.6378
# Epoch 4/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 0.6054 - acc: 0.6682 - val_loss: 0.5986 - val_acc: 0.6733
# Epoch 5/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 0.6060 - acc: 0.6703 - val_loss: 0.6136 - val_acc: 0.6541
# Epoch 6/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 0.6047 - acc: 0.6709 - val_loss: 0.6138 - val_acc: 0.6545
# Epoch 7/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 0.6058 - acc: 0.6707 - val_loss: 0.5987 - val_acc: 0.6715
# Epoch 8/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 0.6056 - acc: 0.6662 - val_loss: 0.6172 - val_acc: 0.6656
# Epoch 9/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 0.6048 - acc: 0.6688 - val_loss: 0.6024 - val_acc: 0.6665
# Epoch 10/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 0.6049 - acc: 0.6727 - val_loss: 0.6167 - val_acc: 0.6516
# Epoch 11/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 0.6050 - acc: 0.6704 - val_loss: 0.6010 - val_acc: 0.6748
# Epoch 12/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 0.6053 - acc: 0.6675 - val_loss: 0.6069 - val_acc: 0.6571
# Epoch 13/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 0.6039 - acc: 0.6692 - val_loss: 0.6012 - val_acc: 0.6718
# Epoch 14/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 0.6053 - acc: 0.6721 - val_loss: 0.5994 - val_acc: 0.6733
# Epoch 15/15
# 12355/12355 [==============================] - 0s 19us/step - loss: 0.6044 - acc: 0.6694 - val_loss: 0.5990 - val_acc: 0.6715

# %%
nn_pred = np.hstack([nn_pred_dict["Education"],nn_pred_dict["age"],nn_pred_dict["gender"]])

# %%
nn_pred.shape
# Out:
# (17651, 14)

# %%
save_pkl(nn_pred,"AF_nn_pred")
# Out:
# 持久化存储路径：./data/WordVectorData/AF_nn_pred.feat

# %%
# 划分数据集
X_tr, X_te, Y_tr, Y_te = get_train_test(nn_pred,data["Education"])

# %%
LR_RF_model = LogisticRegression(max_iter=10000)
LR_RF_model.fit(X_tr,Y_tr)
Model_ACC(LR_RF_model,X_tr,X_te,Y_tr,Y_te)
# Out:
# 训练集准确度: 0.543828, 测试集准确度: 0.533233

# %%
XG_Model = xgb.XGBClassifier()
XG_Model.fit(X_tr,Y_tr,eval_metric='auc')
Model_ACC(XG_Model,X_tr,X_te,Y_tr,Y_te)
# Out:
# 训练集准确度: 0.886443, 测试集准确度: 0.505287

# %%
LR_pred = LR_RF_model.predict_proba(NN_pred)

# %%
LR_pred.shape
# Out:
# (17651, 6)

# %%
X_tr, X_te, Y_tr, Y_te = get_train_test(np.hstack([W2V_X_sp,nn_pred]),data["Education"])

# %%
model = LogisticRegression(max_iter=10000)
model.fit(X_tr,Y_tr)
Model_ACC(model,X_tr,X_te,Y_tr,Y_te)
# Out:
# 训练集准确度: 0.653824, 测试集准确度: 0.630665

# %%
model_nn = BF_nn_Model(X_tr,X_te,Y_tr,Y_te)
nnModel_ACC(model_nn,X_tr,X_te,Y_tr,Y_te)
# Out:
# Train on 12355 samples, validate on 5296 samples
# Epoch 1/15
# 12355/12355 [==============================] - 1s 85us/step - loss: 1.0812 - acc: 0.5480 - val_loss: 1.0140 - val_acc: 0.5802
# Epoch 2/15
# 12355/12355 [==============================] - 0s 25us/step - loss: 0.9731 - acc: 0.6047 - val_loss: 1.0355 - val_acc: 0.5778
# Epoch 3/15
# 12355/12355 [==============================] - 0s 25us/step - loss: 0.9548 - acc: 0.6151 - val_loss: 1.0270 - val_acc: 0.5825
# Epoch 4/15
# 12355/12355 [==============================] - 0s 28us/step - loss: 0.9425 - acc: 0.6220 - val_loss: 0.9563 - val_acc: 0.6171
# Epoch 5/15
# 12355/12355 [==============================] - 0s 25us/step - loss: 0.9344 - acc: 0.6262 - val_loss: 1.0269 - val_acc: 0.5784
# Epoch 6/15
# 12355/12355 [==============================] - 0s 26us/step - loss: 0.9291 - acc: 0.6266 - val_loss: 1.0066 - val_acc: 0.5844
# Epoch 7/15
# 12355/12355 [==============================] - 0s 25us/step - loss: 0.9274 - acc: 0.6257 - val_loss: 0.9719 - val_acc: 0.6156
# Epoch 8/15
# 12355/12355 [==============================] - 0s 25us/step - loss: 0.9259 - acc: 0.6291 - val_loss: 0.9766 - val_acc: 0.6157
# Epoch 9/15
# 12355/12355 [==============================] - 0s 25us/step - loss: 0.9198 - acc: 0.6327 - val_loss: 0.9627 - val_acc: 0.6112
# Epoch 10/15
# 12355/12355 [==============================] - 0s 25us/step - loss: 0.9207 - acc: 0.6305 - val_loss: 1.0565 - val_acc: 0.5682
# Epoch 11/15
# 12355/12355 [==============================] - 0s 25us/step - loss: 0.9167 - acc: 0.6323 - val_loss: 0.9829 - val_acc: 0.6082
# Epoch 12/15
# 12355/12355 [==============================] - 0s 26us/step - loss: 0.9200 - acc: 0.6363 - val_loss: 0.9694 - val_acc: 0.6180
# Epoch 13/15
# 12355/12355 [==============================] - 0s 26us/step - loss: 0.9149 - acc: 0.6333 - val_loss: 0.9704 - val_acc: 0.6154
# Epoch 14/15
# 12355/12355 [==============================] - 0s 25us/step - loss: 0.9139 - acc: 0.6331 - val_loss: 0.9652 - val_acc: 0.6131
# Epoch 15/15
# 12355/12355 [==============================] - 0s 25us/step - loss: 0.9139 - acc: 0.6366 - val_loss: 0.9516 - val_acc: 0.6246
# 训练集准确度: 0.637070, 测试集准确度: 0.624622

# %%
from sklearn.model_selection import GridSearchCV

# %%
model_xgb = xgb.XGBClassifier(
    booster="gbtree",  # # 基分类器；gbtree 树模型，gbliner 线性模型
    objective="multi:softprob",  # 目标函数；multi：softprob 返回概率，multi：softmax multi：softmax
    max_depth=12,  # 树的深度
    min_child_weight=1,  # 最小叶子节点样本权重和
    subsample=0.8,  # 随机选择XX%样本建立决策树
    colsample_bytree=0.8,  # 构造每个树时列的子采样率
)
model_xgb.fit(X_tr,Y_tr,
              eval_metric="merror" # 多分类对数损失（交叉熵）
             )
Model_ACC(model_xgb,X_tr,X_te,Y_tr,Y_te)
# Out:
# 训练集准确度: 1.000000, 测试集准确度: 0.632175

# %%
XGB_CV_params = {
        'max_depth': range(3,16,1),
        'subsample': [round(i,1) for i in np.arange(0.1,1.1,0.1)],
        'colsample_bytree' : [round(i,1) for i in np.arange(0.1,1.1,0.1)],
}

# %%
model_xgb = xgb.XGBClassifier(
    booster="gbtree",  # # 基分类器；gbtree 树模型，gbliner 线性模型
    objective="multi:softprob",  # 目标函数；multi：softprob 返回概率，multi：softmax multi：softmax
    min_child_weight=1,  # 最小叶子节点样本权重和
)
Grid_xgb = GridSearchCV(model_xgb,param_grid=XGB_CV_params,cv=5)

# %%
start = time.time()
Grid_xgb.fit(X_tr,Y_tr,eval_metric="merror")
end = time.time()
print('程序运行时间：%.2f分' %((end - start)/60))
# Out:
# [17:34:29] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:34:30] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:34:31] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:34:33] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:34:34] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:34:35] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:34:36] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:34:37] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:34:39] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:34:40] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:34:41] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:34:43] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:34:44] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:34:46] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:34:47] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:34:49] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:34:51] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:34:52] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:34:54] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:34:56] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:34:57] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:34:59] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:01] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:03] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:05] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:07] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:09] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:11] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:13] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:15] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:17] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:19] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:21] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:23] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:25] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:27] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:30] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:32] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:34] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:36] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:39] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:41] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:43] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:46] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:48] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:50] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:52] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:54] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:56] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:35:58] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:00] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:02] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:03] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:04] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:06] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:07] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:09] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:10] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:12] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:13] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:15] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:17] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:18] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:20] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:22] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:24] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:26] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:28] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:30] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:32] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:34] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:36] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:38] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:40] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:43] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:45] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:47] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:50] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:52] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:55] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:36:57] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:00] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:02] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:05] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:07] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:10] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:13] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:15] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:18] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:21] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:24] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:26] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:29] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:32] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:35] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:38] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:40] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:43] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:46] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:48] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:51] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:52] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:54] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:55] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:56] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:58] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:37:59] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:01] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:03] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:05] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:06] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:08] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:10] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:12] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:14] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:16] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:19] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:21] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:23] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:26] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:28] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:31] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:33] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:36] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:38] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:41] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:44] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:47] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:49] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:52] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:55] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:58] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:39:01] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:39:04] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:39:07] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:39:10] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:39:13] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:39:16] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:39:19] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:39:23] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:39:26] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:39:29] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:39:32] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:39:36] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:39:39] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:39:43] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:39:46] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:39:49] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:39:52] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:39:55] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:39:58] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:40:00] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:40:01] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:40:03] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:40:05] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:40:06] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:40:08] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:40:10] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:40:12] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:40:15] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:40:17] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:40:19] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:40:21] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:40:24] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:40:26] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:40:28] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:40:31] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:40:34] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...
# [08:12:04] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:12:27] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:12:50] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:13:12] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:13:35] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:13:57] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:14:02] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:14:07] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:14:12] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:14:17] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:14:22] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:14:30] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:14:38] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:14:46] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:14:54] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:15:02] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:15:13] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:15:23] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:15:34] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:15:44] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:15:55] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:16:08] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:16:21] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:16:34] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:16:47] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:17:00] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:17:16] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:17:31] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:17:46] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:18:02] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:18:17] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:18:34] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:18:51] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:19:09] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:19:26] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:19:43] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:20:01] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:20:20] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:20:39] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:20:58] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:21:17] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:21:37] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:21:58] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:22:18] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:22:39] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:22:59] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:23:21] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:23:43] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:24:05] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:24:26] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:24:48] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:25:11] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:25:34] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:25:56] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:26:19] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:26:41] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 程序运行时间：892.50分

# %%
means = Grid_xgb.cv_results_['mean_test_score']
params = Grid_xgb.cv_results_['params']
for i in range(len(means)):
    print('训练过程分数及参数：',means[i],params[i] )
print('\n最好的分数以及参数：',Grid_xgb.best_score_,Grid_xgb.best_params_)
# Out:
# 训练过程分数及参数： 0.5969243221367867 {'colsample_bytree': 0.1, 'max_depth': 3, 'subsample': 0.1}
# 训练过程分数及参数： 0.6188587616349656 {'colsample_bytree': 0.1, 'max_depth': 3, 'subsample': 0.2}
# 训练过程分数及参数： 0.6246054229057062 {'colsample_bytree': 0.1, 'max_depth': 3, 'subsample': 0.3}
# 训练过程分数及参数： 0.6298664508296236 {'colsample_bytree': 0.1, 'max_depth': 3, 'subsample': 0.4}
# 训练过程分数及参数： 0.6322136786726021 {'colsample_bytree': 0.1, 'max_depth': 3, 'subsample': 0.5}
# 训练过程分数及参数： 0.6340752731687576 {'colsample_bytree': 0.1, 'max_depth': 3, 'subsample': 0.6}
# 训练过程分数及参数： 0.635936867664913 {'colsample_bytree': 0.1, 'max_depth': 3, 'subsample': 0.7}
# 训练过程分数及参数： 0.6391744233104006 {'colsample_bytree': 0.1, 'max_depth': 3, 'subsample': 0.8}
# 训练过程分数及参数： 0.6365843787940105 {'colsample_bytree': 0.1, 'max_depth': 3, 'subsample': 0.9}
# 训练过程分数及参数： 0.6369081343585593 {'colsample_bytree': 0.1, 'max_depth': 3, 'subsample': 1.0}
# 训练过程分数及参数： 0.5820315661675435 {'colsample_bytree': 0.1, 'max_depth': 4, 'subsample': 0.1}
# 训练过程分数及参数： 0.6106029947389721 {'colsample_bytree': 0.1, 'max_depth': 4, 'subsample': 0.2}
# 训练过程分数及参数： 0.6165924726831242 {'colsample_bytree': 0.1, 'max_depth': 4, 'subsample': 0.3}
# 训练过程分数及参数： 0.6227438284095508 {'colsample_bytree': 0.1, 'max_depth': 4, 'subsample': 0.4}
# 训练过程分数及参数： 0.6199109672197491 {'colsample_bytree': 0.1, 'max_depth': 4, 'subsample': 0.5}
# 训练过程分数及参数： 0.6263051396195871 {'colsample_bytree': 0.1, 'max_depth': 4, 'subsample': 0.6}
# 训练过程分数及参数： 0.6314852286523676 {'colsample_bytree': 0.1, 'max_depth': 4, 'subsample': 0.7}
# 训练过程分数及参数： 0.6355321732092271 {'colsample_bytree': 0.1, 'max_depth': 4, 'subsample': 0.8}
# 训练过程分数及参数： 0.6328611898016998 {'colsample_bytree': 0.1, 'max_depth': 4, 'subsample': 0.9}
# 训练过程分数及参数： 0.6312424119789559 {'colsample_bytree': 0.1, 'max_depth': 4, 'subsample': 1.0}
# 训练过程分数及参数： 0.563253743423715 {'colsample_bytree': 0.1, 'max_depth': 5, 'subsample': 0.1}
# 训练过程分数及参数： 0.5964386887899635 {'colsample_bytree': 0.1, 'max_depth': 5, 'subsample': 0.2}
# 训练过程分数及参数： 0.6063941723998382 {'colsample_bytree': 0.1, 'max_depth': 5, 'subsample': 0.3}
# 训练过程分数及参数： 0.6125455281262647 {'colsample_bytree': 0.1, 'max_depth': 5, 'subsample': 0.4}
# 训练过程分数及参数： 0.6171590449210846 {'colsample_bytree': 0.1, 'max_depth': 5, 'subsample': 0.5}
# 训练过程分数及参数： 0.6220963172804532 {'colsample_bytree': 0.1, 'max_depth': 5, 'subsample': 0.6}
# 训练过程分数及参数： 0.629218939700526 {'colsample_bytree': 0.1, 'max_depth': 5, 'subsample': 0.7}
# 训练过程分数及参数： 0.6284904896802914 {'colsample_bytree': 0.1, 'max_depth': 5, 'subsample': 0.8}
# 训练过程分数及参数： 0.6263860785107245 {'colsample_bytree': 0.1, 'max_depth': 5, 'subsample': 0.9}
# 训练过程分数及参数： 0.6267907729664104 {'colsample_bytree': 0.1, 'max_depth': 5, 'subsample': 1.0}
# 训练过程分数及参数： 0.5563739376770538 {'colsample_bytree': 0.1, 'max_depth': 6, 'subsample': 0.1}
# 训练过程分数及参数： 0.5912585997571834 {'colsample_bytree': 0.1, 'max_depth': 6, 'subsample': 0.2}
# 训练过程分数及参数： 0.6033184945366249 {'colsample_bytree': 0.1, 'max_depth': 6, 'subsample': 0.3}
# 训练过程分数及参数： 0.6094698502630514 {'colsample_bytree': 0.1, 'max_depth': 6, 'subsample': 0.4}
# 训练过程分数及参数： 0.6121408336705787 {'colsample_bytree': 0.1, 'max_depth': 6, 'subsample': 0.5}
# 训练过程分数及参数： 0.6166734115742615 {'colsample_bytree': 0.1, 'max_depth': 6, 'subsample': 0.6}
# 训练过程分数及参数： 0.6221772561715905 {'colsample_bytree': 0.1, 'max_depth': 6, 'subsample': 0.7}
# 训练过程分数及参数： 0.6271145285309592 {'colsample_bytree': 0.1, 'max_depth': 6, 'subsample': 0.8}
# 训练过程分数及参数： 0.6237150951031971 {'colsample_bytree': 0.1, 'max_depth': 6, 'subsample': 0.9}
# 训练过程分数及参数： 0.6293808174828005 {'colsample_bytree': 0.1, 'max_depth': 6, 'subsample': 1.0}
# 训练过程分数及参数： 0.5558073654390936 {'colsample_bytree': 0.1, 'max_depth': 7, 'subsample': 0.1}
# 训练过程分数及参数： 0.5851881829218939 {'colsample_bytree': 0.1, 'max_depth': 7, 'subsample': 0.2}
# 训练过程分数及参数： 0.5952246054229058 {'colsample_bytree': 0.1, 'max_depth': 7, 'subsample': 0.3}
# 训练过程分数及参数： 0.6046944556859571 {'colsample_bytree': 0.1, 'max_depth': 7, 'subsample': 0.4}
# 训练过程分数及参数： 0.6077701335491704 {'colsample_bytree': 0.1, 'max_depth': 7, 'subsample': 0.5}
# 训练过程分数及参数： 0.6162687171185756 {'colsample_bytree': 0.1, 'max_depth': 7, 'subsample': 0.6}
# 训练过程分数及参数： 0.6171590449210844 {'colsample_bytree': 0.1, 'max_depth': 7, 'subsample': 0.7}
# 训练过程分数及参数： 0.6207203561311211 {'colsample_bytree': 0.1, 'max_depth': 7, 'subsample': 0.8}
# 训练过程分数及参数： 0.6212059894779441 {'colsample_bytree': 0.1, 'max_depth': 7, 'subsample': 0.9}
# 训练过程分数及参数： 0.6275192229866451 {'colsample_bytree': 0.1, 'max_depth': 7, 'subsample': 1.0}
# 训练过程分数及参数： 0.5428571428571429 {'colsample_bytree': 0.1, 'max_depth': 8, 'subsample': 0.1}
# 训练过程分数及参数： 0.5780655605018212 {'colsample_bytree': 0.1, 'max_depth': 8, 'subsample': 0.2}
# 训练过程分数及参数： 0.5933630109267504 {'colsample_bytree': 0.1, 'max_depth': 8, 'subsample': 0.3}
# 训练过程分数及参数： 0.6027519222986645 {'colsample_bytree': 0.1, 'max_depth': 8, 'subsample': 0.4}
# 训练过程分数及参数： 0.6106029947389721 {'colsample_bytree': 0.1, 'max_depth': 8, 'subsample': 0.5}
# 训练过程分数及参数： 0.6159449615540267 {'colsample_bytree': 0.1, 'max_depth': 8, 'subsample': 0.6}
# 训练过程分数及参数： 0.619425333872926 {'colsample_bytree': 0.1, 'max_depth': 8, 'subsample': 0.7}
# 训练过程分数及参数： 0.6187778227438285 {'colsample_bytree': 0.1, 'max_depth': 8, 'subsample': 0.8}
# 训练过程分数及参数： 0.6204775394577094 {'colsample_bytree': 0.1, 'max_depth': 8, 'subsample': 0.9}
# 训练过程分数及参数： 0.6216106839336302 {'colsample_bytree': 0.1, 'max_depth': 8, 'subsample': 1.0}
# 训练过程分数及参数： 0.5446377984621611 {'colsample_bytree': 0.1, 'max_depth': 9, 'subsample': 0.1}
# 训练过程分数及参数： 0.5802509105625253 {'colsample_bytree': 0.1, 'max_depth': 9, 'subsample': 0.2}
# 训练过程分数及参数： 0.5939295831647107 {'colsample_bytree': 0.1, 'max_depth': 9, 'subsample': 0.3}
# 训练过程分数及参数： 0.6044516390125455 {'colsample_bytree': 0.1, 'max_depth': 9, 'subsample': 0.4}
# 训练过程分数及参数： 0.6086604613516794 {'colsample_bytree': 0.1, 'max_depth': 9, 'subsample': 0.5}
# 训练过程分数及参数： 0.6153783893160664 {'colsample_bytree': 0.1, 'max_depth': 9, 'subsample': 0.6}
# 训练过程分数及参数： 0.6174018615944961 {'colsample_bytree': 0.1, 'max_depth': 9, 'subsample': 0.7}
# 训练过程分数及参数： 0.6255766895993526 {'colsample_bytree': 0.1, 'max_depth': 9, 'subsample': 0.8}
# 训练过程分数及参数： 0.6220153783893161 {'colsample_bytree': 0.1, 'max_depth': 9, 'subsample': 0.9}
# 训练过程分数及参数： 0.6267907729664104 {'colsample_bytree': 0.1, 'max_depth': 9, 'subsample': 1.0}
# 训练过程分数及参数： 0.5469040874140024 {'colsample_bytree': 0.1, 'max_depth': 10, 'subsample': 0.1}
# 训练过程分数及参数： 0.5779036827195467 {'colsample_bytree': 0.1, 'max_depth': 10, 'subsample': 0.2}
# 训练过程分数及参数： 0.5917442331040064 {'colsample_bytree': 0.1, 'max_depth': 10, 'subsample': 0.3}
# 训练过程分数及参数： 0.5990287333063538 {'colsample_bytree': 0.1, 'max_depth': 10, 'subsample': 0.4}
# 训练过程分数及参数： 0.6059894779441521 {'colsample_bytree': 0.1, 'max_depth': 10, 'subsample': 0.5}
# 训练过程分数及参数： 0.6140833670578714 {'colsample_bytree': 0.1, 'max_depth': 10, 'subsample': 0.6}
# 训练过程分数及参数： 0.6134358559287738 {'colsample_bytree': 0.1, 'max_depth': 10, 'subsample': 0.7}
# 训练过程分数及参数： 0.6201537838931606 {'colsample_bytree': 0.1, 'max_depth': 10, 'subsample': 0.8}
# 训练过程分数及参数： 0.6207203561311211 {'colsample_bytree': 0.1, 'max_depth': 10, 'subsample': 0.9}
# 训练过程分数及参数： 0.6182112505058681 {'colsample_bytree': 0.1, 'max_depth': 10, 'subsample': 1.0}
# 训练过程分数及参数： 0.5435046539862405 {'colsample_bytree': 0.1, 'max_depth': 11, 'subsample': 0.1}
# 训练过程分数及参数： 0.5731282881424524 {'colsample_bytree': 0.1, 'max_depth': 11, 'subsample': 0.2}
# 训练过程分数及参数： 0.5887494941319303 {'colsample_bytree': 0.1, 'max_depth': 11, 'subsample': 0.3}
# 训练过程分数及参数： 0.6070416835289356 {'colsample_bytree': 0.1, 'max_depth': 11, 'subsample': 0.4}
# 训练过程分数及参数： 0.6080938891137192 {'colsample_bytree': 0.1, 'max_depth': 11, 'subsample': 0.5}
# 训练过程分数及参数： 0.6098745447187375 {'colsample_bytree': 0.1, 'max_depth': 11, 'subsample': 0.6}
# 训练过程分数及参数： 0.6125455281262646 {'colsample_bytree': 0.1, 'max_depth': 11, 'subsample': 0.7}
# 训练过程分数及参数： 0.6174828004856333 {'colsample_bytree': 0.1, 'max_depth': 11, 'subsample': 0.8}
# 训练过程分数及参数： 0.6164305949008498 {'colsample_bytree': 0.1, 'max_depth': 11, 'subsample': 0.9}
# 训练过程分数及参数： 0.6159449615540267 {'colsample_bytree': 0.1, 'max_depth': 11, 'subsample': 1.0}
# 训练过程分数及参数： 0.5473897207608257 {'colsample_bytree': 0.1, 'max_depth': 12, 'subsample': 0.1}
# 训练过程分数及参数： 0.5730473492513152 {'colsample_bytree': 0.1, 'max_depth': 12, 'subsample': 0.2}
# 训练过程分数及参数： 0.5985430999595305 {'colsample_bytree': 0.1, 'max_depth': 12, 'subsample': 0.3}
# 训练过程分数及参数： 0.6018615944961554 {'colsample_bytree': 0.1, 'max_depth': 12, 'subsample': 0.4}
# 训练过程分数及参数： 0.6100364225010116 {'colsample_bytree': 0.1, 'max_depth': 12, 'subsample': 0.5}
# 训练过程分数及参数： 0.6148927559692432 {'colsample_bytree': 0.1, 'max_depth': 12, 'subsample': 0.6}
# 训练过程分数及参数： 0.611412383650344 {'colsample_bytree': 0.1, 'max_depth': 12, 'subsample': 0.7}
# 训练过程分数及参数： 0.616916228247673 {'colsample_bytree': 0.1, 'max_depth': 12, 'subsample': 0.8}
# 训练过程分数及参数： 0.6172399838122218 {'colsample_bytree': 0.1, 'max_depth': 12, 'subsample': 0.9}
# 训练过程分数及参数： 0.619910967219749 {'colsample_bytree': 0.1, 'max_depth': 12, 'subsample': 1.0}
# 训练过程分数及参数： 0.5456900040469446 {'colsample_bytree': 0.1, 'max_depth': 13, 'subsample': 0.1}
# 训练过程分数及参数： 0.5736948603804128 {'colsample_bytree': 0.1, 'max_depth': 13, 'subsample': 0.2}
# 训练过程分数及参数： 0.5895588830433024 {'colsample_bytree': 0.1, 'max_depth': 13, 'subsample': 0.3}
# 训练过程分数及参数： 0.5973290165924727 {'colsample_bytree': 0.1, 'max_depth': 13, 'subsample': 0.4}
# 训练过程分数及参数： 0.609307972480777 {'colsample_bytree': 0.1, 'max_depth': 13, 'subsample': 0.5}
# 训练过程分数及参数： 0.612707405908539 {'colsample_bytree': 0.1, 'max_depth': 13, 'subsample': 0.6}
# 训练过程分数及参数： 0.6073654390934845 {'colsample_bytree': 0.1, 'max_depth': 13, 'subsample': 0.7}
# 训练过程分数及参数： 0.614326183731283 {'colsample_bytree': 0.1, 'max_depth': 13, 'subsample': 0.8}
# 训练过程分数及参数： 0.6147308781869688 {'colsample_bytree': 0.1, 'max_depth': 13, 'subsample': 0.9}
# 训练过程分数及参数： 0.6156212059894779 {'colsample_bytree': 0.1, 'max_depth': 13, 'subsample': 1.0}
# 训练过程分数及参数： 0.542533387292594 {'colsample_bytree': 0.1, 'max_depth': 14, 'subsample': 0.1}
# 训练过程分数及参数： 0.5760420882233914 {'colsample_bytree': 0.1, 'max_depth': 14, 'subsample': 0.2}
# 训练过程分数及参数： 0.5957102387697288 {'colsample_bytree': 0.1, 'max_depth': 14, 'subsample': 0.3}
# 训练过程分数及参数： 0.5975718332658844 {'colsample_bytree': 0.1, 'max_depth': 14, 'subsample': 0.4}
# 训练过程分数及参数： 0.6093889113719142 {'colsample_bytree': 0.1, 'max_depth': 14, 'subsample': 0.5}
# 训练过程分数及参数： 0.6094698502630514 {'colsample_bytree': 0.1, 'max_depth': 14, 'subsample': 0.6}
# 训练过程分数及参数： 0.6134358559287738 {'colsample_bytree': 0.1, 'max_depth': 14, 'subsample': 0.7}
# 训练过程分数及参数： 0.6144880615135573 {'colsample_bytree': 0.1, 'max_depth': 14, 'subsample': 0.8}
# 训练过程分数及参数： 0.6146499392958317 {'colsample_bytree': 0.1, 'max_depth': 14, 'subsample': 0.9}
# 训练过程分数及参数： 0.6157021448806151 {'colsample_bytree': 0.1, 'max_depth': 14, 'subsample': 1.0}
# 训练过程分数及参数： 0.5350870093079725 {'colsample_bytree': 0.1, 'max_depth': 15, 'subsample': 0.1}
# 训练过程分数及参数： 0.5749898826386077 {'colsample_bytree': 0.1, 'max_depth': 15, 'subsample': 0.2}
# 训练过程分数及参数： 0.593686766491299 {'colsample_bytree': 0.1, 'max_depth': 15, 'subsample': 0.3}
# 训练过程分数及参数： 0.5983002832861191 {'colsample_bytree': 0.1, 'max_depth': 15, 'subsample': 0.4}
# 训练过程分数及参数： 0.6055847834884662 {'colsample_bytree': 0.1, 'max_depth': 15, 'subsample': 0.5}
# 训练过程分数及参数： 0.6133549170376366 {'colsample_bytree': 0.1, 'max_depth': 15, 'subsample': 0.6}
# 训练过程分数及参数： 0.6107648725212466 {'colsample_bytree': 0.1, 'max_depth': 15, 'subsample': 0.7}
# 训练过程分数及参数： 0.6142452448401456 {'colsample_bytree': 0.1, 'max_depth': 15, 'subsample': 0.8}
# 训练过程分数及参数： 0.6131930392553622 {'colsample_bytree': 0.1, 'max_depth': 15, 'subsample': 0.9}
# 训练过程分数及参数： 0.6110076891946581 {'colsample_bytree': 0.1, 'max_depth': 15, 'subsample': 1.0}
# 训练过程分数及参数： 0.6002428166734116 {'colsample_bytree': 0.2, 'max_depth': 3, 'subsample': 0.1}
# 训练过程分数及参数： 0.6181303116147309 {'colsample_bytree': 0.2, 'max_depth': 3, 'subsample': 0.2}
# 训练过程分数及参数： 0.6225010117361391 {'colsample_bytree': 0.2, 'max_depth': 3, 'subsample': 0.3}
# 训练过程分数及参数： 0.6302711452853096 {'colsample_bytree': 0.2, 'max_depth': 3, 'subsample': 0.4}
# 训练过程分数及参数： 0.6296236341562121 {'colsample_bytree': 0.2, 'max_depth': 3, 'subsample': 0.5}
# 训练过程分数及参数： 0.6336705787130716 {'colsample_bytree': 0.2, 'max_depth': 3, 'subsample': 0.6}
# 训练过程分数及参数： 0.636422501011736 {'colsample_bytree': 0.2, 'max_depth': 3, 'subsample': 0.7}
# 训练过程分数及参数： 0.6351274787535411 {'colsample_bytree': 0.2, 'max_depth': 3, 'subsample': 0.8}
# 训练过程分数及参数： 0.635127478753541 {'colsample_bytree': 0.2, 'max_depth': 3, 'subsample': 0.9}
# 训练过程分数及参数： 0.6395791177660867 {'colsample_bytree': 0.2, 'max_depth': 3, 'subsample': 1.0}
# 训练过程分数及参数： 0.5873735329825982 {'colsample_bytree': 0.2, 'max_depth': 4, 'subsample': 0.1}
# 训练过程分数及参数： 0.606313233508701 {'colsample_bytree': 0.2, 'max_depth': 4, 'subsample': 0.2}
# 训练过程分数及参数： 0.6148118170781061 {'colsample_bytree': 0.2, 'max_depth': 4, 'subsample': 0.3}
# 训练过程分数及参数： 0.6268717118575475 {'colsample_bytree': 0.2, 'max_depth': 4, 'subsample': 0.4}
# 训练过程分数及参数： 0.6268717118575476 {'colsample_bytree': 0.2, 'max_depth': 4, 'subsample': 0.5}
# 训练过程分数及参数： 0.6274382840955078 {'colsample_bytree': 0.2, 'max_depth': 4, 'subsample': 0.6}
# 训练过程分数及参数： 0.6320518008903278 {'colsample_bytree': 0.2, 'max_depth': 4, 'subsample': 0.7}
# 训练过程分数及参数： 0.6303520841764467 {'colsample_bytree': 0.2, 'max_depth': 4, 'subsample': 0.8}
# 训练过程分数及参数： 0.6326183731282882 {'colsample_bytree': 0.2, 'max_depth': 4, 'subsample': 0.9}
# 训练过程分数及参数： 0.6331849453662486 {'colsample_bytree': 0.2, 'max_depth': 4, 'subsample': 1.0}
# 训练过程分数及参数： 0.5702144880615135 {'colsample_bytree': 0.2, 'max_depth': 5, 'subsample': 0.1}
# 训练过程分数及参数： 0.5995143666531768 {'colsample_bytree': 0.2, 'max_depth': 5, 'subsample': 0.2}
# 训练过程分数及参数： 0.6053419668150547 {'colsample_bytree': 0.2, 'max_depth': 5, 'subsample': 0.3}
# 训练过程分数及参数： 0.6184540671792796 {'colsample_bytree': 0.2, 'max_depth': 5, 'subsample': 0.4}
# 训练过程分数及参数： 0.6221772561715905 {'colsample_bytree': 0.2, 'max_depth': 5, 'subsample': 0.5}
# 训练过程分数及参数： 0.6227438284095508 {'colsample_bytree': 0.2, 'max_depth': 5, 'subsample': 0.6}
# 训练过程分数及参数： 0.6229057061918252 {'colsample_bytree': 0.2, 'max_depth': 5, 'subsample': 0.7}
# 训练过程分数及参数： 0.6263051396195871 {'colsample_bytree': 0.2, 'max_depth': 5, 'subsample': 0.8}
# 训练过程分数及参数： 0.6290570619182517 {'colsample_bytree': 0.2, 'max_depth': 5, 'subsample': 0.9}
# 训练过程分数及参数： 0.6318089842169162 {'colsample_bytree': 0.2, 'max_depth': 5, 'subsample': 1.0}
# 训练过程分数及参数： 0.5595305544314043 {'colsample_bytree': 0.2, 'max_depth': 6, 'subsample': 0.1}
# 训练过程分数及参数： 0.5867260218535006 {'colsample_bytree': 0.2, 'max_depth': 6, 'subsample': 0.2}
# 训练过程分数及参数： 0.6081748280048563 {'colsample_bytree': 0.2, 'max_depth': 6, 'subsample': 0.3}
# 训练过程分数及参数： 0.6103601780655605 {'colsample_bytree': 0.2, 'max_depth': 6, 'subsample': 0.4}
# 训练过程分数及参数： 0.6179684338324565 {'colsample_bytree': 0.2, 'max_depth': 6, 'subsample': 0.5}
# 训练过程分数及参数： 0.6229866450829624 {'colsample_bytree': 0.2, 'max_depth': 6, 'subsample': 0.6}
# 训练过程分数及参数： 0.6213678672602185 {'colsample_bytree': 0.2, 'max_depth': 6, 'subsample': 0.7}
# 训练过程分数及参数： 0.6276811007689196 {'colsample_bytree': 0.2, 'max_depth': 6, 'subsample': 0.8}
# 训练过程分数及参数： 0.629623634156212 {'colsample_bytree': 0.2, 'max_depth': 6, 'subsample': 0.9}
# 训练过程分数及参数： 0.630433023067584 {'colsample_bytree': 0.2, 'max_depth': 6, 'subsample': 1.0}
# 训练过程分数及参数： 0.5578308377175233 {'colsample_bytree': 0.2, 'max_depth': 7, 'subsample': 0.1}
# 训练过程分数及参数： 0.5918251719951437 {'colsample_bytree': 0.2, 'max_depth': 7, 'subsample': 0.2}
# 训练过程分数及参数： 0.6017806556050183 {'colsample_bytree': 0.2, 'max_depth': 7, 'subsample': 0.3}
# 训练过程分数及参数： 0.6129502225819505 {'colsample_bytree': 0.2, 'max_depth': 7, 'subsample': 0.4}
# 训练过程分数及参数： 0.6216916228247673 {'colsample_bytree': 0.2, 'max_depth': 7, 'subsample': 0.5}
# 训练过程分数及参数： 0.6226628895184135 {'colsample_bytree': 0.2, 'max_depth': 7, 'subsample': 0.6}
# 训练过程分数及参数： 0.6251719951436666 {'colsample_bytree': 0.2, 'max_depth': 7, 'subsample': 0.7}
# 训练过程分数及参数： 0.628733306353703 {'colsample_bytree': 0.2, 'max_depth': 7, 'subsample': 0.8}
# 训练过程分数及参数： 0.6294617563739378 {'colsample_bytree': 0.2, 'max_depth': 7, 'subsample': 0.9}
# 训练过程分数及参数： 0.6320518008903278 {'colsample_bytree': 0.2, 'max_depth': 7, 'subsample': 1.0}
# 训练过程分数及参数： 0.5557264265479562 {'colsample_bytree': 0.2, 'max_depth': 8, 'subsample': 0.1}
# 训练过程分数及参数： 0.585188182921894 {'colsample_bytree': 0.2, 'max_depth': 8, 'subsample': 0.2}
# 训练过程分数及参数： 0.6 {'colsample_bytree': 0.2, 'max_depth': 8, 'subsample': 0.3}
# 训练过程分数及参数： 0.6115742614326184 {'colsample_bytree': 0.2, 'max_depth': 8, 'subsample': 0.4}
# 训练过程分数及参数： 0.6182921893970053 {'colsample_bytree': 0.2, 'max_depth': 8, 'subsample': 0.5}
# 训练过程分数及参数： 0.6238769728854714 {'colsample_bytree': 0.2, 'max_depth': 8, 'subsample': 0.6}
# 训练过程分数及参数： 0.6225010117361393 {'colsample_bytree': 0.2, 'max_depth': 8, 'subsample': 0.7}
# 训练过程分数及参数： 0.6254957507082153 {'colsample_bytree': 0.2, 'max_depth': 8, 'subsample': 0.8}
# 训练过程分数及参数： 0.6300283286118981 {'colsample_bytree': 0.2, 'max_depth': 8, 'subsample': 0.9}
# 训练过程分数及参数： 0.6319708619991906 {'colsample_bytree': 0.2, 'max_depth': 8, 'subsample': 1.0}
# 训练过程分数及参数： 0.5515176042088223 {'colsample_bytree': 0.2, 'max_depth': 9, 'subsample': 0.1}
# 训练过程分数及参数： 0.5943342776203966 {'colsample_bytree': 0.2, 'max_depth': 9, 'subsample': 0.2}
# 训练过程分数及参数： 0.5996762444354512 {'colsample_bytree': 0.2, 'max_depth': 9, 'subsample': 0.3}
# 训练过程分数及参数： 0.611412383650344 {'colsample_bytree': 0.2, 'max_depth': 9, 'subsample': 0.4}
# 训练过程分数及参数： 0.6157830837717524 {'colsample_bytree': 0.2, 'max_depth': 9, 'subsample': 0.5}
# 训练过程分数及参数： 0.6201537838931607 {'colsample_bytree': 0.2, 'max_depth': 9, 'subsample': 0.6}
# 训练过程分数及参数： 0.6242007284500203 {'colsample_bytree': 0.2, 'max_depth': 9, 'subsample': 0.7}
# 训练过程分数及参数： 0.624929178470255 {'colsample_bytree': 0.2, 'max_depth': 9, 'subsample': 0.8}
# 训练过程分数及参数： 0.6280048563334683 {'colsample_bytree': 0.2, 'max_depth': 9, 'subsample': 0.9}
# 训练过程分数及参数： 0.6292189397005261 {'colsample_bytree': 0.2, 'max_depth': 9, 'subsample': 1.0}
# 训练过程分数及参数： 0.5548360987454471 {'colsample_bytree': 0.2, 'max_depth': 10, 'subsample': 0.1}
# 训练过程分数及参数： 0.5881019830028328 {'colsample_bytree': 0.2, 'max_depth': 10, 'subsample': 0.2}
# 训练过程分数及参数： 0.6003237555645488 {'colsample_bytree': 0.2, 'max_depth': 10, 'subsample': 0.3}
# 训练过程分数及参数： 0.6115742614326184 {'colsample_bytree': 0.2, 'max_depth': 10, 'subsample': 0.4}
# 训练过程分数及参数： 0.6193443949817887 {'colsample_bytree': 0.2, 'max_depth': 10, 'subsample': 0.5}
# 训练过程分数及参数： 0.6246863617968434 {'colsample_bytree': 0.2, 'max_depth': 10, 'subsample': 0.6}
# 训练过程分数及参数： 0.6251719951436664 {'colsample_bytree': 0.2, 'max_depth': 10, 'subsample': 0.7}
# 训练过程分数及参数： 0.6282476730068798 {'colsample_bytree': 0.2, 'max_depth': 10, 'subsample': 0.8}
# 训练过程分数及参数： 0.6263860785107245 {'colsample_bytree': 0.2, 'max_depth': 10, 'subsample': 0.9}
# 训练过程分数及参数： 0.6298664508296236 {'colsample_bytree': 0.2, 'max_depth': 10, 'subsample': 1.0}
# 训练过程分数及参数： 0.5532173209227034 {'colsample_bytree': 0.2, 'max_depth': 11, 'subsample': 0.1}
# 训练过程分数及参数： 0.5870497774180493 {'colsample_bytree': 0.2, 'max_depth': 11, 'subsample': 0.2}
# 训练过程分数及参数： 0.6025900445163902 {'colsample_bytree': 0.2, 'max_depth': 11, 'subsample': 0.3}
# 训练过程分数及参数： 0.6125455281262646 {'colsample_bytree': 0.2, 'max_depth': 11, 'subsample': 0.4}
# 训练过程分数及参数： 0.6142452448401456 {'colsample_bytree': 0.2, 'max_depth': 11, 'subsample': 0.5}
# 训练过程分数及参数： 0.6254148118170781 {'colsample_bytree': 0.2, 'max_depth': 11, 'subsample': 0.6}
# 训练过程分数及参数： 0.624929178470255 {'colsample_bytree': 0.2, 'max_depth': 11, 'subsample': 0.7}
# 训练过程分数及参数： 0.628733306353703 {'colsample_bytree': 0.2, 'max_depth': 11, 'subsample': 0.8}
# 训练过程分数及参数： 0.6267907729664104 {'colsample_bytree': 0.2, 'max_depth': 11, 'subsample': 0.9}
# 训练过程分数及参数： 0.6301092675030352 {'colsample_bytree': 0.2, 'max_depth': 11, 'subsample': 1.0}
# 训练过程分数及参数： 0.5588830433023068 {'colsample_bytree': 0.2, 'max_depth': 12, 'subsample': 0.1}
# 训练过程分数及参数： 0.5917442331040064 {'colsample_bytree': 0.2, 'max_depth': 12, 'subsample': 0.2}
# 训练过程分数及参数： 0.6012950222581951 {'colsample_bytree': 0.2, 'max_depth': 12, 'subsample': 0.3}
# 训练过程分数及参数： 0.6104411169566977 {'colsample_bytree': 0.2, 'max_depth': 12, 'subsample': 0.4}
# 训练过程分数及参数： 0.6180493727235937 {'colsample_bytree': 0.2, 'max_depth': 12, 'subsample': 0.5}
# 训练过程分数及参数： 0.6216106839336301 {'colsample_bytree': 0.2, 'max_depth': 12, 'subsample': 0.6}
# 训练过程分数及参数： 0.6281667341157426 {'colsample_bytree': 0.2, 'max_depth': 12, 'subsample': 0.7}
# 训练过程分数及参数： 0.6236341562120599 {'colsample_bytree': 0.2, 'max_depth': 12, 'subsample': 0.8}
# 训练过程分数及参数： 0.6282476730068798 {'colsample_bytree': 0.2, 'max_depth': 12, 'subsample': 0.9}
# 训练过程分数及参数： 0.6302711452853095 {'colsample_bytree': 0.2, 'max_depth': 12, 'subsample': 1.0}
# 训练过程分数及参数： 0.5575070821529746 {'colsample_bytree': 0.2, 'max_depth': 13, 'subsample': 0.1}
# 训练过程分数及参数： 0.5913395386483206 {'colsample_bytree': 0.2, 'max_depth': 13, 'subsample': 0.2}
# 训练过程分数及参数： 0.6004046944556859 {'colsample_bytree': 0.2, 'max_depth': 13, 'subsample': 0.3}
# 训练过程分数及参数： 0.6136786726021854 {'colsample_bytree': 0.2, 'max_depth': 13, 'subsample': 0.4}
# 训练过程分数及参数： 0.6191015783083771 {'colsample_bytree': 0.2, 'max_depth': 13, 'subsample': 0.5}
# 训练过程分数及参数： 0.6193443949817887 {'colsample_bytree': 0.2, 'max_depth': 13, 'subsample': 0.6}
# 训练过程分数及参数： 0.6237150951031971 {'colsample_bytree': 0.2, 'max_depth': 13, 'subsample': 0.7}
# 训练过程分数及参数： 0.6226628895184136 {'colsample_bytree': 0.2, 'max_depth': 13, 'subsample': 0.8}
# 训练过程分数及参数： 0.6225819506272765 {'colsample_bytree': 0.2, 'max_depth': 13, 'subsample': 0.9}
# 训练过程分数及参数： 0.6250101173613922 {'colsample_bytree': 0.2, 'max_depth': 13, 'subsample': 1.0}
# 训练过程分数及参数： 0.551355726426548 {'colsample_bytree': 0.2, 'max_depth': 14, 'subsample': 0.1}
# 训练过程分数及参数： 0.5862403885066774 {'colsample_bytree': 0.2, 'max_depth': 14, 'subsample': 0.2}
# 训练过程分数及参数： 0.6002428166734116 {'colsample_bytree': 0.2, 'max_depth': 14, 'subsample': 0.3}
# 训练过程分数及参数： 0.608903278025091 {'colsample_bytree': 0.2, 'max_depth': 14, 'subsample': 0.4}
# 训练过程分数及参数： 0.6179684338324565 {'colsample_bytree': 0.2, 'max_depth': 14, 'subsample': 0.5}
# 训练过程分数及参数： 0.616916228247673 {'colsample_bytree': 0.2, 'max_depth': 14, 'subsample': 0.6}
# 训练过程分数及参数： 0.6237960339943343 {'colsample_bytree': 0.2, 'max_depth': 14, 'subsample': 0.7}
# 训练过程分数及参数： 0.625333872925941 {'colsample_bytree': 0.2, 'max_depth': 14, 'subsample': 0.8}
# 训练过程分数及参数： 0.624929178470255 {'colsample_bytree': 0.2, 'max_depth': 14, 'subsample': 0.9}
# 训练过程分数及参数： 0.6276811007689196 {'colsample_bytree': 0.2, 'max_depth': 14, 'subsample': 1.0}
# 训练过程分数及参数： 0.5597733711048158 {'colsample_bytree': 0.2, 'max_depth': 15, 'subsample': 0.1}
# 训练过程分数及参数： 0.583083771752327 {'colsample_bytree': 0.2, 'max_depth': 15, 'subsample': 0.2}
# 训练过程分数及参数： 0.5987859166329421 {'colsample_bytree': 0.2, 'max_depth': 15, 'subsample': 0.3}
# 训练过程分数及参数： 0.6089032780250909 {'colsample_bytree': 0.2, 'max_depth': 15, 'subsample': 0.4}
# 训练过程分数及参数： 0.6157830837717523 {'colsample_bytree': 0.2, 'max_depth': 15, 'subsample': 0.5}
# 训练过程分数及参数： 0.6191825171995144 {'colsample_bytree': 0.2, 'max_depth': 15, 'subsample': 0.6}
# 训练过程分数及参数： 0.6198300283286119 {'colsample_bytree': 0.2, 'max_depth': 15, 'subsample': 0.7}
# 训练过程分数及参数： 0.6250910562525294 {'colsample_bytree': 0.2, 'max_depth': 15, 'subsample': 0.8}
# 训练过程分数及参数： 0.6251719951436665 {'colsample_bytree': 0.2, 'max_depth': 15, 'subsample': 0.9}
# 训练过程分数及参数： 0.6305139619587211 {'colsample_bytree': 0.2, 'max_depth': 15, 'subsample': 1.0}
# 训练过程分数及参数： 0.597005261027924 {'colsample_bytree': 0.3, 'max_depth': 3, 'subsample': 0.1}
# 训练过程分数及参数： 0.6176446782679077 {'colsample_bytree': 0.3, 'max_depth': 3, 'subsample': 0.2}
# 训练过程分数及参数： 0.6206394172399838 {'colsample_bytree': 0.3, 'max_depth': 3, 'subsample': 0.3}
# 训练过程分数及参数： 0.626628895184136 {'colsample_bytree': 0.3, 'max_depth': 3, 'subsample': 0.4}
# 训练过程分数及参数： 0.6367462565762849 {'colsample_bytree': 0.3, 'max_depth': 3, 'subsample': 0.5}
# 训练过程分数及参数： 0.6349656009712666 {'colsample_bytree': 0.3, 'max_depth': 3, 'subsample': 0.6}
# 训练过程分数及参数： 0.6349656009712668 {'colsample_bytree': 0.3, 'max_depth': 3, 'subsample': 0.7}
# 训练过程分数及参数： 0.6362606232294616 {'colsample_bytree': 0.3, 'max_depth': 3, 'subsample': 0.8}
# 训练过程分数及参数： 0.6376365843787941 {'colsample_bytree': 0.3, 'max_depth': 3, 'subsample': 0.9}
# 训练过程分数及参数： 0.6372318899231081 {'colsample_bytree': 0.3, 'max_depth': 3, 'subsample': 1.0}
# 训练过程分数及参数： 0.5788749494131931 {'colsample_bytree': 0.3, 'max_depth': 4, 'subsample': 0.1}
# 训练过程分数及参数： 0.6034803723188992 {'colsample_bytree': 0.3, 'max_depth': 4, 'subsample': 0.2}
# 训练过程分数及参数： 0.6127883447996763 {'colsample_bytree': 0.3, 'max_depth': 4, 'subsample': 0.3}
# 训练过程分数及参数： 0.62363415621206 {'colsample_bytree': 0.3, 'max_depth': 4, 'subsample': 0.4}
# 训练过程分数及参数： 0.6260623229461756 {'colsample_bytree': 0.3, 'max_depth': 4, 'subsample': 0.5}
# 训练过程分数及参数： 0.6263051396195871 {'colsample_bytree': 0.3, 'max_depth': 4, 'subsample': 0.6}
# 训练过程分数及参数： 0.6305949008498584 {'colsample_bytree': 0.3, 'max_depth': 4, 'subsample': 0.7}
# 训练过程分数及参数： 0.63342776203966 {'colsample_bytree': 0.3, 'max_depth': 4, 'subsample': 0.8}
# 训练过程分数及参数： 0.6369890732496966 {'colsample_bytree': 0.3, 'max_depth': 4, 'subsample': 0.9}
# 训练过程分数及参数： 0.6361796843383246 {'colsample_bytree': 0.3, 'max_depth': 4, 'subsample': 1.0}
# 训练过程分数及参数： 0.5730473492513153 {'colsample_bytree': 0.3, 'max_depth': 5, 'subsample': 0.1}
# 训练过程分数及参数： 0.5978146499392958 {'colsample_bytree': 0.3, 'max_depth': 5, 'subsample': 0.2}
# 训练过程分数及参数： 0.6113314447592068 {'colsample_bytree': 0.3, 'max_depth': 5, 'subsample': 0.3}
# 训练过程分数及参数： 0.6165115337919871 {'colsample_bytree': 0.3, 'max_depth': 5, 'subsample': 0.4}
# 训练过程分数及参数： 0.620720356131121 {'colsample_bytree': 0.3, 'max_depth': 5, 'subsample': 0.5}
# 训练过程分数及参数： 0.6254148118170781 {'colsample_bytree': 0.3, 'max_depth': 5, 'subsample': 0.6}
# 训练过程分数及参数： 0.6269526507486848 {'colsample_bytree': 0.3, 'max_depth': 5, 'subsample': 0.7}
# 训练过程分数及参数： 0.63083771752327 {'colsample_bytree': 0.3, 'max_depth': 5, 'subsample': 0.8}
# 训练过程分数及参数： 0.6275192229866451 {'colsample_bytree': 0.3, 'max_depth': 5, 'subsample': 0.9}
# 训练过程分数及参数： 0.6308377175232699 {'colsample_bytree': 0.3, 'max_depth': 5, 'subsample': 1.0}
# 训练过程分数及参数： 0.5662484823957912 {'colsample_bytree': 0.3, 'max_depth': 6, 'subsample': 0.1}
# 训练过程分数及参数： 0.5969243221367867 {'colsample_bytree': 0.3, 'max_depth': 6, 'subsample': 0.2}
# 训练过程分数及参数： 0.6016187778227438 {'colsample_bytree': 0.3, 'max_depth': 6, 'subsample': 0.3}
# 训练过程分数及参数： 0.6105220558478348 {'colsample_bytree': 0.3, 'max_depth': 6, 'subsample': 0.4}
# 训练过程分数及参数： 0.6237150951031971 {'colsample_bytree': 0.3, 'max_depth': 6, 'subsample': 0.5}
# 训练过程分数及参数： 0.6217725617159044 {'colsample_bytree': 0.3, 'max_depth': 6, 'subsample': 0.6}
# 训练过程分数及参数： 0.6263860785107245 {'colsample_bytree': 0.3, 'max_depth': 6, 'subsample': 0.7}
# 训练过程分数及参数： 0.6251719951436665 {'colsample_bytree': 0.3, 'max_depth': 6, 'subsample': 0.8}
# 训练过程分数及参数： 0.6318089842169162 {'colsample_bytree': 0.3, 'max_depth': 6, 'subsample': 0.9}
# 训练过程分数及参数： 0.6284095507891542 {'colsample_bytree': 0.3, 'max_depth': 6, 'subsample': 1.0}
# 训练过程分数及参数： 0.5634156212059895 {'colsample_bytree': 0.3, 'max_depth': 7, 'subsample': 0.1}
# 训练过程分数及参数： 0.5949008498583568 {'colsample_bytree': 0.3, 'max_depth': 7, 'subsample': 0.2}
# 训练过程分数及参数： 0.6057466612707405 {'colsample_bytree': 0.3, 'max_depth': 7, 'subsample': 0.3}
# 训练过程分数及参数： 0.614002428166734 {'colsample_bytree': 0.3, 'max_depth': 7, 'subsample': 0.4}
# 训练过程分数及参数： 0.6215297450424929 {'colsample_bytree': 0.3, 'max_depth': 7, 'subsample': 0.5}
# 训练过程分数及参数： 0.6240388506677459 {'colsample_bytree': 0.3, 'max_depth': 7, 'subsample': 0.6}
# 训练过程分数及参数： 0.6273573452043706 {'colsample_bytree': 0.3, 'max_depth': 7, 'subsample': 0.7}
# 训练过程分数及参数： 0.6268717118575475 {'colsample_bytree': 0.3, 'max_depth': 7, 'subsample': 0.8}
# 训练过程分数及参数： 0.6314042897612302 {'colsample_bytree': 0.3, 'max_depth': 7, 'subsample': 0.9}
# 训练过程分数及参数： 0.6316471064346418 {'colsample_bytree': 0.3, 'max_depth': 7, 'subsample': 1.0}
# 训练过程分数及参数： 0.5621205989477944 {'colsample_bytree': 0.3, 'max_depth': 8, 'subsample': 0.1}
# 训练过程分数及参数： 0.5925536220153784 {'colsample_bytree': 0.3, 'max_depth': 8, 'subsample': 0.2}
# 训练过程分数及参数： 0.6024281667341158 {'colsample_bytree': 0.3, 'max_depth': 8, 'subsample': 0.3}
# 训练过程分数及参数： 0.6154593282072035 {'colsample_bytree': 0.3, 'max_depth': 8, 'subsample': 0.4}
# 训练过程分数及参数： 0.6242007284500202 {'colsample_bytree': 0.3, 'max_depth': 8, 'subsample': 0.5}
# 训练过程分数及参数： 0.624524484014569 {'colsample_bytree': 0.3, 'max_depth': 8, 'subsample': 0.6}
# 训练过程分数及参数： 0.6268717118575475 {'colsample_bytree': 0.3, 'max_depth': 8, 'subsample': 0.7}
# 训练过程分数及参数： 0.6318089842169163 {'colsample_bytree': 0.3, 'max_depth': 8, 'subsample': 0.8}
# 训练过程分数及参数： 0.6330230675839741 {'colsample_bytree': 0.3, 'max_depth': 8, 'subsample': 0.9}
# 训练过程分数及参数： 0.6337515176042088 {'colsample_bytree': 0.3, 'max_depth': 8, 'subsample': 1.0}
# 训练过程分数及参数： 0.5597733711048158 {'colsample_bytree': 0.3, 'max_depth': 9, 'subsample': 0.1}
# 训练过程分数及参数： 0.5896398219344394 {'colsample_bytree': 0.3, 'max_depth': 9, 'subsample': 0.2}
# 训练过程分数及参数： 0.6059894779441521 {'colsample_bytree': 0.3, 'max_depth': 9, 'subsample': 0.3}
# 训练过程分数及参数： 0.6131930392553622 {'colsample_bytree': 0.3, 'max_depth': 9, 'subsample': 0.4}
# 训练过程分数及参数： 0.6248482395791177 {'colsample_bytree': 0.3, 'max_depth': 9, 'subsample': 0.5}
# 训练过程分数及参数： 0.6258195062727641 {'colsample_bytree': 0.3, 'max_depth': 9, 'subsample': 0.6}
# 训练过程分数及参数： 0.624929178470255 {'colsample_bytree': 0.3, 'max_depth': 9, 'subsample': 0.7}
# 训练过程分数及参数： 0.6320518008903278 {'colsample_bytree': 0.3, 'max_depth': 9, 'subsample': 0.8}
# 训练过程分数及参数： 0.627033589639822 {'colsample_bytree': 0.3, 'max_depth': 9, 'subsample': 0.9}
# 训练过程分数及参数： 0.6284904896802914 {'colsample_bytree': 0.3, 'max_depth': 9, 'subsample': 1.0}
# 训练过程分数及参数： 0.5654390934844193 {'colsample_bytree': 0.3, 'max_depth': 10, 'subsample': 0.1}
# 训练过程分数及参数： 0.5872116552003238 {'colsample_bytree': 0.3, 'max_depth': 10, 'subsample': 0.2}
# 训练过程分数及参数： 0.6101173613921489 {'colsample_bytree': 0.3, 'max_depth': 10, 'subsample': 0.3}
# 训练过程分数及参数： 0.6152974504249291 {'colsample_bytree': 0.3, 'max_depth': 10, 'subsample': 0.4}
# 训练过程分数及参数： 0.6242007284500202 {'colsample_bytree': 0.3, 'max_depth': 10, 'subsample': 0.5}
# 训练过程分数及参数： 0.6278429785511939 {'colsample_bytree': 0.3, 'max_depth': 10, 'subsample': 0.6}
# 训练过程分数及参数： 0.6281667341157425 {'colsample_bytree': 0.3, 'max_depth': 10, 'subsample': 0.7}
# 训练过程分数及参数： 0.6318089842169162 {'colsample_bytree': 0.3, 'max_depth': 10, 'subsample': 0.8}
# 训练过程分数及参数： 0.633023067583974 {'colsample_bytree': 0.3, 'max_depth': 10, 'subsample': 0.9}
# 训练过程分数及参数： 0.6358559287737758 {'colsample_bytree': 0.3, 'max_depth': 10, 'subsample': 1.0}
# 训练过程分数及参数： 0.5643868878996358 {'colsample_bytree': 0.3, 'max_depth': 11, 'subsample': 0.1}
# 训练过程分数及参数： 0.5899635774989883 {'colsample_bytree': 0.3, 'max_depth': 11, 'subsample': 0.2}
# 训练过程分数及参数： 0.6046944556859571 {'colsample_bytree': 0.3, 'max_depth': 11, 'subsample': 0.3}
# 训练过程分数及参数： 0.6141643059490084 {'colsample_bytree': 0.3, 'max_depth': 11, 'subsample': 0.4}
# 训练过程分数及参数： 0.6250910562525294 {'colsample_bytree': 0.3, 'max_depth': 11, 'subsample': 0.5}
# 训练过程分数及参数： 0.6291380008093889 {'colsample_bytree': 0.3, 'max_depth': 11, 'subsample': 0.6}
# 训练过程分数及参数： 0.6233104006475111 {'colsample_bytree': 0.3, 'max_depth': 11, 'subsample': 0.7}
# 训练过程分数及参数： 0.6289761230271145 {'colsample_bytree': 0.3, 'max_depth': 11, 'subsample': 0.8}
# 训练过程分数及参数： 0.6293808174828005 {'colsample_bytree': 0.3, 'max_depth': 11, 'subsample': 0.9}
# 训练过程分数及参数： 0.6335896398219345 {'colsample_bytree': 0.3, 'max_depth': 11, 'subsample': 1.0}
# 训练过程分数及参数： 0.5592877377579928 {'colsample_bytree': 0.3, 'max_depth': 12, 'subsample': 0.1}
# 训练过程分数及参数： 0.5875354107648725 {'colsample_bytree': 0.3, 'max_depth': 12, 'subsample': 0.2}
# 训练过程分数及参数： 0.605422905706192 {'colsample_bytree': 0.3, 'max_depth': 12, 'subsample': 0.3}
# 训练过程分数及参数： 0.6108458114123836 {'colsample_bytree': 0.3, 'max_depth': 12, 'subsample': 0.4}
# 训练过程分数及参数： 0.6200728450020234 {'colsample_bytree': 0.3, 'max_depth': 12, 'subsample': 0.5}
# 训练过程分数及参数： 0.6240388506677459 {'colsample_bytree': 0.3, 'max_depth': 12, 'subsample': 0.6}
# 训练过程分数及参数： 0.6242816673411574 {'colsample_bytree': 0.3, 'max_depth': 12, 'subsample': 0.7}
# 训练过程分数及参数： 0.6318089842169162 {'colsample_bytree': 0.3, 'max_depth': 12, 'subsample': 0.8}
# 训练过程分数及参数： 0.632942128692837 {'colsample_bytree': 0.3, 'max_depth': 12, 'subsample': 0.9}
# 训练过程分数及参数： 0.6297855119384865 {'colsample_bytree': 0.3, 'max_depth': 12, 'subsample': 1.0}
# 训练过程分数及参数： 0.5648725212464589 {'colsample_bytree': 0.3, 'max_depth': 13, 'subsample': 0.1}
# 训练过程分数及参数： 0.5921489275596924 {'colsample_bytree': 0.3, 'max_depth': 13, 'subsample': 0.2}
# 训练过程分数及参数： 0.6074463779846215 {'colsample_bytree': 0.3, 'max_depth': 13, 'subsample': 0.3}
# 训练过程分数及参数： 0.6141643059490085 {'colsample_bytree': 0.3, 'max_depth': 13, 'subsample': 0.4}
# 训练过程分数及参数： 0.6227438284095508 {'colsample_bytree': 0.3, 'max_depth': 13, 'subsample': 0.5}
# 训练过程分数及参数： 0.6257385673816269 {'colsample_bytree': 0.3, 'max_depth': 13, 'subsample': 0.6}
# 训练过程分数及参数： 0.628328611898017 {'colsample_bytree': 0.3, 'max_depth': 13, 'subsample': 0.7}
# 训练过程分数及参数： 0.626628895184136 {'colsample_bytree': 0.3, 'max_depth': 13, 'subsample': 0.8}
# 训练过程分数及参数： 0.6305139619587212 {'colsample_bytree': 0.3, 'max_depth': 13, 'subsample': 0.9}
# 训练过程分数及参数： 0.6322136786726021 {'colsample_bytree': 0.3, 'max_depth': 13, 'subsample': 1.0}
# 训练过程分数及参数： 0.5643868878996356 {'colsample_bytree': 0.3, 'max_depth': 14, 'subsample': 0.1}
# 训练过程分数及参数： 0.5952246054229058 {'colsample_bytree': 0.3, 'max_depth': 14, 'subsample': 0.2}
# 训练过程分数及参数： 0.6065560501821126 {'colsample_bytree': 0.3, 'max_depth': 14, 'subsample': 0.3}
# 训练过程分数及参数： 0.6152974504249291 {'colsample_bytree': 0.3, 'max_depth': 14, 'subsample': 0.4}
# 训练过程分数及参数： 0.6197490894374746 {'colsample_bytree': 0.3, 'max_depth': 14, 'subsample': 0.5}
# 训练过程分数及参数： 0.6235532173209227 {'colsample_bytree': 0.3, 'max_depth': 14, 'subsample': 0.6}
# 训练过程分数及参数： 0.622824767300688 {'colsample_bytree': 0.3, 'max_depth': 14, 'subsample': 0.7}
# 训练过程分数及参数： 0.6296236341562121 {'colsample_bytree': 0.3, 'max_depth': 14, 'subsample': 0.8}
# 训练过程分数及参数： 0.6297855119384865 {'colsample_bytree': 0.3, 'max_depth': 14, 'subsample': 0.9}
# 训练过程分数及参数： 0.6350465398624039 {'colsample_bytree': 0.3, 'max_depth': 14, 'subsample': 1.0}
# 训练过程分数及参数： 0.5510319708619992 {'colsample_bytree': 0.3, 'max_depth': 15, 'subsample': 0.1}
# 训练过程分数及参数： 0.595791177660866 {'colsample_bytree': 0.3, 'max_depth': 15, 'subsample': 0.2}
# 训练过程分数及参数： 0.609307972480777 {'colsample_bytree': 0.3, 'max_depth': 15, 'subsample': 0.3}
# 训练过程分数及参数： 0.6132739781464993 {'colsample_bytree': 0.3, 'max_depth': 15, 'subsample': 0.4}
# 训练过程分数及参数： 0.6189397005261028 {'colsample_bytree': 0.3, 'max_depth': 15, 'subsample': 0.5}
# 训练过程分数及参数： 0.6264670174018616 {'colsample_bytree': 0.3, 'max_depth': 15, 'subsample': 0.6}
# 训练过程分数及参数： 0.6242007284500202 {'colsample_bytree': 0.3, 'max_depth': 15, 'subsample': 0.7}
# 训练过程分数及参数： 0.6309186564144071 {'colsample_bytree': 0.3, 'max_depth': 15, 'subsample': 0.8}
# 训练过程分数及参数： 0.6319708619991905 {'colsample_bytree': 0.3, 'max_depth': 15, 'subsample': 0.9}
# 训练过程分数及参数： 0.6335087009307973 {'colsample_bytree': 0.3, 'max_depth': 15, 'subsample': 1.0}
# 训练过程分数及参数： 0.6012140833670578 {'colsample_bytree': 0.4, 'max_depth': 3, 'subsample': 0.1}
# 训练过程分数及参数： 0.6218535006070416 {'colsample_bytree': 0.4, 'max_depth': 3, 'subsample': 0.2}
# 训练过程分数及参数： 0.6215297450424929 {'colsample_bytree': 0.4, 'max_depth': 3, 'subsample': 0.3}
# 训练过程分数及参数： 0.6318899231080535 {'colsample_bytree': 0.4, 'max_depth': 3, 'subsample': 0.4}
# 训练过程分数及参数： 0.6331849453662486 {'colsample_bytree': 0.4, 'max_depth': 3, 'subsample': 0.5}
# 训练过程分数及参数： 0.6326993120194253 {'colsample_bytree': 0.4, 'max_depth': 3, 'subsample': 0.6}
# 训练过程分数及参数： 0.6301092675030352 {'colsample_bytree': 0.4, 'max_depth': 3, 'subsample': 0.7}
# 训练过程分数及参数： 0.6368271954674221 {'colsample_bytree': 0.4, 'max_depth': 3, 'subsample': 0.8}
# 训练过程分数及参数： 0.6396600566572237 {'colsample_bytree': 0.4, 'max_depth': 3, 'subsample': 0.9}
# 训练过程分数及参数： 0.63804127883448 {'colsample_bytree': 0.4, 'max_depth': 3, 'subsample': 1.0}
# 训练过程分数及参数： 0.5800890327802509 {'colsample_bytree': 0.4, 'max_depth': 4, 'subsample': 0.1}
# 训练过程分数及参数： 0.6131930392553622 {'colsample_bytree': 0.4, 'max_depth': 4, 'subsample': 0.2}
# 训练过程分数及参数： 0.619910967219749 {'colsample_bytree': 0.4, 'max_depth': 4, 'subsample': 0.3}
# 训练过程分数及参数： 0.6229866450829624 {'colsample_bytree': 0.4, 'max_depth': 4, 'subsample': 0.4}
# 训练过程分数及参数： 0.6289761230271146 {'colsample_bytree': 0.4, 'max_depth': 4, 'subsample': 0.5}
# 训练过程分数及参数： 0.631728045325779 {'colsample_bytree': 0.4, 'max_depth': 4, 'subsample': 0.6}
# 训练过程分数及参数： 0.6303520841764467 {'colsample_bytree': 0.4, 'max_depth': 4, 'subsample': 0.7}
# 训练过程分数及参数： 0.6343180898421692 {'colsample_bytree': 0.4, 'max_depth': 4, 'subsample': 0.8}
# 训练过程分数及参数： 0.6324564953460137 {'colsample_bytree': 0.4, 'max_depth': 4, 'subsample': 0.9}
# 训练过程分数及参数： 0.6355321732092271 {'colsample_bytree': 0.4, 'max_depth': 4, 'subsample': 1.0}
# 训练过程分数及参数： 0.5688385269121812 {'colsample_bytree': 0.4, 'max_depth': 5, 'subsample': 0.1}
# 训练过程分数及参数： 0.6029138000809388 {'colsample_bytree': 0.4, 'max_depth': 5, 'subsample': 0.2}
# 训练过程分数及参数： 0.6087414002428166 {'colsample_bytree': 0.4, 'max_depth': 5, 'subsample': 0.3}
# 训练过程分数及参数： 0.6111695669769324 {'colsample_bytree': 0.4, 'max_depth': 5, 'subsample': 0.4}
# 训练过程分数及参数： 0.6273573452043707 {'colsample_bytree': 0.4, 'max_depth': 5, 'subsample': 0.5}
# 训练过程分数及参数： 0.6208822339133955 {'colsample_bytree': 0.4, 'max_depth': 5, 'subsample': 0.6}
# 训练过程分数及参数： 0.6303520841764467 {'colsample_bytree': 0.4, 'max_depth': 5, 'subsample': 0.7}
# 训练过程分数及参数： 0.6326993120194253 {'colsample_bytree': 0.4, 'max_depth': 5, 'subsample': 0.8}
# 训练过程分数及参数： 0.6338324564953459 {'colsample_bytree': 0.4, 'max_depth': 5, 'subsample': 0.9}
# 训练过程分数及参数： 0.6347227842978551 {'colsample_bytree': 0.4, 'max_depth': 5, 'subsample': 1.0}
# 训练过程分数及参数： 0.5670578713071632 {'colsample_bytree': 0.4, 'max_depth': 6, 'subsample': 0.1}
# 训练过程分数及参数： 0.594091460946985 {'colsample_bytree': 0.4, 'max_depth': 6, 'subsample': 0.2}
# 训练过程分数及参数： 0.605908539053015 {'colsample_bytree': 0.4, 'max_depth': 6, 'subsample': 0.3}
# 训练过程分数及参数： 0.6124645892351275 {'colsample_bytree': 0.4, 'max_depth': 6, 'subsample': 0.4}
# 训练过程分数及参数： 0.6178065560501821 {'colsample_bytree': 0.4, 'max_depth': 6, 'subsample': 0.5}
# 训练过程分数及参数： 0.6249291784702549 {'colsample_bytree': 0.4, 'max_depth': 6, 'subsample': 0.6}
# 训练过程分数及参数： 0.628328611898017 {'colsample_bytree': 0.4, 'max_depth': 6, 'subsample': 0.7}
# 训练过程分数及参数： 0.6249291784702549 {'colsample_bytree': 0.4, 'max_depth': 6, 'subsample': 0.8}
# 训练过程分数及参数： 0.6341562120598948 {'colsample_bytree': 0.4, 'max_depth': 6, 'subsample': 0.9}
# 训练过程分数及参数： 0.6301092675030352 {'colsample_bytree': 0.4, 'max_depth': 6, 'subsample': 1.0}
# 训练过程分数及参数： 0.5631728045325779 {'colsample_bytree': 0.4, 'max_depth': 7, 'subsample': 0.1}
# 训练过程分数及参数： 0.5978146499392958 {'colsample_bytree': 0.4, 'max_depth': 7, 'subsample': 0.2}
# 训练过程分数及参数： 0.6068798057466612 {'colsample_bytree': 0.4, 'max_depth': 7, 'subsample': 0.3}
# 训练过程分数及参数： 0.6151355726426548 {'colsample_bytree': 0.4, 'max_depth': 7, 'subsample': 0.4}
# 训练过程分数及参数： 0.621529745042493 {'colsample_bytree': 0.4, 'max_depth': 7, 'subsample': 0.5}
# 训练过程分数及参数： 0.6271145285309591 {'colsample_bytree': 0.4, 'max_depth': 7, 'subsample': 0.6}
# 训练过程分数及参数： 0.630028328611898 {'colsample_bytree': 0.4, 'max_depth': 7, 'subsample': 0.7}
# 训练过程分数及参数： 0.6348846620801295 {'colsample_bytree': 0.4, 'max_depth': 7, 'subsample': 0.8}
# 训练过程分数及参数： 0.632942128692837 {'colsample_bytree': 0.4, 'max_depth': 7, 'subsample': 0.9}
# 训练过程分数及参数： 0.6345609065155807 {'colsample_bytree': 0.4, 'max_depth': 7, 'subsample': 1.0}
# 训练过程分数及参数： 0.562849048968029 {'colsample_bytree': 0.4, 'max_depth': 8, 'subsample': 0.1}
# 训练过程分数及参数： 0.5875354107648725 {'colsample_bytree': 0.4, 'max_depth': 8, 'subsample': 0.2}
# 训练过程分数及参数： 0.60720356131121 {'colsample_bytree': 0.4, 'max_depth': 8, 'subsample': 0.3}
# 训练过程分数及参数： 0.6183731282881425 {'colsample_bytree': 0.4, 'max_depth': 8, 'subsample': 0.4}
# 训练过程分数及参数： 0.6284904896802914 {'colsample_bytree': 0.4, 'max_depth': 8, 'subsample': 0.5}
# 训练过程分数及参数： 0.6268717118575476 {'colsample_bytree': 0.4, 'max_depth': 8, 'subsample': 0.6}
# 训练过程分数及参数： 0.6300283286118981 {'colsample_bytree': 0.4, 'max_depth': 8, 'subsample': 0.7}
# 训练过程分数及参数： 0.6314852286523674 {'colsample_bytree': 0.4, 'max_depth': 8, 'subsample': 0.8}
# 训练过程分数及参数： 0.631728045325779 {'colsample_bytree': 0.4, 'max_depth': 8, 'subsample': 0.9}
# 训练过程分数及参数： 0.6325374342371509 {'colsample_bytree': 0.4, 'max_depth': 8, 'subsample': 1.0}
# 训练过程分数及参数： 0.5596924322136787 {'colsample_bytree': 0.4, 'max_depth': 9, 'subsample': 0.1}
# 训练过程分数及参数： 0.5904492108458114 {'colsample_bytree': 0.4, 'max_depth': 9, 'subsample': 0.2}
# 训练过程分数及参数： 0.6100364225010118 {'colsample_bytree': 0.4, 'max_depth': 9, 'subsample': 0.3}
# 训练过程分数及参数： 0.6131930392553622 {'colsample_bytree': 0.4, 'max_depth': 9, 'subsample': 0.4}
# 训练过程分数及参数： 0.6230675839740997 {'colsample_bytree': 0.4, 'max_depth': 9, 'subsample': 0.5}
# 训练过程分数及参数： 0.6284904896802914 {'colsample_bytree': 0.4, 'max_depth': 9, 'subsample': 0.6}
# 训练过程分数及参数： 0.6309995953055443 {'colsample_bytree': 0.4, 'max_depth': 9, 'subsample': 0.7}
# 训练过程分数及参数： 0.6288951841359773 {'colsample_bytree': 0.4, 'max_depth': 9, 'subsample': 0.8}
# 训练过程分数及参数： 0.6364225010117361 {'colsample_bytree': 0.4, 'max_depth': 9, 'subsample': 0.9}
# 训练过程分数及参数： 0.6348846620801295 {'colsample_bytree': 0.4, 'max_depth': 9, 'subsample': 1.0}
# 训练过程分数及参数： 0.5638203156616755 {'colsample_bytree': 0.4, 'max_depth': 10, 'subsample': 0.1}
# 训练过程分数及参数： 0.5957102387697288 {'colsample_bytree': 0.4, 'max_depth': 10, 'subsample': 0.2}
# 训练过程分数及参数： 0.6086604613516794 {'colsample_bytree': 0.4, 'max_depth': 10, 'subsample': 0.3}
# 训练过程分数及参数： 0.6174018615944961 {'colsample_bytree': 0.4, 'max_depth': 10, 'subsample': 0.4}
# 训练过程分数及参数： 0.6244435451234318 {'colsample_bytree': 0.4, 'max_depth': 10, 'subsample': 0.5}
# 训练过程分数及参数： 0.6248482395791177 {'colsample_bytree': 0.4, 'max_depth': 10, 'subsample': 0.6}
# 训练过程分数及参数： 0.628733306353703 {'colsample_bytree': 0.4, 'max_depth': 10, 'subsample': 0.7}
# 训练过程分数及参数： 0.6330230675839741 {'colsample_bytree': 0.4, 'max_depth': 10, 'subsample': 0.8}
# 训练过程分数及参数： 0.636341562120599 {'colsample_bytree': 0.4, 'max_depth': 10, 'subsample': 0.9}
# 训练过程分数及参数： 0.6331040064751112 {'colsample_bytree': 0.4, 'max_depth': 10, 'subsample': 1.0}
# 训练过程分数及参数： 0.5652772157021448 {'colsample_bytree': 0.4, 'max_depth': 11, 'subsample': 0.1}
# 训练过程分数及参数： 0.5998381222177256 {'colsample_bytree': 0.4, 'max_depth': 11, 'subsample': 0.2}
# 训练过程分数及参数： 0.6082557668959936 {'colsample_bytree': 0.4, 'max_depth': 11, 'subsample': 0.3}
# 训练过程分数及参数： 0.6166734115742614 {'colsample_bytree': 0.4, 'max_depth': 11, 'subsample': 0.4}
# 训练过程分数及参数： 0.6213678672602185 {'colsample_bytree': 0.4, 'max_depth': 11, 'subsample': 0.5}
# 训练过程分数及参数： 0.625010117361392 {'colsample_bytree': 0.4, 'max_depth': 11, 'subsample': 0.6}
# 训练过程分数及参数： 0.6335896398219344 {'colsample_bytree': 0.4, 'max_depth': 11, 'subsample': 0.7}
# 训练过程分数及参数： 0.6299473897207608 {'colsample_bytree': 0.4, 'max_depth': 11, 'subsample': 0.8}
# 训练过程分数及参数： 0.6325374342371509 {'colsample_bytree': 0.4, 'max_depth': 11, 'subsample': 0.9}
# 训练过程分数及参数： 0.6322136786726021 {'colsample_bytree': 0.4, 'max_depth': 11, 'subsample': 1.0}
# 训练过程分数及参数： 0.55475515985431 {'colsample_bytree': 0.4, 'max_depth': 12, 'subsample': 0.1}
# 训练过程分数及参数： 0.5980574666127073 {'colsample_bytree': 0.4, 'max_depth': 12, 'subsample': 0.2}
# 训练过程分数及参数： 0.6074463779846215 {'colsample_bytree': 0.4, 'max_depth': 12, 'subsample': 0.3}
# 训练过程分数及参数： 0.6127883447996763 {'colsample_bytree': 0.4, 'max_depth': 12, 'subsample': 0.4}
# 训练过程分数及参数： 0.6221772561715905 {'colsample_bytree': 0.4, 'max_depth': 12, 'subsample': 0.5}
# 训练过程分数及参数： 0.622015378389316 {'colsample_bytree': 0.4, 'max_depth': 12, 'subsample': 0.6}
# 训练过程分数及参数： 0.6288951841359772 {'colsample_bytree': 0.4, 'max_depth': 12, 'subsample': 0.7}
# 训练过程分数及参数： 0.6335896398219345 {'colsample_bytree': 0.4, 'max_depth': 12, 'subsample': 0.8}
# 训练过程分数及参数： 0.6343990287333063 {'colsample_bytree': 0.4, 'max_depth': 12, 'subsample': 0.9}
# 训练过程分数及参数： 0.630433023067584 {'colsample_bytree': 0.4, 'max_depth': 12, 'subsample': 1.0}
# 训练过程分数及参数： 0.5580736543909348 {'colsample_bytree': 0.4, 'max_depth': 13, 'subsample': 0.1}
# 训练过程分数及参数： 0.5946580331849454 {'colsample_bytree': 0.4, 'max_depth': 13, 'subsample': 0.2}
# 训练过程分数及参数： 0.61181707810603 {'colsample_bytree': 0.4, 'max_depth': 13, 'subsample': 0.3}
# 训练过程分数及参数： 0.6148118170781061 {'colsample_bytree': 0.4, 'max_depth': 13, 'subsample': 0.4}
# 训练过程分数及参数： 0.6277620396600566 {'colsample_bytree': 0.4, 'max_depth': 13, 'subsample': 0.5}
# 训练过程分数及参数： 0.628328611898017 {'colsample_bytree': 0.4, 'max_depth': 13, 'subsample': 0.6}
# 训练过程分数及参数： 0.6301902063941724 {'colsample_bytree': 0.4, 'max_depth': 13, 'subsample': 0.7}
# 训练过程分数及参数： 0.6317280453257791 {'colsample_bytree': 0.4, 'max_depth': 13, 'subsample': 0.8}
# 训练过程分数及参数： 0.632537434237151 {'colsample_bytree': 0.4, 'max_depth': 13, 'subsample': 0.9}
# 训练过程分数及参数： 0.6288951841359773 {'colsample_bytree': 0.4, 'max_depth': 13, 'subsample': 1.0}
# 训练过程分数及参数： 0.561068393363011 {'colsample_bytree': 0.4, 'max_depth': 14, 'subsample': 0.1}
# 训练过程分数及参数： 0.6010522055847836 {'colsample_bytree': 0.4, 'max_depth': 14, 'subsample': 0.2}
# 训练过程分数及参数： 0.6102792391744234 {'colsample_bytree': 0.4, 'max_depth': 14, 'subsample': 0.3}
# 训练过程分数及参数： 0.612221772561716 {'colsample_bytree': 0.4, 'max_depth': 14, 'subsample': 0.4}
# 训练过程分数及参数： 0.6247673006879806 {'colsample_bytree': 0.4, 'max_depth': 14, 'subsample': 0.5}
# 训练过程分数及参数： 0.6281667341157426 {'colsample_bytree': 0.4, 'max_depth': 14, 'subsample': 0.6}
# 训练过程分数及参数： 0.633832456495346 {'colsample_bytree': 0.4, 'max_depth': 14, 'subsample': 0.7}
# 训练过程分数及参数： 0.6322136786726023 {'colsample_bytree': 0.4, 'max_depth': 14, 'subsample': 0.8}
# 训练过程分数及参数： 0.6328611898016997 {'colsample_bytree': 0.4, 'max_depth': 14, 'subsample': 0.9}
# 训练过程分数及参数： 0.6310805341966815 {'colsample_bytree': 0.4, 'max_depth': 14, 'subsample': 1.0}
# 训练过程分数及参数： 0.5656819101578309 {'colsample_bytree': 0.4, 'max_depth': 15, 'subsample': 0.1}
# 训练过程分数及参数： 0.5935248887090246 {'colsample_bytree': 0.4, 'max_depth': 15, 'subsample': 0.2}
# 训练过程分数及参数： 0.6119789558883044 {'colsample_bytree': 0.4, 'max_depth': 15, 'subsample': 0.3}
# 训练过程分数及参数： 0.6160259004451639 {'colsample_bytree': 0.4, 'max_depth': 15, 'subsample': 0.4}
# 训练过程分数及参数： 0.6178065560501821 {'colsample_bytree': 0.4, 'max_depth': 15, 'subsample': 0.5}
# 训练过程分数及参数： 0.6252529340348036 {'colsample_bytree': 0.4, 'max_depth': 15, 'subsample': 0.6}
# 训练过程分数及参数： 0.6318899231080535 {'colsample_bytree': 0.4, 'max_depth': 15, 'subsample': 0.7}
# 训练过程分数及参数： 0.6336705787130716 {'colsample_bytree': 0.4, 'max_depth': 15, 'subsample': 0.8}
# 训练过程分数及参数： 0.6344799676244436 {'colsample_bytree': 0.4, 'max_depth': 15, 'subsample': 0.9}
# 训练过程分数及参数： 0.634641845406718 {'colsample_bytree': 0.4, 'max_depth': 15, 'subsample': 1.0}
# 训练过程分数及参数： 0.6033184945366248 {'colsample_bytree': 0.5, 'max_depth': 3, 'subsample': 0.1}
# 训练过程分数及参数： 0.6165115337919871 {'colsample_bytree': 0.5, 'max_depth': 3, 'subsample': 0.2}
# 训练过程分数及参数： 0.6325374342371509 {'colsample_bytree': 0.5, 'max_depth': 3, 'subsample': 0.3}
# 训练过程分数及参数： 0.6318899231080534 {'colsample_bytree': 0.5, 'max_depth': 3, 'subsample': 0.4}
# 训练过程分数及参数： 0.630028328611898 {'colsample_bytree': 0.5, 'max_depth': 3, 'subsample': 0.5}
# 训练过程分数及参数： 0.6335896398219345 {'colsample_bytree': 0.5, 'max_depth': 3, 'subsample': 0.6}
# 训练过程分数及参数： 0.6335896398219345 {'colsample_bytree': 0.5, 'max_depth': 3, 'subsample': 0.7}
# 训练过程分数及参数： 0.6369081343585592 {'colsample_bytree': 0.5, 'max_depth': 3, 'subsample': 0.8}
# 训练过程分数及参数： 0.6391744233104008 {'colsample_bytree': 0.5, 'max_depth': 3, 'subsample': 0.9}
# 训练过程分数及参数： 0.6382031566167543 {'colsample_bytree': 0.5, 'max_depth': 3, 'subsample': 1.0}
# 训练过程分数及参数： 0.5767705382436261 {'colsample_bytree': 0.5, 'max_depth': 4, 'subsample': 0.1}
# ...
# 训练过程分数及参数： 0.6355321732092271 {'colsample_bytree': 0.9, 'max_depth': 11, 'subsample': 0.6}
# 训练过程分数及参数： 0.6310805341966814 {'colsample_bytree': 0.9, 'max_depth': 11, 'subsample': 0.7}
# 训练过程分数及参数： 0.634237150951032 {'colsample_bytree': 0.9, 'max_depth': 11, 'subsample': 0.8}
# 训练过程分数及参数： 0.6370700121408337 {'colsample_bytree': 0.9, 'max_depth': 11, 'subsample': 0.9}
# 训练过程分数及参数： 0.6308377175232699 {'colsample_bytree': 0.9, 'max_depth': 11, 'subsample': 1.0}
# 训练过程分数及参数： 0.5634965600971267 {'colsample_bytree': 0.9, 'max_depth': 12, 'subsample': 0.1}
# 训练过程分数及参数： 0.5933630109267503 {'colsample_bytree': 0.9, 'max_depth': 12, 'subsample': 0.2}
# 训练过程分数及参数： 0.6172399838122218 {'colsample_bytree': 0.9, 'max_depth': 12, 'subsample': 0.3}
# 训练过程分数及参数： 0.6229866450829624 {'colsample_bytree': 0.9, 'max_depth': 12, 'subsample': 0.4}
# 训练过程分数及参数： 0.6265479562929988 {'colsample_bytree': 0.9, 'max_depth': 12, 'subsample': 0.5}
# 训练过程分数及参数： 0.6280048563334683 {'colsample_bytree': 0.9, 'max_depth': 12, 'subsample': 0.6}
# 训练过程分数及参数： 0.635936867664913 {'colsample_bytree': 0.9, 'max_depth': 12, 'subsample': 0.7}
# 训练过程分数及参数： 0.6387697288547146 {'colsample_bytree': 0.9, 'max_depth': 12, 'subsample': 0.8}
# 训练过程分数及参数： 0.6348037231889923 {'colsample_bytree': 0.9, 'max_depth': 12, 'subsample': 0.9}
# 训练过程分数及参数： 0.634237150951032 {'colsample_bytree': 0.9, 'max_depth': 12, 'subsample': 1.0}
# 训练过程分数及参数： 0.5728854714690409 {'colsample_bytree': 0.9, 'max_depth': 13, 'subsample': 0.1}
# 训练过程分数及参数： 0.59740995548361 {'colsample_bytree': 0.9, 'max_depth': 13, 'subsample': 0.2}
# 训练过程分数及参数： 0.6113314447592069 {'colsample_bytree': 0.9, 'max_depth': 13, 'subsample': 0.3}
# 训练过程分数及参数： 0.6218535006070416 {'colsample_bytree': 0.9, 'max_depth': 13, 'subsample': 0.4}
# 训练过程分数及参数： 0.624119789558883 {'colsample_bytree': 0.9, 'max_depth': 13, 'subsample': 0.5}
# 训练过程分数及参数： 0.6282476730068798 {'colsample_bytree': 0.9, 'max_depth': 13, 'subsample': 0.6}
# 训练过程分数及参数： 0.6299473897207608 {'colsample_bytree': 0.9, 'max_depth': 13, 'subsample': 0.7}
# 训练过程分数及参数： 0.6305139619587212 {'colsample_bytree': 0.9, 'max_depth': 13, 'subsample': 0.8}
# 训练过程分数及参数： 0.6328611898016997 {'colsample_bytree': 0.9, 'max_depth': 13, 'subsample': 0.9}
# 训练过程分数及参数： 0.6294617563739375 {'colsample_bytree': 0.9, 'max_depth': 13, 'subsample': 1.0}
# 训练过程分数及参数： 0.5656009712666937 {'colsample_bytree': 0.9, 'max_depth': 14, 'subsample': 0.1}
# 训练过程分数及参数： 0.5980574666127074 {'colsample_bytree': 0.9, 'max_depth': 14, 'subsample': 0.2}
# 训练过程分数及参数： 0.6128692836908134 {'colsample_bytree': 0.9, 'max_depth': 14, 'subsample': 0.3}
# 训练过程分数及参数： 0.6258195062727641 {'colsample_bytree': 0.9, 'max_depth': 14, 'subsample': 0.4}
# 训练过程分数及参数： 0.6256576284904898 {'colsample_bytree': 0.9, 'max_depth': 14, 'subsample': 0.5}
# 训练过程分数及参数： 0.6314852286523674 {'colsample_bytree': 0.9, 'max_depth': 14, 'subsample': 0.6}
# 训练过程分数及参数： 0.6343180898421691 {'colsample_bytree': 0.9, 'max_depth': 14, 'subsample': 0.7}
# 训练过程分数及参数： 0.6337515176042088 {'colsample_bytree': 0.9, 'max_depth': 14, 'subsample': 0.8}
# 训练过程分数及参数： 0.6332658842573856 {'colsample_bytree': 0.9, 'max_depth': 14, 'subsample': 0.9}
# 训练过程分数及参数： 0.6297855119384865 {'colsample_bytree': 0.9, 'max_depth': 14, 'subsample': 1.0}
# 训练过程分数及参数： 0.5667341157426143 {'colsample_bytree': 0.9, 'max_depth': 15, 'subsample': 0.1}
# 训练过程分数及参数： 0.6011331444759207 {'colsample_bytree': 0.9, 'max_depth': 15, 'subsample': 0.2}
# 训练过程分数及参数： 0.6063941723998382 {'colsample_bytree': 0.9, 'max_depth': 15, 'subsample': 0.3}
# 训练过程分数及参数： 0.6268717118575475 {'colsample_bytree': 0.9, 'max_depth': 15, 'subsample': 0.4}
# 训练过程分数及参数： 0.628328611898017 {'colsample_bytree': 0.9, 'max_depth': 15, 'subsample': 0.5}
# 训练过程分数及参数： 0.6272764063132334 {'colsample_bytree': 0.9, 'max_depth': 15, 'subsample': 0.6}
# 训练过程分数及参数： 0.6314852286523674 {'colsample_bytree': 0.9, 'max_depth': 15, 'subsample': 0.7}
# 训练过程分数及参数： 0.6330230675839741 {'colsample_bytree': 0.9, 'max_depth': 15, 'subsample': 0.8}
# 训练过程分数及参数： 0.6326993120194253 {'colsample_bytree': 0.9, 'max_depth': 15, 'subsample': 0.9}
# 训练过程分数及参数： 0.6301902063941723 {'colsample_bytree': 0.9, 'max_depth': 15, 'subsample': 1.0}
# 训练过程分数及参数： 0.5898826386078511 {'colsample_bytree': 1.0, 'max_depth': 3, 'subsample': 0.1}
# 训练过程分数及参数： 0.6166734115742615 {'colsample_bytree': 1.0, 'max_depth': 3, 'subsample': 0.2}
# 训练过程分数及参数： 0.6252529340348036 {'colsample_bytree': 1.0, 'max_depth': 3, 'subsample': 0.3}
# 训练过程分数及参数： 0.630433023067584 {'colsample_bytree': 1.0, 'max_depth': 3, 'subsample': 0.4}
# 训练过程分数及参数： 0.6354512343180898 {'colsample_bytree': 1.0, 'max_depth': 3, 'subsample': 0.5}
# 训练过程分数及参数： 0.6372318899231081 {'colsample_bytree': 1.0, 'max_depth': 3, 'subsample': 0.6}
# 训练过程分数及参数： 0.6356131121003643 {'colsample_bytree': 1.0, 'max_depth': 3, 'subsample': 0.7}
# 训练过程分数及参数： 0.6379603399433428 {'colsample_bytree': 1.0, 'max_depth': 3, 'subsample': 0.8}
# 训练过程分数及参数： 0.6382840955078916 {'colsample_bytree': 1.0, 'max_depth': 3, 'subsample': 0.9}
# 训练过程分数及参数： 0.637150951031971 {'colsample_bytree': 1.0, 'max_depth': 3, 'subsample': 1.0}
# 训练过程分数及参数： 0.5779036827195467 {'colsample_bytree': 1.0, 'max_depth': 4, 'subsample': 0.1}
# 训练过程分数及参数： 0.6038850667745852 {'colsample_bytree': 1.0, 'max_depth': 4, 'subsample': 0.2}
# 训练过程分数及参数： 0.6163496560097126 {'colsample_bytree': 1.0, 'max_depth': 4, 'subsample': 0.3}
# 训练过程分数及参数： 0.6226628895184134 {'colsample_bytree': 1.0, 'max_depth': 4, 'subsample': 0.4}
# 训练过程分数及参数： 0.628328611898017 {'colsample_bytree': 1.0, 'max_depth': 4, 'subsample': 0.5}
# 训练过程分数及参数： 0.6326993120194253 {'colsample_bytree': 1.0, 'max_depth': 4, 'subsample': 0.6}
# 训练过程分数及参数： 0.6326183731282882 {'colsample_bytree': 1.0, 'max_depth': 4, 'subsample': 0.7}
# 训练过程分数及参数： 0.634641845406718 {'colsample_bytree': 1.0, 'max_depth': 4, 'subsample': 0.8}
# 训练过程分数及参数： 0.632942128692837 {'colsample_bytree': 1.0, 'max_depth': 4, 'subsample': 0.9}
# 训练过程分数及参数： 0.6356940509915014 {'colsample_bytree': 1.0, 'max_depth': 4, 'subsample': 1.0}
# 训练过程分数及参数： 0.5744233104006475 {'colsample_bytree': 1.0, 'max_depth': 5, 'subsample': 0.1}
# 训练过程分数及参数： 0.5993524888709024 {'colsample_bytree': 1.0, 'max_depth': 5, 'subsample': 0.2}
# 训练过程分数及参数： 0.6130311614730879 {'colsample_bytree': 1.0, 'max_depth': 5, 'subsample': 0.3}
# 训练过程分数及参数： 0.617806556050182 {'colsample_bytree': 1.0, 'max_depth': 5, 'subsample': 0.4}
# 训练过程分数及参数： 0.6239579117766085 {'colsample_bytree': 1.0, 'max_depth': 5, 'subsample': 0.5}
# 训练过程分数及参数： 0.6285714285714286 {'colsample_bytree': 1.0, 'max_depth': 5, 'subsample': 0.6}
# 训练过程分数及参数： 0.6303520841764468 {'colsample_bytree': 1.0, 'max_depth': 5, 'subsample': 0.7}
# 训练过程分数及参数： 0.6301092675030352 {'colsample_bytree': 1.0, 'max_depth': 5, 'subsample': 0.8}
# 训练过程分数及参数： 0.6297045730473492 {'colsample_bytree': 1.0, 'max_depth': 5, 'subsample': 0.9}
# 训练过程分数及参数： 0.6299473897207608 {'colsample_bytree': 1.0, 'max_depth': 5, 'subsample': 1.0}
# 训练过程分数及参数： 0.558478348846621 {'colsample_bytree': 1.0, 'max_depth': 6, 'subsample': 0.1}
# 训练过程分数及参数： 0.5950627276406313 {'colsample_bytree': 1.0, 'max_depth': 6, 'subsample': 0.2}
# 训练过程分数及参数： 0.6097936058276001 {'colsample_bytree': 1.0, 'max_depth': 6, 'subsample': 0.3}
# 训练过程分数及参数： 0.6185350060704169 {'colsample_bytree': 1.0, 'max_depth': 6, 'subsample': 0.4}
# 训练过程分数及参数： 0.6242816673411574 {'colsample_bytree': 1.0, 'max_depth': 6, 'subsample': 0.5}
# 训练过程分数及参数： 0.6282476730068798 {'colsample_bytree': 1.0, 'max_depth': 6, 'subsample': 0.6}
# 训练过程分数及参数： 0.6343180898421691 {'colsample_bytree': 1.0, 'max_depth': 6, 'subsample': 0.7}
# 训练过程分数及参数： 0.6293808174828005 {'colsample_bytree': 1.0, 'max_depth': 6, 'subsample': 0.8}
# 训练过程分数及参数： 0.6316471064346418 {'colsample_bytree': 1.0, 'max_depth': 6, 'subsample': 0.9}
# 训练过程分数及参数： 0.6323755564548765 {'colsample_bytree': 1.0, 'max_depth': 6, 'subsample': 1.0}
# 训练过程分数及参数： 0.5677863213273978 {'colsample_bytree': 1.0, 'max_depth': 7, 'subsample': 0.1}
# 训练过程分数及参数： 0.5935248887090248 {'colsample_bytree': 1.0, 'max_depth': 7, 'subsample': 0.2}
# 训练过程分数及参数： 0.6039660056657224 {'colsample_bytree': 1.0, 'max_depth': 7, 'subsample': 0.3}
# 训练过程分数及参数： 0.6199919061108863 {'colsample_bytree': 1.0, 'max_depth': 7, 'subsample': 0.4}
# 训练过程分数及参数： 0.6232294617563741 {'colsample_bytree': 1.0, 'max_depth': 7, 'subsample': 0.5}
# 训练过程分数及参数： 0.628733306353703 {'colsample_bytree': 1.0, 'max_depth': 7, 'subsample': 0.6}
# 训练过程分数及参数： 0.6312424119789559 {'colsample_bytree': 1.0, 'max_depth': 7, 'subsample': 0.7}
# 训练过程分数及参数： 0.632942128692837 {'colsample_bytree': 1.0, 'max_depth': 7, 'subsample': 0.8}
# 训练过程分数及参数： 0.6373937677053825 {'colsample_bytree': 1.0, 'max_depth': 7, 'subsample': 0.9}
# 训练过程分数及参数： 0.6331849453662484 {'colsample_bytree': 1.0, 'max_depth': 7, 'subsample': 1.0}
# 训练过程分数及参数： 0.5714285714285714 {'colsample_bytree': 1.0, 'max_depth': 8, 'subsample': 0.1}
# 训练过程分数及参数： 0.5932011331444759 {'colsample_bytree': 1.0, 'max_depth': 8, 'subsample': 0.2}
# 训练过程分数及参数： 0.6160259004451639 {'colsample_bytree': 1.0, 'max_depth': 8, 'subsample': 0.3}
# 训练过程分数及参数： 0.6229057061918252 {'colsample_bytree': 1.0, 'max_depth': 8, 'subsample': 0.4}
# 训练过程分数及参数： 0.621934439498179 {'colsample_bytree': 1.0, 'max_depth': 8, 'subsample': 0.5}
# 训练过程分数及参数： 0.6299473897207608 {'colsample_bytree': 1.0, 'max_depth': 8, 'subsample': 0.6}
# 训练过程分数及参数： 0.6350465398624039 {'colsample_bytree': 1.0, 'max_depth': 8, 'subsample': 0.7}
# 训练过程分数及参数： 0.6360987454471874 {'colsample_bytree': 1.0, 'max_depth': 8, 'subsample': 0.8}
# 训练过程分数及参数： 0.6337515176042089 {'colsample_bytree': 1.0, 'max_depth': 8, 'subsample': 0.9}
# 训练过程分数及参数： 0.6345609065155806 {'colsample_bytree': 1.0, 'max_depth': 8, 'subsample': 1.0}
# 训练过程分数及参数： 0.5648725212464589 {'colsample_bytree': 1.0, 'max_depth': 9, 'subsample': 0.1}
# 训练过程分数及参数： 0.601214083367058 {'colsample_bytree': 1.0, 'max_depth': 9, 'subsample': 0.2}
# 训练过程分数及参数： 0.6135977337110482 {'colsample_bytree': 1.0, 'max_depth': 9, 'subsample': 0.3}
# 训练过程分数及参数： 0.6176446782679077 {'colsample_bytree': 1.0, 'max_depth': 9, 'subsample': 0.4}
# 训练过程分数及参数： 0.6246863617968434 {'colsample_bytree': 1.0, 'max_depth': 9, 'subsample': 0.5}
# 训练过程分数及参数： 0.6293808174828005 {'colsample_bytree': 1.0, 'max_depth': 9, 'subsample': 0.6}
# 训练过程分数及参数： 0.630028328611898 {'colsample_bytree': 1.0, 'max_depth': 9, 'subsample': 0.7}
# 训练过程分数及参数： 0.6358559287737757 {'colsample_bytree': 1.0, 'max_depth': 9, 'subsample': 0.8}
# 训练过程分数及参数： 0.6340752731687576 {'colsample_bytree': 1.0, 'max_depth': 9, 'subsample': 0.9}
# 训练过程分数及参数： 0.6382840955078916 {'colsample_bytree': 1.0, 'max_depth': 9, 'subsample': 1.0}
# 训练过程分数及参数： 0.5677863213273978 {'colsample_bytree': 1.0, 'max_depth': 10, 'subsample': 0.1}
# 训练过程分数及参数： 0.5953055443140429 {'colsample_bytree': 1.0, 'max_depth': 10, 'subsample': 0.2}
# 训练过程分数及参数： 0.612221772561716 {'colsample_bytree': 1.0, 'max_depth': 10, 'subsample': 0.3}
# 训练过程分数及参数： 0.6264670174018616 {'colsample_bytree': 1.0, 'max_depth': 10, 'subsample': 0.4}
# 训练过程分数及参数： 0.6276001618777822 {'colsample_bytree': 1.0, 'max_depth': 10, 'subsample': 0.5}
# 训练过程分数及参数： 0.6277620396600567 {'colsample_bytree': 1.0, 'max_depth': 10, 'subsample': 0.6}
# 训练过程分数及参数： 0.6292998785916633 {'colsample_bytree': 1.0, 'max_depth': 10, 'subsample': 0.7}
# 训练过程分数及参数： 0.6356940509915014 {'colsample_bytree': 1.0, 'max_depth': 10, 'subsample': 0.8}
# 训练过程分数及参数： 0.6358559287737758 {'colsample_bytree': 1.0, 'max_depth': 10, 'subsample': 0.9}
# 训练过程分数及参数： 0.6307567786321328 {'colsample_bytree': 1.0, 'max_depth': 10, 'subsample': 1.0}
# 训练过程分数及参数： 0.5641440712262241 {'colsample_bytree': 1.0, 'max_depth': 11, 'subsample': 0.1}
# 训练过程分数及参数： 0.5975718332658843 {'colsample_bytree': 1.0, 'max_depth': 11, 'subsample': 0.2}
# 训练过程分数及参数： 0.613112100364225 {'colsample_bytree': 1.0, 'max_depth': 11, 'subsample': 0.3}
# 训练过程分数及参数： 0.6289761230271145 {'colsample_bytree': 1.0, 'max_depth': 11, 'subsample': 0.4}
# 训练过程分数及参数： 0.6295426952650749 {'colsample_bytree': 1.0, 'max_depth': 11, 'subsample': 0.5}
# 训练过程分数及参数： 0.6301092675030352 {'colsample_bytree': 1.0, 'max_depth': 11, 'subsample': 0.6}
# 训练过程分数及参数： 0.6326993120194253 {'colsample_bytree': 1.0, 'max_depth': 11, 'subsample': 0.7}
# 训练过程分数及参数： 0.6324564953460137 {'colsample_bytree': 1.0, 'max_depth': 11, 'subsample': 0.8}
# 训练过程分数及参数： 0.6362606232294616 {'colsample_bytree': 1.0, 'max_depth': 11, 'subsample': 0.9}
# 训练过程分数及参数： 0.6322946175637394 {'colsample_bytree': 1.0, 'max_depth': 11, 'subsample': 1.0}
# 训练过程分数及参数： 0.5624443545123432 {'colsample_bytree': 1.0, 'max_depth': 12, 'subsample': 0.1}
# 训练过程分数及参数： 0.597895588830433 {'colsample_bytree': 1.0, 'max_depth': 12, 'subsample': 0.2}
# 训练过程分数及参数： 0.6115742614326184 {'colsample_bytree': 1.0, 'max_depth': 12, 'subsample': 0.3}
# 训练过程分数及参数： 0.6212869283690814 {'colsample_bytree': 1.0, 'max_depth': 12, 'subsample': 0.4}
# 训练过程分数及参数： 0.6292189397005261 {'colsample_bytree': 1.0, 'max_depth': 12, 'subsample': 0.5}
# 训练过程分数及参数： 0.6377984621610684 {'colsample_bytree': 1.0, 'max_depth': 12, 'subsample': 0.6}
# 训练过程分数及参数： 0.6306758397409956 {'colsample_bytree': 1.0, 'max_depth': 12, 'subsample': 0.7}
# 训练过程分数及参数： 0.6356940509915014 {'colsample_bytree': 1.0, 'max_depth': 12, 'subsample': 0.8}
# 训练过程分数及参数： 0.6288142452448401 {'colsample_bytree': 1.0, 'max_depth': 12, 'subsample': 0.9}
# 训练过程分数及参数： 0.633832456495346 {'colsample_bytree': 1.0, 'max_depth': 12, 'subsample': 1.0}
# 训练过程分数及参数： 0.5658437879401053 {'colsample_bytree': 1.0, 'max_depth': 13, 'subsample': 0.1}
# 训练过程分数及参数： 0.5972480777013355 {'colsample_bytree': 1.0, 'max_depth': 13, 'subsample': 0.2}
# 训练过程分数及参数： 0.6130311614730878 {'colsample_bytree': 1.0, 'max_depth': 13, 'subsample': 0.3}
# 训练过程分数及参数： 0.6225010117361391 {'colsample_bytree': 1.0, 'max_depth': 13, 'subsample': 0.4}
# 训练过程分数及参数： 0.6276811007689195 {'colsample_bytree': 1.0, 'max_depth': 13, 'subsample': 0.5}
# 训练过程分数及参数： 0.6275192229866452 {'colsample_bytree': 1.0, 'max_depth': 13, 'subsample': 0.6}
# 训练过程分数及参数： 0.6326993120194253 {'colsample_bytree': 1.0, 'max_depth': 13, 'subsample': 0.7}
# 训练过程分数及参数： 0.6336705787130716 {'colsample_bytree': 1.0, 'max_depth': 13, 'subsample': 0.8}
# 训练过程分数及参数： 0.6309995953055443 {'colsample_bytree': 1.0, 'max_depth': 13, 'subsample': 0.9}
# 训练过程分数及参数： 0.6288142452448401 {'colsample_bytree': 1.0, 'max_depth': 13, 'subsample': 1.0}
# 训练过程分数及参数： 0.5629299878591663 {'colsample_bytree': 1.0, 'max_depth': 14, 'subsample': 0.1}
# 训练过程分数及参数： 0.6007284500202348 {'colsample_bytree': 1.0, 'max_depth': 14, 'subsample': 0.2}
# 训练过程分数及参数： 0.6154593282072035 {'colsample_bytree': 1.0, 'max_depth': 14, 'subsample': 0.3}
# 训练过程分数及参数： 0.6247673006879805 {'colsample_bytree': 1.0, 'max_depth': 14, 'subsample': 0.4}
# 训练过程分数及参数： 0.6267098340752731 {'colsample_bytree': 1.0, 'max_depth': 14, 'subsample': 0.5}
# 训练过程分数及参数： 0.6344799676244436 {'colsample_bytree': 1.0, 'max_depth': 14, 'subsample': 0.6}
# 训练过程分数及参数： 0.6261432618373128 {'colsample_bytree': 1.0, 'max_depth': 14, 'subsample': 0.7}
# 训练过程分数及参数： 0.6335896398219345 {'colsample_bytree': 1.0, 'max_depth': 14, 'subsample': 0.8}
# 训练过程分数及参数： 0.6305139619587212 {'colsample_bytree': 1.0, 'max_depth': 14, 'subsample': 0.9}
# 训练过程分数及参数： 0.6336705787130716 {'colsample_bytree': 1.0, 'max_depth': 14, 'subsample': 1.0}
# 训练过程分数及参数： 0.5660056657223795 {'colsample_bytree': 1.0, 'max_depth': 15, 'subsample': 0.1}
# 训练过程分数及参数： 0.5944152165115337 {'colsample_bytree': 1.0, 'max_depth': 15, 'subsample': 0.2}
# 训练过程分数及参数： 0.6135977337110482 {'colsample_bytree': 1.0, 'max_depth': 15, 'subsample': 0.3}
# 训练过程分数及参数： 0.6202347227842978 {'colsample_bytree': 1.0, 'max_depth': 15, 'subsample': 0.4}
# 训练过程分数及参数： 0.6247673006879806 {'colsample_bytree': 1.0, 'max_depth': 15, 'subsample': 0.5}
# 训练过程分数及参数： 0.627438284095508 {'colsample_bytree': 1.0, 'max_depth': 15, 'subsample': 0.6}
# 训练过程分数及参数： 0.6289761230271145 {'colsample_bytree': 1.0, 'max_depth': 15, 'subsample': 0.7}
# 训练过程分数及参数： 0.6362606232294619 {'colsample_bytree': 1.0, 'max_depth': 15, 'subsample': 0.8}
# 训练过程分数及参数： 0.6318899231080535 {'colsample_bytree': 1.0, 'max_depth': 15, 'subsample': 0.9}
# 训练过程分数及参数： 0.6310805341966815 {'colsample_bytree': 1.0, 'max_depth': 15, 'subsample': 1.0}
#
# 最好的分数以及参数： 0.6399028733306353 {'colsample_bytree': 0.7, 'max_depth': 8, 'subsample': 0.8}

# %%
model_xgb = xgb.XGBClassifier(
#         num_class=num_class,
    booster="gbtree",  # # 基分类器；gbtree 树模型，gbliner 线性模型
    objective="multi:softprob",  # 目标函数；multi：softprob 返回概率，multi：softmax multi：softmax
    max_depth=8,  # 最大树深度
    min_child_weight=1,  # 最小叶子节点样本权重和
    subsample=0.8,  # 随机选择训练实例的子样本比率
    colsample_bytree=0.7,  # 构造每个树时列的子采样率
)
model_xgb.fit(X_tr,Y_tr,eval_metric="merror")
Model_ACC(model_xgb,X_tr,X_te,Y_tr,Y_te)
# Out:
# 训练集准确度: 1.000000, 测试集准确度: 0.623489

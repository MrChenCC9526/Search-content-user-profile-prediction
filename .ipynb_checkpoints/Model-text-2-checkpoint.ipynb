# %%
import pandas as pd
import sys
import os
import pickle
import config # 自定义配置文件
import numpy as np

# %% [markdown]
# ### 数据载入

# %% [markdown]
# #### DF数据

# %%
data = pd.read_csv(config.AF_Data_path + "AFAfter.csv")
col_list = ["Education","age","gender"]

# %% [markdown]
# #### 词向量数据

# %%
def load_pkl(pkl_name):
    # 加载文件
    pkl_file = open(config.WV_Data_path + pkl_name + '.feat','rb')
    load_data = pickle.load(pkl_file)
    pkl_file.close()
    return load_data

# %%
# 加载TFIDF词向量数据
TFIDF_sp = load_pkl("TFIDF_sp")
TFIDF_HW_sp = load_pkl("TFIDF_HW_sp")

print("TFIDF_sp\t",TFIDF_sp.shape)
print("TFIDF_HW_sp\t",TFIDF_HW_sp.shape)
# Out:
# TFIDF_sp	 (17651, 336460)
# TFIDF_HW_sp	 (17651, 12699)

# %%
# 加载W2V词向量数据
W2V_X_sp = load_pkl("W2V_X_sp")
W2V_HW_sp = load_pkl("W2V_HW_sp")

print("W2V_X_sp\t",W2V_X_sp.shape)
print("W2V_HW_sp\t",W2V_HW_sp.shape)
# Out:
# W2V_X_sp	 (17651, 100)
# W2V_HW_sp	 (17651, 100)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.python.keras.utils import np_utils

from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
# 传入特征与目标列进行划分训练集与测试集
def get_train_test(X,Y):
    X_train, X_test,  Y_train, Y_test = train_test_split(X, # 特征
                                                         Y, # 目标
                                                         test_size = 0.3, # 测试集大小为30%
                                                         random_state = 10)
    return X_train, X_test,  Y_train, Y_test

# %%
def SNN_Model(X_tr, X_te, Y_tr, Y_te):

    num_class = len(Y_tr.value_counts()) # 计算目标列类别数量
    input_num = X_tr.shape[1] # 输入层尺寸
    
    # One-Hot编码
    y_train = np_utils.to_categorical(Y_tr)
    y_test = np_utils.to_categorical(Y_te)
    
    model = tf.keras.Sequential() # 实例化
    # 输入层
    model.add(Dense(300,input_shape=(input_num,))) # 全连接层
    
    # 隐含层
    model.add(Dropout(0.5)) # 随机失活
    model.add(Activation('tanh')) # 激活函数,tanh
    model.add(Dense(y_train.shape[1])) # 全连接层
    
    # 输出层
    model.add(Activation('softmax')) # 激活函数,softmax
    
    # 配置训练方法
    model.compile(loss='categorical_crossentropy', # 损失函数，分类交叉熵
                          optimizer='adadelta', # 优化器，自适应增量 Adaptive Delta
                          metrics=['accuracy']) # 准确率评测，精确度
    
    print("模型各层的参数状况")
    print(model.summary()) # 查看模型
    
    # 模型训练
    history = model.fit(
            X_tr, y_train, # XY
            verbose=2,# 0 为不在标准输出流输出日志信息；1 为输出进度条记录；2 没有进度条，只是输出一行记录
            epochs=35, # 训练次数,训练模型的迭代数
#             batch_size=128, # 批处理大小,每次梯度更新的样本数
            validation_data=(X_te, y_test),# 验证数据
            shuffle=True, # 在每个epoch之前对训练数据进行洗牌
           )
    
    # 预测
    pred_train = model.predict_proba(X_tr) # 训练集预测
    pred_test = model.predict_proba(X_te) # 测试集预测
    
    return pred_train,pred_test

# %%
def ACC(y_train,y_test,pred_train,pred_test):
    # 准确度计算
    train_acc = accuracy_score(y_train,pred_train)
    test_acc = accuracy_score(y_test,pred_test)
    print("训练集准确度: {0:.4f}, 测试集准确度: {1:.4f}".format(train_acc, test_acc))

# %%
pred_df = pd.DataFrame()
for col in col_list:
    
    print(col,end="\t")# 打印当前训练目标列列名
    
    # 划分数据集
    # 训练特征集，测试特征集合，训练目标列，测试目标列
    X_tr, X_te, Y_tr, Y_te = get_train_test(TFIDF_sp,data[col]) 
    
    # 构建模型并进行训练
    # 输出为One-Hot编码后对应索引上概率值
    pred_tr,pred_te = SNN_Model(X_tr, X_te, Y_tr, Y_te) 
    
    # 根据概率值最大值输出预测类别
    pred_train = np.argmax(pred_tr,axis=1)
    pred_test = np.argmax(pred_te,axis=1)
    
    # 准确度计算
    ACC(Y_tr,Y_te,pred_train,pred_test)
    
    # 输出结果进行纵向拼接
    pred = np.vstack([pred_tr,pred_te])
    # 输出结果存储
    for i in range(pred.shape[1]):
        col_name = "{}_{}".format(col,i+1)
        pred_df[col_name] = pred[:,i]
        
    # 打印存储对象情况
    print(pred_df.columns)

    print("="*50)
# Out:
# Education	模型各层的参数状况
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 300)               100938300
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 300)               0
# _________________________________________________________________
# activation_12 (Activation)   (None, 300)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 7)                 2107
# _________________________________________________________________
# activation_13 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 100,940,407
# Trainable params: 100,940,407
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 12355 samples, validate on 5296 samples
# Epoch 1/5
# 12355/12355 [==============================] - 109s 9ms/step - loss: 1.4918 - acc: 0.4170 - val_loss: 1.2617 - val_acc: 0.4158
# Epoch 2/5
# 12355/12355 [==============================] - 108s 9ms/step - loss: 1.2159 - acc: 0.4321 - val_loss: 1.2142 - val_acc: 0.4158
# Epoch 3/5
# 12355/12355 [==============================] - 108s 9ms/step - loss: 1.1607 - acc: 0.4787 - val_loss: 1.1642 - val_acc: 0.4583
# Epoch 4/5
# 12355/12355 [==============================] - 107s 9ms/step - loss: 1.0962 - acc: 0.5389 - val_loss: 1.1160 - val_acc: 0.5444
# Epoch 5/5
# 12355/12355 [==============================] - 112s 9ms/step - loss: 1.0319 - acc: 0.5911 - val_loss: 1.0871 - val_acc: 0.5174
# 训练集准确度: 0.5705, 测试集准确度: 0.5174
# Index(['Education_1', 'Education_2', 'Education_3', 'Education_4',
#        'Education_5', 'Education_6', 'Education_7'],
#       dtype='object')
# ==================================================
# age	模型各层的参数状况
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 300)               100938300
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 300)               0
# _________________________________________________________________
# activation_14 (Activation)   (None, 300)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 7)                 2107
# _________________________________________________________________
# activation_15 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 100,940,407
# Trainable params: 100,940,407
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 12355 samples, validate on 5296 samples
# Epoch 1/5
# 12355/12355 [==============================] - 113s 9ms/step - loss: 1.5693 - acc: 0.4001 - val_loss: 1.3654 - val_acc: 0.4077
# Epoch 2/5
# 12355/12355 [==============================] - 106s 9ms/step - loss: 1.3298 - acc: 0.4064 - val_loss: 1.3090 - val_acc: 0.4077
# Epoch 3/5
# 12355/12355 [==============================] - 107s 9ms/step - loss: 1.2685 - acc: 0.4376 - val_loss: 1.2513 - val_acc: 0.4647
# Epoch 4/5
# 12355/12355 [==============================] - 109s 9ms/step - loss: 1.1960 - acc: 0.5022 - val_loss: 1.1950 - val_acc: 0.5043
# Epoch 5/5
# 12355/12355 [==============================] - 110s 9ms/step - loss: 1.1239 - acc: 0.5559 - val_loss: 1.1544 - val_acc: 0.5614
# 训练集准确度: 0.6318, 测试集准确度: 0.5614
# Index(['Education_1', 'Education_2', 'Education_3', 'Education_4',
#        'Education_5', 'Education_6', 'Education_7', 'age_1', 'age_2', 'age_3',
#        'age_4', 'age_5', 'age_6', 'age_7'],
#       dtype='object')
# ==================================================
# gender	模型各层的参数状况
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 300)               100938300
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 300)               0
# _________________________________________________________________
# activation_16 (Activation)   (None, 300)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 3)                 903
# _________________________________________________________________
# activation_17 (Activation)   (None, 3)                 0
# =================================================================
# Total params: 100,939,203
# Trainable params: 100,939,203
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 12355 samples, validate on 5296 samples
# Epoch 1/5
# 12355/12355 [==============================] - 111s 9ms/step - loss: 0.8141 - acc: 0.5757 - val_loss: 0.6674 - val_acc: 0.5997
# Epoch 2/5
# 12355/12355 [==============================] - 106s 9ms/step - loss: 0.6265 - acc: 0.6580 - val_loss: 0.5871 - val_acc: 0.7553
# Epoch 3/5
# 12355/12355 [==============================] - 109s 9ms/step - loss: 0.5380 - acc: 0.7929 - val_loss: 0.5103 - val_acc: 0.7942
# Epoch 4/5
# 12355/12355 [==============================] - 109s 9ms/step - loss: 0.4594 - acc: 0.8312 - val_loss: 0.4671 - val_acc: 0.8270
# Epoch 5/5
# 12355/12355 [==============================] - 108s 9ms/step - loss: 0.4039 - acc: 0.8541 - val_loss: 0.4504 - val_acc: 0.8072
# 训练集准确度: 0.8541, 测试集准确度: 0.8072
# Index(['Education_1', 'Education_2', 'Education_3', 'Education_4',
#        'Education_5', 'Education_6', 'Education_7', 'age_1', 'age_2', 'age_3',
#        'age_4', 'age_5', 'age_6', 'age_7', 'gender_1', 'gender_2', 'gender_3'],
#       dtype='object')
# ==================================================

# %% [markdown]
# #### TFIDF_X_sp

# %%
TFIDF_nn_pred_df = pd.DataFrame()
for col in col_list:
    
    print(col,end="\t")# 打印当前训练目标列列名
    
    # 划分数据集
    # 训练特征集，测试特征集合，训练目标列，测试目标列
    X_tr, X_te, Y_tr, Y_te = get_train_test(TFIDF_sp,data[col]) 
    
    # 构建模型并进行训练
    # 输出为One-Hot编码后对应索引上概率值
    pred_tr,pred_te = SNN_Model(X_tr, X_te, Y_tr, Y_te) 
    
    # 根据概率值最大值输出预测类别
    pred_train = np.argmax(pred_tr,axis=1)
    pred_test = np.argmax(pred_te,axis=1)
    
    # 准确度计算
    ACC(Y_tr,Y_te,pred_train,pred_test)
    
    # 输出结果进行纵向拼接
    pred = np.vstack([pred_tr,pred_te])
    # 输出结果存储
    for i in range(pred.shape[1]):
        col_name = "{}_{}".format(col,i+1)
        TFIDF_nn_pred_df[col_name] = pred[:,i]
        
    # 打印存储对象情况
    print(TFIDF_nn_pred_df.columns)

    print("="*50)
# Out:
# Education	模型各层的参数状况
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 300)               100938300
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 300)               0
# _________________________________________________________________
# activation_18 (Activation)   (None, 300)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 7)                 2107
# _________________________________________________________________
# activation_19 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 100,940,407
# Trainable params: 100,940,407
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 12355 samples, validate on 5296 samples
# Epoch 1/35
# 12355/12355 [==============================] - 543s 44ms/step - loss: 1.1674 - acc: 0.5045 - val_loss: 1.0387 - val_acc: 0.5846
# Epoch 2/35
# 12355/12355 [==============================] - 539s 44ms/step - loss: 0.8670 - acc: 0.6792 - val_loss: 0.9840 - val_acc: 0.6061
# Epoch 3/35
# 12355/12355 [==============================] - 537s 43ms/step - loss: 0.5989 - acc: 0.8193 - val_loss: 0.9686 - val_acc: 0.6129
# Epoch 4/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.3212 - acc: 0.9348 - val_loss: 1.0240 - val_acc: 0.6090
# Epoch 5/35
# 12355/12355 [==============================] - 538s 44ms/step - loss: 0.1387 - acc: 0.9810 - val_loss: 1.1092 - val_acc: 0.6040
# Epoch 6/35
# 12355/12355 [==============================] - 539s 44ms/step - loss: 0.0624 - acc: 0.9898 - val_loss: 1.1881 - val_acc: 0.5997
# Epoch 7/35
# 12355/12355 [==============================] - 537s 43ms/step - loss: 0.0348 - acc: 0.9964 - val_loss: 1.2314 - val_acc: 0.5967
# Epoch 8/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0228 - acc: 0.9976 - val_loss: 1.2846 - val_acc: 0.5959
# Epoch 9/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0164 - acc: 0.9997 - val_loss: 1.3110 - val_acc: 0.6037
# Epoch 10/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0124 - acc: 1.0000 - val_loss: 1.3507 - val_acc: 0.5982
# Epoch 11/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0097 - acc: 1.0000 - val_loss: 1.3714 - val_acc: 0.5974
# Epoch 12/35
# 12355/12355 [==============================] - 537s 43ms/step - loss: 0.0079 - acc: 1.0000 - val_loss: 1.3883 - val_acc: 0.5982
# Epoch 13/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0064 - acc: 1.0000 - val_loss: 1.3789 - val_acc: 0.6029
# Epoch 14/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0054 - acc: 1.0000 - val_loss: 1.4234 - val_acc: 0.6056
# Epoch 15/35
# 12355/12355 [==============================] - 537s 43ms/step - loss: 0.0046 - acc: 1.0000 - val_loss: 1.4285 - val_acc: 0.6033
# Epoch 16/35
# 12355/12355 [==============================] - 537s 43ms/step - loss: 0.0040 - acc: 1.0000 - val_loss: 1.4292 - val_acc: 0.6052
# Epoch 17/35
# 12355/12355 [==============================] - 537s 43ms/step - loss: 0.0036 - acc: 1.0000 - val_loss: 1.4478 - val_acc: 0.6012
# Epoch 18/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0032 - acc: 1.0000 - val_loss: 1.4717 - val_acc: 0.6052
# Epoch 19/35
# 12355/12355 [==============================] - 537s 43ms/step - loss: 0.0029 - acc: 1.0000 - val_loss: 1.4714 - val_acc: 0.6033
# Epoch 20/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0026 - acc: 1.0000 - val_loss: 1.4738 - val_acc: 0.5986
# Epoch 21/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0024 - acc: 1.0000 - val_loss: 1.4787 - val_acc: 0.6018
# Epoch 22/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0022 - acc: 1.0000 - val_loss: 1.4844 - val_acc: 0.6020
# Epoch 23/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0021 - acc: 1.0000 - val_loss: 1.4965 - val_acc: 0.5963
# Epoch 24/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0020 - acc: 1.0000 - val_loss: 1.5028 - val_acc: 0.6020
# Epoch 25/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0018 - acc: 1.0000 - val_loss: 1.5268 - val_acc: 0.5978
# Epoch 26/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0017 - acc: 1.0000 - val_loss: 1.5275 - val_acc: 0.5972
# Epoch 27/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0016 - acc: 1.0000 - val_loss: 1.5224 - val_acc: 0.5995
# Epoch 28/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0015 - acc: 1.0000 - val_loss: 1.5251 - val_acc: 0.6010
# Epoch 29/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0014 - acc: 1.0000 - val_loss: 1.5387 - val_acc: 0.5999
# Epoch 30/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0014 - acc: 1.0000 - val_loss: 1.5429 - val_acc: 0.5993
# Epoch 31/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0013 - acc: 1.0000 - val_loss: 1.5695 - val_acc: 0.6031
# Epoch 32/35
# 12355/12355 [==============================] - 537s 43ms/step - loss: 0.0013 - acc: 1.0000 - val_loss: 1.5479 - val_acc: 0.5991
# Epoch 33/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0012 - acc: 1.0000 - val_loss: 1.5773 - val_acc: 0.6029
# Epoch 34/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0012 - acc: 1.0000 - val_loss: 1.5631 - val_acc: 0.6025
# Epoch 35/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0011 - acc: 1.0000 - val_loss: 1.5688 - val_acc: 0.5991
# 训练集准确度: 1.0000, 测试集准确度: 0.5991
# Index(['Education_1', 'Education_2', 'Education_3', 'Education_4',
#        'Education_5', 'Education_6', 'Education_7'],
#       dtype='object')
# ==================================================
# age	模型各层的参数状况
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_20 (Dense)             (None, 300)               100938300
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 300)               0
# _________________________________________________________________
# activation_20 (Activation)   (None, 300)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 7)                 2107
# _________________________________________________________________
# activation_21 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 100,940,407
# Trainable params: 100,940,407
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 12355 samples, validate on 5296 samples
# Epoch 1/35
# 12355/12355 [==============================] - 539s 44ms/step - loss: 1.2688 - acc: 0.4724 - val_loss: 1.1158 - val_acc: 0.5504
# Epoch 2/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.9390 - acc: 0.6507 - val_loss: 1.0209 - val_acc: 0.5893
# Epoch 3/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.6511 - acc: 0.7964 - val_loss: 1.0103 - val_acc: 0.6005
# Epoch 4/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.3614 - acc: 0.9246 - val_loss: 1.0587 - val_acc: 0.5925
# Epoch 5/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.1580 - acc: 0.9764 - val_loss: 1.1002 - val_acc: 0.5946
# Epoch 6/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0665 - acc: 0.9960 - val_loss: 1.1602 - val_acc: 0.5948
# Epoch 7/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0344 - acc: 0.9980 - val_loss: 1.2145 - val_acc: 0.5882
# Epoch 8/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0215 - acc: 0.9981 - val_loss: 1.2443 - val_acc: 0.5918
# Epoch 9/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0150 - acc: 0.9992 - val_loss: 1.2711 - val_acc: 0.5937
# Epoch 10/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0113 - acc: 0.9998 - val_loss: 1.2981 - val_acc: 0.5921
# Epoch 11/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0088 - acc: 1.0000 - val_loss: 1.3272 - val_acc: 0.5923
# Epoch 12/35
# 12355/12355 [==============================] - 534s 43ms/step - loss: 0.0072 - acc: 1.0000 - val_loss: 1.3318 - val_acc: 0.5882
# Epoch 13/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0059 - acc: 1.0000 - val_loss: 1.3581 - val_acc: 0.5897
# Epoch 14/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0052 - acc: 1.0000 - val_loss: 1.3676 - val_acc: 0.5914
# Epoch 15/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0045 - acc: 1.0000 - val_loss: 1.3666 - val_acc: 0.5923
# Epoch 16/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0039 - acc: 1.0000 - val_loss: 1.3683 - val_acc: 0.5904
# Epoch 17/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0036 - acc: 1.0000 - val_loss: 1.3945 - val_acc: 0.5869
# Epoch 18/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0032 - acc: 1.0000 - val_loss: 1.4049 - val_acc: 0.5918
# Epoch 19/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0029 - acc: 1.0000 - val_loss: 1.4109 - val_acc: 0.5904
# Epoch 20/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0027 - acc: 1.0000 - val_loss: 1.4200 - val_acc: 0.5897
# Epoch 21/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0025 - acc: 1.0000 - val_loss: 1.4361 - val_acc: 0.5880
# Epoch 22/35
# 12355/12355 [==============================] - 537s 43ms/step - loss: 0.0023 - acc: 1.0000 - val_loss: 1.4349 - val_acc: 0.5918
# Epoch 23/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0021 - acc: 1.0000 - val_loss: 1.4335 - val_acc: 0.5904
# Epoch 24/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0020 - acc: 1.0000 - val_loss: 1.4543 - val_acc: 0.5903
# Epoch 25/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0019 - acc: 1.0000 - val_loss: 1.4511 - val_acc: 0.5920
# Epoch 26/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0018 - acc: 1.0000 - val_loss: 1.4566 - val_acc: 0.5916
# Epoch 27/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0017 - acc: 1.0000 - val_loss: 1.4734 - val_acc: 0.5867
# Epoch 28/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0016 - acc: 1.0000 - val_loss: 1.4674 - val_acc: 0.5918
# Epoch 29/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0015 - acc: 1.0000 - val_loss: 1.4867 - val_acc: 0.5903
# Epoch 30/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0014 - acc: 1.0000 - val_loss: 1.4879 - val_acc: 0.5870
# Epoch 31/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0014 - acc: 1.0000 - val_loss: 1.4763 - val_acc: 0.5910
# Epoch 32/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0013 - acc: 1.0000 - val_loss: 1.4849 - val_acc: 0.5903
# Epoch 33/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0013 - acc: 1.0000 - val_loss: 1.5009 - val_acc: 0.5901
# Epoch 34/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0012 - acc: 1.0000 - val_loss: 1.5037 - val_acc: 0.5874
# Epoch 35/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0012 - acc: 1.0000 - val_loss: 1.5074 - val_acc: 0.5903
# 训练集准确度: 1.0000, 测试集准确度: 0.5903
# Index(['Education_1', 'Education_2', 'Education_3', 'Education_4',
#        'Education_5', 'Education_6', 'Education_7', 'age_1', 'age_2', 'age_3',
#        'age_4', 'age_5', 'age_6', 'age_7'],
#       dtype='object')
# ==================================================
# gender	模型各层的参数状况
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_22 (Dense)             (None, 300)               100938300
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 300)               0
# _________________________________________________________________
# activation_22 (Activation)   (None, 300)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 3)                 903
# _________________________________________________________________
# activation_23 (Activation)   (None, 3)                 0
# =================================================================
# Total params: 100,939,203
# Trainable params: 100,939,203
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 12355 samples, validate on 5296 samples
# Epoch 1/35
# 12355/12355 [==============================] - 541s 44ms/step - loss: 0.5523 - acc: 0.7464 - val_loss: 0.4528 - val_acc: 0.8269
# Epoch 2/35
# 12355/12355 [==============================] - 537s 43ms/step - loss: 0.3257 - acc: 0.8830 - val_loss: 0.4239 - val_acc: 0.8410
# Epoch 3/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.1784 - acc: 0.9466 - val_loss: 0.4927 - val_acc: 0.8000
# Epoch 4/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0670 - acc: 0.9899 - val_loss: 0.4862 - val_acc: 0.8272
# Epoch 5/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0214 - acc: 0.9992 - val_loss: 0.5348 - val_acc: 0.8293
# Epoch 6/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0100 - acc: 1.0000 - val_loss: 0.5751 - val_acc: 0.8261
# Epoch 7/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0062 - acc: 1.0000 - val_loss: 0.5974 - val_acc: 0.8265
# Epoch 8/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0044 - acc: 1.0000 - val_loss: 0.6228 - val_acc: 0.8255
# Epoch 9/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0035 - acc: 1.0000 - val_loss: 0.6316 - val_acc: 0.8265
# Epoch 10/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0028 - acc: 1.0000 - val_loss: 0.6497 - val_acc: 0.8265
# Epoch 11/35
# 12355/12355 [==============================] - 534s 43ms/step - loss: 0.0023 - acc: 1.0000 - val_loss: 0.6642 - val_acc: 0.8248
# Epoch 12/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0020 - acc: 1.0000 - val_loss: 0.6899 - val_acc: 0.8235
# Epoch 13/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0017 - acc: 1.0000 - val_loss: 0.6842 - val_acc: 0.8261
# Epoch 14/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0015 - acc: 1.0000 - val_loss: 0.6897 - val_acc: 0.8267
# Epoch 15/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0014 - acc: 1.0000 - val_loss: 0.6957 - val_acc: 0.8280
# Epoch 16/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0013 - acc: 1.0000 - val_loss: 0.7020 - val_acc: 0.8270
# Epoch 17/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 0.0011 - acc: 1.0000 - val_loss: 0.7223 - val_acc: 0.8235
# Epoch 18/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 0.0011 - acc: 1.0000 - val_loss: 0.7269 - val_acc: 0.8233
# Epoch 19/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 9.6810e-04 - acc: 1.0000 - val_loss: 0.7224 - val_acc: 0.8280
# Epoch 20/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 8.9860e-04 - acc: 1.0000 - val_loss: 0.7287 - val_acc: 0.8255
# Epoch 21/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 8.3479e-04 - acc: 1.0000 - val_loss: 0.7310 - val_acc: 0.8272
# Epoch 22/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 7.8468e-04 - acc: 1.0000 - val_loss: 0.7353 - val_acc: 0.8255
# Epoch 23/35
# 12355/12355 [==============================] - 535s 43ms/step - loss: 7.4498e-04 - acc: 1.0000 - val_loss: 0.7430 - val_acc: 0.8261
# Epoch 24/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 7.0123e-04 - acc: 1.0000 - val_loss: 0.7437 - val_acc: 0.8255
# Epoch 25/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 6.5862e-04 - acc: 1.0000 - val_loss: 0.7521 - val_acc: 0.8252
# Epoch 26/35
# 12355/12355 [==============================] - 536s 43ms/step - loss: 6.2103e-04 - acc: 1.0000 - val_loss: 0.7584 - val_acc: 0.8253
# Epoch 27/35
# 12355/12355 [==============================] - 538s 44ms/step - loss: 5.9162e-04 - acc: 1.0000 - val_loss: 0.7553 - val_acc: 0.8252
# Epoch 28/35
# 12355/12355 [==============================] - 543s 44ms/step - loss: 5.6545e-04 - acc: 1.0000 - val_loss: 0.7596 - val_acc: 0.8272
# Epoch 29/35
# 12355/12355 [==============================] - 563s 46ms/step - loss: 5.4318e-04 - acc: 1.0000 - val_loss: 0.7631 - val_acc: 0.8261
# Epoch 30/35
# 12355/12355 [==============================] - 572s 46ms/step - loss: 5.1601e-04 - acc: 1.0000 - val_loss: 0.7765 - val_acc: 0.8233
# Epoch 31/35
# 12355/12355 [==============================] - 556s 45ms/step - loss: 4.9806e-04 - acc: 1.0000 - val_loss: 0.7709 - val_acc: 0.8259
# Epoch 32/35
# 12355/12355 [==============================] - 553s 45ms/step - loss: 4.7009e-04 - acc: 1.0000 - val_loss: 0.7778 - val_acc: 0.8253
# Epoch 33/35
# 12355/12355 [==============================] - 544s 44ms/step - loss: 4.5336e-04 - acc: 1.0000 - val_loss: 0.7808 - val_acc: 0.8253
# Epoch 34/35
# 12355/12355 [==============================] - 545s 44ms/step - loss: 4.3415e-04 - acc: 1.0000 - val_loss: 0.7777 - val_acc: 0.8252
# Epoch 35/35
# 12355/12355 [==============================] - 552s 45ms/step - loss: 4.1813e-04 - acc: 1.0000 - val_loss: 0.7811 - val_acc: 0.8259
# 训练集准确度: 1.0000, 测试集准确度: 0.8259
# Index(['Education_1', 'Education_2', 'Education_3', 'Education_4',
#        'Education_5', 'Education_6', 'Education_7', 'age_1', 'age_2', 'age_3',
#        'age_4', 'age_5', 'age_6', 'age_7', 'gender_1', 'gender_2', 'gender_3'],
#       dtype='object')
# ==================================================

# %%
# 保存模型输出结果
TFIDF_nn_pred_df.to_csv("TFIDF_nn.csv",index=False)

# %% [markdown]
# #### TFIDF_HW_sp

# %%
TFIDF_HW_pred_df = pd.DataFrame()
for col in col_list:
    
    print(col,end="\t")# 打印当前训练目标列列名
    
    # 划分数据集
    # 训练特征集，测试特征集合，训练目标列，测试目标列
    X_tr, X_te, Y_tr, Y_te = get_train_test(TFIDF_HW_sp,data[col]) 
    
    # 构建模型并进行训练
    # 输出为One-Hot编码后对应索引上概率值
    pred_tr,pred_te = SNN_Model(X_tr, X_te, Y_tr, Y_te) 
    
    # 根据概率值最大值输出预测类别
    pred_train = np.argmax(pred_tr,axis=1)
    pred_test = np.argmax(pred_te,axis=1)
    
    # 准确度计算
    ACC(Y_tr,Y_te,pred_train,pred_test)
    
    # 输出结果进行纵向拼接
    pred = np.vstack([pred_tr,pred_te])
    # 输出结果存储
    for i in range(pred.shape[1]):
        col_name = "{}_{}".format(col,i+1)
        TFIDF_HW_pred_df[col_name] = pred[:,i]
        
    # 打印存储对象情况
    print(TFIDF_HW_pred_df.columns)

    print("="*50)
# Out:
# Education	模型各层的参数状况
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_54 (Dense)             (None, 300)               3810000
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 300)               0
# _________________________________________________________________
# activation_54 (Activation)   (None, 300)               0
# _________________________________________________________________
# dense_55 (Dense)             (None, 7)                 2107
# _________________________________________________________________
# activation_55 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 3,812,107
# Trainable params: 3,812,107
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 12355 samples, validate on 5296 samples
# Epoch 1/35
#  - 23s - loss: 1.2196 - acc: 0.4718 - val_loss: 1.1260 - val_acc: 0.5009
# Epoch 2/35
#  - 21s - loss: 1.0429 - acc: 0.5717 - val_loss: 1.0828 - val_acc: 0.5349
# Epoch 3/35
#  - 21s - loss: 0.9603 - acc: 0.6217 - val_loss: 1.1065 - val_acc: 0.5368
# Epoch 4/35
#  - 22s - loss: 0.8911 - acc: 0.6601 - val_loss: 1.0993 - val_acc: 0.5436
# Epoch 5/35
#  - 22s - loss: 0.8255 - acc: 0.6911 - val_loss: 1.1366 - val_acc: 0.5429
# Epoch 6/35
#  - 21s - loss: 0.7680 - acc: 0.7166 - val_loss: 1.1666 - val_acc: 0.5272
# Epoch 7/35
#  - 21s - loss: 0.7098 - acc: 0.7425 - val_loss: 1.2128 - val_acc: 0.5261
# Epoch 8/35
#  - 22s - loss: 0.6616 - acc: 0.7603 - val_loss: 1.2500 - val_acc: 0.5198
# Epoch 9/35
#  - 21s - loss: 0.6143 - acc: 0.7819 - val_loss: 1.3007 - val_acc: 0.5115
# Epoch 10/35
#  - 21s - loss: 0.5730 - acc: 0.7955 - val_loss: 1.3539 - val_acc: 0.5026
# Epoch 11/35
#  - 22s - loss: 0.5363 - acc: 0.8122 - val_loss: 1.4033 - val_acc: 0.4998
# Epoch 12/35
#  - 22s - loss: 0.5041 - acc: 0.8278 - val_loss: 1.4508 - val_acc: 0.4958
# Epoch 13/35
#  - 22s - loss: 0.4725 - acc: 0.8410 - val_loss: 1.5005 - val_acc: 0.4926
# Epoch 14/35
#  - 22s - loss: 0.4472 - acc: 0.8498 - val_loss: 1.5550 - val_acc: 0.4841
# Epoch 15/35
#  - 22s - loss: 0.4204 - acc: 0.8575 - val_loss: 1.6130 - val_acc: 0.4749
# Epoch 16/35
#  - 22s - loss: 0.3945 - acc: 0.8683 - val_loss: 1.6736 - val_acc: 0.4681
# Epoch 17/35
#  - 21s - loss: 0.3728 - acc: 0.8812 - val_loss: 1.6954 - val_acc: 0.4779
# Epoch 18/35
#  - 21s - loss: 0.3536 - acc: 0.8880 - val_loss: 1.7527 - val_acc: 0.4654
# Epoch 19/35
#  - 21s - loss: 0.3334 - acc: 0.8940 - val_loss: 1.7877 - val_acc: 0.4796
# Epoch 20/35
#  - 21s - loss: 0.3181 - acc: 0.8999 - val_loss: 1.8337 - val_acc: 0.4732
# Epoch 21/35
#  - 21s - loss: 0.3016 - acc: 0.9050 - val_loss: 1.8763 - val_acc: 0.4711
# Epoch 22/35
#  - 21s - loss: 0.2861 - acc: 0.9132 - val_loss: 1.9417 - val_acc: 0.4664
# Epoch 23/35
#  - 23s - loss: 0.2701 - acc: 0.9197 - val_loss: 1.9939 - val_acc: 0.4794
# Epoch 24/35
#  - 22s - loss: 0.2573 - acc: 0.9204 - val_loss: 2.0223 - val_acc: 0.4670
# Epoch 25/35
#  - 22s - loss: 0.2453 - acc: 0.9252 - val_loss: 2.0831 - val_acc: 0.4709
# Epoch 26/35
#  - 22s - loss: 0.2325 - acc: 0.9301 - val_loss: 2.1072 - val_acc: 0.4668
# Epoch 27/35
#  - 23s - loss: 0.2195 - acc: 0.9345 - val_loss: 2.1514 - val_acc: 0.4664
# Epoch 28/35
#  - 22s - loss: 0.2089 - acc: 0.9397 - val_loss: 2.2033 - val_acc: 0.4707
# Epoch 29/35
#  - 21s - loss: 0.1980 - acc: 0.9425 - val_loss: 2.2587 - val_acc: 0.4690
# Epoch 30/35
#  - 21s - loss: 0.1919 - acc: 0.9454 - val_loss: 2.2979 - val_acc: 0.4690
# Epoch 31/35
#  - 22s - loss: 0.1819 - acc: 0.9481 - val_loss: 2.3555 - val_acc: 0.4520
# Epoch 32/35
#  - 22s - loss: 0.1712 - acc: 0.9544 - val_loss: 2.3824 - val_acc: 0.4622
# Epoch 33/35
#  - 21s - loss: 0.1646 - acc: 0.9548 - val_loss: 2.4348 - val_acc: 0.4624
# Epoch 34/35
#  - 21s - loss: 0.1561 - acc: 0.9550 - val_loss: 2.4918 - val_acc: 0.4530
# Epoch 35/35
#  - 22s - loss: 0.1500 - acc: 0.9593 - val_loss: 2.5386 - val_acc: 0.4688
# 训练集准确度: 0.9690, 测试集准确度: 0.4688
# Index(['Education_1', 'Education_2', 'Education_3', 'Education_4',
#        'Education_5', 'Education_6', 'Education_7'],
#       dtype='object')
# ==================================================
# age	模型各层的参数状况
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_56 (Dense)             (None, 300)               3810000
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 300)               0
# _________________________________________________________________
# activation_56 (Activation)   (None, 300)               0
# _________________________________________________________________
# dense_57 (Dense)             (None, 7)                 2107
# _________________________________________________________________
# activation_57 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 3,812,107
# Trainable params: 3,812,107
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 12355 samples, validate on 5296 samples
# Epoch 1/35
#  - 23s - loss: 1.3186 - acc: 0.4435 - val_loss: 1.1993 - val_acc: 0.5140
# Epoch 2/35
#  - 22s - loss: 1.1335 - acc: 0.5476 - val_loss: 1.1510 - val_acc: 0.5287
# Epoch 3/35
#  - 22s - loss: 1.0470 - acc: 0.5954 - val_loss: 1.1450 - val_acc: 0.5295
# Epoch 4/35
#  - 21s - loss: 0.9755 - acc: 0.6275 - val_loss: 1.1556 - val_acc: 0.5332
# Epoch 5/35
#  - 21s - loss: 0.9058 - acc: 0.6646 - val_loss: 1.1718 - val_acc: 0.5321
# Epoch 6/35
#  - 21s - loss: 0.8389 - acc: 0.6958 - val_loss: 1.2036 - val_acc: 0.5261
# Epoch 7/35
#  - 22s - loss: 0.7780 - acc: 0.7220 - val_loss: 1.2573 - val_acc: 0.5149
# Epoch 8/35
#  - 22s - loss: 0.7168 - acc: 0.7490 - val_loss: 1.2871 - val_acc: 0.5128
# Epoch 9/35
#  - 21s - loss: 0.6630 - acc: 0.7661 - val_loss: 1.3630 - val_acc: 0.4917
# Epoch 10/35
#  - 21s - loss: 0.6152 - acc: 0.7879 - val_loss: 1.3878 - val_acc: 0.5004
# Epoch 11/35
#  - 21s - loss: 0.5715 - acc: 0.8039 - val_loss: 1.4368 - val_acc: 0.4947
# Epoch 12/35
#  - 21s - loss: 0.5263 - acc: 0.8209 - val_loss: 1.4950 - val_acc: 0.4828
# Epoch 13/35
#  - 21s - loss: 0.4919 - acc: 0.8355 - val_loss: 1.5514 - val_acc: 0.4890
# Epoch 14/35
#  - 21s - loss: 0.4558 - acc: 0.8495 - val_loss: 1.6091 - val_acc: 0.4726
# Epoch 15/35
#  - 21s - loss: 0.4300 - acc: 0.8600 - val_loss: 1.6638 - val_acc: 0.4840
# Epoch 16/35
#  - 21s - loss: 0.4018 - acc: 0.8699 - val_loss: 1.7330 - val_acc: 0.4636
# Epoch 17/35
#  - 22s - loss: 0.3747 - acc: 0.8841 - val_loss: 1.7613 - val_acc: 0.4709
# Epoch 18/35
#  - 22s - loss: 0.3496 - acc: 0.8893 - val_loss: 1.8217 - val_acc: 0.4590
# Epoch 19/35
#  - 21s - loss: 0.3280 - acc: 0.8961 - val_loss: 1.8841 - val_acc: 0.4662
# Epoch 20/35
#  - 21s - loss: 0.3104 - acc: 0.9049 - val_loss: 1.9385 - val_acc: 0.4658
# Epoch 21/35
#  - 21s - loss: 0.2888 - acc: 0.9120 - val_loss: 1.9842 - val_acc: 0.4641
# Epoch 22/35
#  - 21s - loss: 0.2747 - acc: 0.9155 - val_loss: 2.0461 - val_acc: 0.4636
# Epoch 23/35
#  - 21s - loss: 0.2581 - acc: 0.9225 - val_loss: 2.0940 - val_acc: 0.4558
# Epoch 24/35
#  - 21s - loss: 0.2433 - acc: 0.9285 - val_loss: 2.1838 - val_acc: 0.4460
# Epoch 25/35
#  - 21s - loss: 0.2334 - acc: 0.9333 - val_loss: 2.1905 - val_acc: 0.4520
# Epoch 26/35
#  - 21s - loss: 0.2130 - acc: 0.9390 - val_loss: 2.2667 - val_acc: 0.4554
# Epoch 27/35
#  - 21s - loss: 0.2028 - acc: 0.9420 - val_loss: 2.2994 - val_acc: 0.4545
# Epoch 28/35
#  - 21s - loss: 0.1929 - acc: 0.9458 - val_loss: 2.3507 - val_acc: 0.4543
# Epoch 29/35
#  - 21s - loss: 0.1815 - acc: 0.9483 - val_loss: 2.4145 - val_acc: 0.4477
# Epoch 30/35
#  - 21s - loss: 0.1694 - acc: 0.9524 - val_loss: 2.4596 - val_acc: 0.4539
# Epoch 31/35
#  - 21s - loss: 0.1618 - acc: 0.9547 - val_loss: 2.5215 - val_acc: 0.4449
# Epoch 32/35
#  - 21s - loss: 0.1515 - acc: 0.9590 - val_loss: 2.5643 - val_acc: 0.4430
# Epoch 33/35
#  - 21s - loss: 0.1457 - acc: 0.9577 - val_loss: 2.6271 - val_acc: 0.4437
# Epoch 34/35
#  - 21s - loss: 0.1359 - acc: 0.9633 - val_loss: 2.6757 - val_acc: 0.4513
# Epoch 35/35
#  - 21s - loss: 0.1304 - acc: 0.9645 - val_loss: 2.7164 - val_acc: 0.4449
# 训练集准确度: 0.9771, 测试集准确度: 0.4449
# Index(['Education_1', 'Education_2', 'Education_3', 'Education_4',
#        'Education_5', 'Education_6', 'Education_7', 'age_1', 'age_2', 'age_3',
#        'age_4', 'age_5', 'age_6', 'age_7'],
#       dtype='object')
# ==================================================
# gender	模型各层的参数状况
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_58 (Dense)             (None, 300)               3810000
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 300)               0
# _________________________________________________________________
# activation_58 (Activation)   (None, 300)               0
# _________________________________________________________________
# dense_59 (Dense)             (None, 3)                 903
# _________________________________________________________________
# activation_59 (Activation)   (None, 3)                 0
# =================================================================
# Total params: 3,810,903
# Trainable params: 3,810,903
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 12355 samples, validate on 5296 samples
# Epoch 1/35
#  - 22s - loss: 0.6189 - acc: 0.6838 - val_loss: 0.5337 - val_acc: 0.7313
# Epoch 2/35
#  - 21s - loss: 0.4875 - acc: 0.7789 - val_loss: 0.5165 - val_acc: 0.7611
# Epoch 3/35
#  - 21s - loss: 0.4413 - acc: 0.8067 - val_loss: 0.5112 - val_acc: 0.7679
# Epoch 4/35
#  - 21s - loss: 0.4088 - acc: 0.8287 - val_loss: 0.5390 - val_acc: 0.7526
# Epoch 5/35
#  - 21s - loss: 0.3830 - acc: 0.8431 - val_loss: 0.5483 - val_acc: 0.7555
# Epoch 6/35
#  - 21s - loss: 0.3587 - acc: 0.8527 - val_loss: 0.5521 - val_acc: 0.7594
# Epoch 7/35
#  - 21s - loss: 0.3381 - acc: 0.8634 - val_loss: 0.5660 - val_acc: 0.7570
# Epoch 8/35
#  - 21s - loss: 0.3196 - acc: 0.8744 - val_loss: 0.5961 - val_acc: 0.7466
# Epoch 9/35
#  - 21s - loss: 0.3020 - acc: 0.8803 - val_loss: 0.6050 - val_acc: 0.7457
# Epoch 10/35
#  - 21s - loss: 0.2859 - acc: 0.8902 - val_loss: 0.6263 - val_acc: 0.7453
# Epoch 11/35
#  - 21s - loss: 0.2714 - acc: 0.8975 - val_loss: 0.6441 - val_acc: 0.7423
# Epoch 12/35
#  - 21s - loss: 0.2561 - acc: 0.9024 - val_loss: 0.6668 - val_acc: 0.7330
# Epoch 13/35
#  - 21s - loss: 0.2452 - acc: 0.9082 - val_loss: 0.6872 - val_acc: 0.7355
# Epoch 14/35
#  - 21s - loss: 0.2335 - acc: 0.9116 - val_loss: 0.7073 - val_acc: 0.7323
# Epoch 15/35
#  - 21s - loss: 0.2216 - acc: 0.9164 - val_loss: 0.7298 - val_acc: 0.7313
# Epoch 16/35
#  - 21s - loss: 0.2105 - acc: 0.9212 - val_loss: 0.7708 - val_acc: 0.7194
# Epoch 17/35
#  - 21s - loss: 0.2009 - acc: 0.9268 - val_loss: 0.8122 - val_acc: 0.7266
# Epoch 18/35
#  - 21s - loss: 0.1920 - acc: 0.9312 - val_loss: 0.7979 - val_acc: 0.7236
# Epoch 19/35
#  - 21s - loss: 0.1875 - acc: 0.9331 - val_loss: 0.8164 - val_acc: 0.7270
# Epoch 20/35
#  - 21s - loss: 0.1803 - acc: 0.9349 - val_loss: 0.8462 - val_acc: 0.7204
# Epoch 21/35
#  - 21s - loss: 0.1704 - acc: 0.9382 - val_loss: 0.8614 - val_acc: 0.7222
# Epoch 22/35
#  - 21s - loss: 0.1632 - acc: 0.9429 - val_loss: 0.8864 - val_acc: 0.7132
# Epoch 23/35
#  - 21s - loss: 0.1595 - acc: 0.9441 - val_loss: 0.9081 - val_acc: 0.7137
# Epoch 24/35
#  - 21s - loss: 0.1549 - acc: 0.9458 - val_loss: 0.9504 - val_acc: 0.7071
# Epoch 25/35
#  - 21s - loss: 0.1485 - acc: 0.9484 - val_loss: 0.9491 - val_acc: 0.7139
# Epoch 26/35
#  - 21s - loss: 0.1407 - acc: 0.9518 - val_loss: 0.9814 - val_acc: 0.7083
# Epoch 27/35
#  - 21s - loss: 0.1412 - acc: 0.9509 - val_loss: 0.9934 - val_acc: 0.7132
# Epoch 28/35
#  - 21s - loss: 0.1351 - acc: 0.9546 - val_loss: 1.0248 - val_acc: 0.7068
# Epoch 29/35
#  - 21s - loss: 0.1307 - acc: 0.9561 - val_loss: 1.0436 - val_acc: 0.7041
# Epoch 30/35
#  - 21s - loss: 0.1262 - acc: 0.9582 - val_loss: 1.0675 - val_acc: 0.7051
# Epoch 31/35
#  - 21s - loss: 0.1212 - acc: 0.9586 - val_loss: 1.0927 - val_acc: 0.7022
# Epoch 32/35
#  - 21s - loss: 0.1188 - acc: 0.9615 - val_loss: 1.1119 - val_acc: 0.7015
# Epoch 33/35
#  - 21s - loss: 0.1149 - acc: 0.9627 - val_loss: 1.1482 - val_acc: 0.6990
# Epoch 34/35
#  - 21s - loss: 0.1094 - acc: 0.9651 - val_loss: 1.1663 - val_acc: 0.7058
# Epoch 35/35
#  - 21s - loss: 0.1059 - acc: 0.9672 - val_loss: 1.1942 - val_acc: 0.7013
# 训练集准确度: 0.9737, 测试集准确度: 0.7013
# Index(['Education_1', 'Education_2', 'Education_3', 'Education_4',
#        'Education_5', 'Education_6', 'Education_7', 'age_1', 'age_2', 'age_3',
#        'age_4', 'age_5', 'age_6', 'age_7', 'gender_1', 'gender_2', 'gender_3'],
#       dtype='object')
# ==================================================

# %%
# 保存模型输出结果
TFIDF_HW_pred_df.to_csv("TFIDF_HW_nn.csv",index=False)

# %% [markdown]
# #### W2V_X_sp

# %%
W2V_nn_pred_df = pd.DataFrame()
for col in col_list:
    
    print(col,end="\t")# 打印当前训练目标列列名
    
    # 划分数据集
    # 训练特征集，测试特征集合，训练目标列，测试目标列
    X_tr, X_te, Y_tr, Y_te = get_train_test(W2V_X_sp,data[col]) 
    
    # 构建模型并进行训练
    # 输出为One-Hot编码后对应索引上概率值
    pred_tr,pred_te = SNN_Model(X_tr, X_te, Y_tr, Y_te) 
    
    # 根据概率值最大值输出预测类别
    pred_train = np.argmax(pred_tr,axis=1)
    pred_test = np.argmax(pred_te,axis=1)
    
    # 准确度计算
    ACC(Y_tr,Y_te,pred_train,pred_test)
    
    # 输出结果进行纵向拼接
    pred = np.vstack([pred_tr,pred_te])
    # 输出结果存储
    for i in range(pred.shape[1]):
        col_name = "{}_{}".format(col,i+1)
        W2V_nn_pred_df[col_name] = pred[:,i]
        
    # 打印存储对象情况
    print(W2V_nn_pred_df.columns)

    print("="*50)
# Out:
# Education	模型各层的参数状况
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_60 (Dense)             (None, 300)               30300
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 300)               0
# _________________________________________________________________
# activation_60 (Activation)   (None, 300)               0
# _________________________________________________________________
# dense_61 (Dense)             (None, 7)                 2107
# _________________________________________________________________
# activation_61 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 32,407
# Trainable params: 32,407
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 12355 samples, validate on 5296 samples
# Epoch 1/35
#  - 2s - loss: 1.1215 - acc: 0.5184 - val_loss: 1.1013 - val_acc: 0.5270
# Epoch 2/35
#  - 1s - loss: 1.0541 - acc: 0.5531 - val_loss: 1.1260 - val_acc: 0.5134
# Epoch 3/35
#  - 1s - loss: 1.0432 - acc: 0.5565 - val_loss: 1.1008 - val_acc: 0.5295
# Epoch 4/35
#  - 1s - loss: 1.0319 - acc: 0.5688 - val_loss: 1.1678 - val_acc: 0.4637
# Epoch 5/35
#  - 1s - loss: 1.0310 - acc: 0.5662 - val_loss: 1.0587 - val_acc: 0.5701
# Epoch 6/35
#  - 1s - loss: 1.0300 - acc: 0.5692 - val_loss: 1.1257 - val_acc: 0.5242
# Epoch 7/35
#  - 0s - loss: 1.0250 - acc: 0.5665 - val_loss: 1.1014 - val_acc: 0.5414
# Epoch 8/35
#  - 1s - loss: 1.0213 - acc: 0.5747 - val_loss: 1.0639 - val_acc: 0.5670
# Epoch 9/35
#  - 0s - loss: 1.0216 - acc: 0.5741 - val_loss: 1.0970 - val_acc: 0.5313
# Epoch 10/35
#  - 1s - loss: 1.0214 - acc: 0.5715 - val_loss: 1.0645 - val_acc: 0.5546
# Epoch 11/35
#  - 0s - loss: 1.0189 - acc: 0.5775 - val_loss: 1.0856 - val_acc: 0.5576
# Epoch 12/35
#  - 1s - loss: 1.0199 - acc: 0.5730 - val_loss: 1.0656 - val_acc: 0.5634
# Epoch 13/35
#  - 1s - loss: 1.0187 - acc: 0.5767 - val_loss: 1.0365 - val_acc: 0.5791
# Epoch 14/35
#  - 0s - loss: 1.0143 - acc: 0.5777 - val_loss: 1.0784 - val_acc: 0.5506
# Epoch 15/35
#  - 1s - loss: 1.0135 - acc: 0.5773 - val_loss: 1.0520 - val_acc: 0.5759
# Epoch 16/35
#  - 0s - loss: 1.0125 - acc: 0.5793 - val_loss: 1.1068 - val_acc: 0.5406
# Epoch 17/35
#  - 1s - loss: 1.0120 - acc: 0.5754 - val_loss: 1.0556 - val_acc: 0.5695
# Epoch 18/35
#  - 0s - loss: 1.0125 - acc: 0.5772 - val_loss: 1.0569 - val_acc: 0.5719
# Epoch 19/35
#  - 1s - loss: 1.0085 - acc: 0.5800 - val_loss: 1.0538 - val_acc: 0.5719
# Epoch 20/35
#  - 0s - loss: 1.0095 - acc: 0.5805 - val_loss: 1.0383 - val_acc: 0.5818
# Epoch 21/35
#  - 1s - loss: 1.0099 - acc: 0.5828 - val_loss: 1.0817 - val_acc: 0.5451
# Epoch 22/35
#  - 0s - loss: 1.0082 - acc: 0.5810 - val_loss: 1.0808 - val_acc: 0.5510
# Epoch 23/35
#  - 1s - loss: 1.0083 - acc: 0.5794 - val_loss: 1.0488 - val_acc: 0.5761
# Epoch 24/35
#  - 1s - loss: 1.0059 - acc: 0.5841 - val_loss: 1.0393 - val_acc: 0.5736
# Epoch 25/35
#  - 1s - loss: 1.0071 - acc: 0.5828 - val_loss: 1.0468 - val_acc: 0.5642
# Epoch 26/35
#  - 1s - loss: 1.0055 - acc: 0.5828 - val_loss: 1.0508 - val_acc: 0.5784
# Epoch 27/35
#  - 0s - loss: 1.0069 - acc: 0.5808 - val_loss: 1.0469 - val_acc: 0.5761
# Epoch 28/35
#  - 1s - loss: 1.0054 - acc: 0.5824 - val_loss: 1.0665 - val_acc: 0.5716
# Epoch 29/35
#  - 0s - loss: 1.0060 - acc: 0.5807 - val_loss: 1.0505 - val_acc: 0.5776
# Epoch 30/35
#  - 1s - loss: 1.0049 - acc: 0.5836 - val_loss: 1.0756 - val_acc: 0.5640
# Epoch 31/35
#  - 0s - loss: 1.0043 - acc: 0.5853 - val_loss: 1.0579 - val_acc: 0.5757
# Epoch 32/35
#  - 0s - loss: 1.0041 - acc: 0.5864 - val_loss: 1.0954 - val_acc: 0.5514
# Epoch 33/35
#  - 1s - loss: 1.0010 - acc: 0.5820 - val_loss: 1.0599 - val_acc: 0.5769
# Epoch 34/35
#  - 0s - loss: 0.9996 - acc: 0.5887 - val_loss: 1.0650 - val_acc: 0.5695
# Epoch 35/35
#  - 1s - loss: 1.0000 - acc: 0.5837 - val_loss: 1.0945 - val_acc: 0.5585
# 训练集准确度: 0.5672, 测试集准确度: 0.5585
# Index(['Education_1', 'Education_2', 'Education_3', 'Education_4',
#        'Education_5', 'Education_6', 'Education_7'],
#       dtype='object')
# ==================================================
# age	模型各层的参数状况
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_62 (Dense)             (None, 300)               30300
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 300)               0
# _________________________________________________________________
# activation_62 (Activation)   (None, 300)               0
# _________________________________________________________________
# dense_63 (Dense)             (None, 7)                 2107
# _________________________________________________________________
# activation_63 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 32,407
# Trainable params: 32,407
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 12355 samples, validate on 5296 samples
# Epoch 1/35
#  - 2s - loss: 1.2205 - acc: 0.4919 - val_loss: 1.2183 - val_acc: 0.4968
# Epoch 2/35
#  - 0s - loss: 1.1501 - acc: 0.5265 - val_loss: 1.1213 - val_acc: 0.5414
# Epoch 3/35
#  - 0s - loss: 1.1330 - acc: 0.5347 - val_loss: 1.1218 - val_acc: 0.5395
# Epoch 4/35
#  - 0s - loss: 1.1289 - acc: 0.5377 - val_loss: 1.1504 - val_acc: 0.5159
# Epoch 5/35
#  - 1s - loss: 1.1216 - acc: 0.5389 - val_loss: 1.1613 - val_acc: 0.5085
# Epoch 6/35
#  - 0s - loss: 1.1171 - acc: 0.5472 - val_loss: 1.1761 - val_acc: 0.5268
# Epoch 7/35
#  - 0s - loss: 1.1160 - acc: 0.5460 - val_loss: 1.1689 - val_acc: 0.5327
# Epoch 8/35
#  - 0s - loss: 1.1137 - acc: 0.5446 - val_loss: 1.1225 - val_acc: 0.5606
# Epoch 9/35
#  - 0s - loss: 1.1088 - acc: 0.5480 - val_loss: 1.2449 - val_acc: 0.4781
# Epoch 10/35
#  - 1s - loss: 1.1084 - acc: 0.5496 - val_loss: 1.1912 - val_acc: 0.5047
# Epoch 11/35
#  - 0s - loss: 1.1102 - acc: 0.5505 - val_loss: 1.1722 - val_acc: 0.5072
# Epoch 12/35
#  - 0s - loss: 1.1042 - acc: 0.5531 - val_loss: 1.1523 - val_acc: 0.5404
# Epoch 13/35
#  - 0s - loss: 1.1045 - acc: 0.5510 - val_loss: 1.1364 - val_acc: 0.5378
# Epoch 14/35
#  - 0s - loss: 1.1011 - acc: 0.5518 - val_loss: 1.1497 - val_acc: 0.5410
# Epoch 15/35
#  - 0s - loss: 1.1008 - acc: 0.5514 - val_loss: 1.1490 - val_acc: 0.5378
# Epoch 16/35
#  - 1s - loss: 1.0988 - acc: 0.5577 - val_loss: 1.0996 - val_acc: 0.5629
# Epoch 17/35
#  - 0s - loss: 1.0969 - acc: 0.5540 - val_loss: 1.1140 - val_acc: 0.5419
# Epoch 18/35
#  - 0s - loss: 1.0969 - acc: 0.5530 - val_loss: 1.1155 - val_acc: 0.5474
# Epoch 19/35
#  - 1s - loss: 1.0965 - acc: 0.5507 - val_loss: 1.1126 - val_acc: 0.5544
# Epoch 20/35
#  - 0s - loss: 1.0934 - acc: 0.5573 - val_loss: 1.1687 - val_acc: 0.5196
# Epoch 21/35
#  - 0s - loss: 1.0939 - acc: 0.5556 - val_loss: 1.1154 - val_acc: 0.5402
# Epoch 22/35
#  - 0s - loss: 1.0931 - acc: 0.5541 - val_loss: 1.1940 - val_acc: 0.4979
# Epoch 23/35
#  - 1s - loss: 1.0922 - acc: 0.5552 - val_loss: 1.0984 - val_acc: 0.5642
# Epoch 24/35
#  - 0s - loss: 1.0917 - acc: 0.5552 - val_loss: 1.1348 - val_acc: 0.5506
# Epoch 25/35
#  - 0s - loss: 1.0877 - acc: 0.5605 - val_loss: 1.1177 - val_acc: 0.5570
# Epoch 26/35
#  - 0s - loss: 1.0890 - acc: 0.5590 - val_loss: 1.1028 - val_acc: 0.5621
# Epoch 27/35
#  - 0s - loss: 1.0893 - acc: 0.5610 - val_loss: 1.2139 - val_acc: 0.5059
# Epoch 28/35
#  - 1s - loss: 1.0865 - acc: 0.5625 - val_loss: 1.1013 - val_acc: 0.5612
# Epoch 29/35
#  - 0s - loss: 1.0887 - acc: 0.5557 - val_loss: 1.1261 - val_acc: 0.5359
# Epoch 30/35
#  - 1s - loss: 1.0884 - acc: 0.5599 - val_loss: 1.1319 - val_acc: 0.5500
# Epoch 31/35
#  - 0s - loss: 1.0870 - acc: 0.5579 - val_loss: 1.1191 - val_acc: 0.5465
# Epoch 32/35
#  - 0s - loss: 1.0826 - acc: 0.5591 - val_loss: 1.1274 - val_acc: 0.5627
# Epoch 33/35
#  - 0s - loss: 1.0858 - acc: 0.5611 - val_loss: 1.1034 - val_acc: 0.5608
# Epoch 34/35
#  - 1s - loss: 1.0808 - acc: 0.5621 - val_loss: 1.1141 - val_acc: 0.5612
# Epoch 35/35
#  - 0s - loss: 1.0849 - acc: 0.5557 - val_loss: 1.1322 - val_acc: 0.5387
# 训练集准确度: 0.5428, 测试集准确度: 0.5387
# Index(['Education_1', 'Education_2', 'Education_3', 'Education_4',
#        'Education_5', 'Education_6', 'Education_7', 'age_1', 'age_2', 'age_3',
#        'age_4', 'age_5', 'age_6', 'age_7'],
#       dtype='object')
# ==================================================
# gender	模型各层的参数状况
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_64 (Dense)             (None, 300)               30300
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 300)               0
# _________________________________________________________________
# activation_64 (Activation)   (None, 300)               0
# _________________________________________________________________
# dense_65 (Dense)             (None, 3)                 903
# _________________________________________________________________
# activation_65 (Activation)   (None, 3)                 0
# =================================================================
# Total params: 31,203
# Trainable params: 31,203
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 12355 samples, validate on 5296 samples
# Epoch 1/35
#  - 2s - loss: 0.5243 - acc: 0.7590 - val_loss: 0.5954 - val_acc: 0.7183
# Epoch 2/35
#  - 0s - loss: 0.4814 - acc: 0.7926 - val_loss: 0.4687 - val_acc: 0.8104
# Epoch 3/35
#  - 0s - loss: 0.4754 - acc: 0.7998 - val_loss: 0.4945 - val_acc: 0.7674
# Epoch 4/35
#  - 0s - loss: 0.4755 - acc: 0.8045 - val_loss: 0.4555 - val_acc: 0.8119
# Epoch 5/35
#  - 0s - loss: 0.4707 - acc: 0.8041 - val_loss: 0.5116 - val_acc: 0.7823
# Epoch 6/35
#  - 0s - loss: 0.4692 - acc: 0.8047 - val_loss: 0.4513 - val_acc: 0.8197
# Epoch 7/35
#  - 0s - loss: 0.4666 - acc: 0.8058 - val_loss: 0.4646 - val_acc: 0.8151
# Epoch 8/35
#  - 0s - loss: 0.4668 - acc: 0.8058 - val_loss: 0.4563 - val_acc: 0.8048
# Epoch 9/35
#  - 0s - loss: 0.4627 - acc: 0.8086 - val_loss: 0.4934 - val_acc: 0.7957
# Epoch 10/35
#  - 0s - loss: 0.4651 - acc: 0.8076 - val_loss: 0.4760 - val_acc: 0.8102
# Epoch 11/35
#  - 0s - loss: 0.4642 - acc: 0.8084 - val_loss: 0.4501 - val_acc: 0.8206
# Epoch 12/35
#  - 0s - loss: 0.4645 - acc: 0.8098 - val_loss: 0.4581 - val_acc: 0.8204
# Epoch 13/35
#  - 0s - loss: 0.4621 - acc: 0.8079 - val_loss: 0.4853 - val_acc: 0.7997
# Epoch 14/35
#  - 0s - loss: 0.4601 - acc: 0.8095 - val_loss: 0.4698 - val_acc: 0.8146
# Epoch 15/35
#  - 0s - loss: 0.4619 - acc: 0.8094 - val_loss: 0.4710 - val_acc: 0.8134
# Epoch 16/35
#  - 0s - loss: 0.4601 - acc: 0.8119 - val_loss: 0.4485 - val_acc: 0.8180
# Epoch 17/35
#  - 0s - loss: 0.4584 - acc: 0.8104 - val_loss: 0.5087 - val_acc: 0.7900
# Epoch 18/35
#  - 0s - loss: 0.4591 - acc: 0.8117 - val_loss: 0.4579 - val_acc: 0.8104
# Epoch 19/35
#  - 0s - loss: 0.4584 - acc: 0.8086 - val_loss: 0.4500 - val_acc: 0.8195
# Epoch 20/35
#  - 0s - loss: 0.4576 - acc: 0.8128 - val_loss: 0.4565 - val_acc: 0.8208
# Epoch 21/35
#  - 1s - loss: 0.4574 - acc: 0.8097 - val_loss: 0.4610 - val_acc: 0.8136
# Epoch 22/35
#  - 0s - loss: 0.4573 - acc: 0.8117 - val_loss: 0.4808 - val_acc: 0.8097
# Epoch 23/35
#  - 1s - loss: 0.4580 - acc: 0.8122 - val_loss: 0.4681 - val_acc: 0.7944
# Epoch 24/35
#  - 0s - loss: 0.4541 - acc: 0.8121 - val_loss: 0.5006 - val_acc: 0.7764
# Epoch 25/35
#  - 0s - loss: 0.4554 - acc: 0.8125 - val_loss: 0.4471 - val_acc: 0.8178
# Epoch 26/35
#  - 0s - loss: 0.4547 - acc: 0.8126 - val_loss: 0.4712 - val_acc: 0.8012
# Epoch 27/35
#  - 0s - loss: 0.4539 - acc: 0.8134 - val_loss: 0.4531 - val_acc: 0.8212
# Epoch 28/35
#  - 0s - loss: 0.4546 - acc: 0.8115 - val_loss: 0.4523 - val_acc: 0.8225
# Epoch 29/35
#  - 0s - loss: 0.4530 - acc: 0.8133 - val_loss: 0.4537 - val_acc: 0.8221
# Epoch 30/35
#  - 1s - loss: 0.4538 - acc: 0.8138 - val_loss: 0.4623 - val_acc: 0.8185
# Epoch 31/35
#  - 0s - loss: 0.4534 - acc: 0.8138 - val_loss: 0.4472 - val_acc: 0.8195
# Epoch 32/35
#  - 1s - loss: 0.4510 - acc: 0.8158 - val_loss: 0.4661 - val_acc: 0.8176
# Epoch 33/35
#  - 0s - loss: 0.4512 - acc: 0.8171 - val_loss: 0.4587 - val_acc: 0.8140
# Epoch 34/35
#  - 0s - loss: 0.4503 - acc: 0.8133 - val_loss: 0.4546 - val_acc: 0.8240
# Epoch 35/35
#  - 0s - loss: 0.4515 - acc: 0.8144 - val_loss: 0.4518 - val_acc: 0.8191
# 训练集准确度: 0.8189, 测试集准确度: 0.8191
# Index(['Education_1', 'Education_2', 'Education_3', 'Education_4',
#        'Education_5', 'Education_6', 'Education_7', 'age_1', 'age_2', 'age_3',
#        'age_4', 'age_5', 'age_6', 'age_7', 'gender_1', 'gender_2', 'gender_3'],
#       dtype='object')
# ==================================================

# %%
# 保存模型输出结果
W2V_nn_pred_df.to_csv("W2V_nn.csv",index=False)

# %% [markdown]
# #### W2V_HW_sp

# %%
W2V_HW_pred_df = pd.DataFrame()
for col in col_list:
    
    print(col,end="\t")# 打印当前训练目标列列名
    
    # 划分数据集
    # 训练特征集，测试特征集合，训练目标列，测试目标列
    X_tr, X_te, Y_tr, Y_te = get_train_test(W2V_HW_sp,data[col]) 
    
    # 构建模型并进行训练
    # 输出为One-Hot编码后对应索引上概率值
    pred_tr,pred_te = SNN_Model(X_tr, X_te, Y_tr, Y_te) 
    
    # 根据概率值最大值输出预测类别
    pred_train = np.argmax(pred_tr,axis=1)
    pred_test = np.argmax(pred_te,axis=1)
    
    # 准确度计算
    ACC(Y_tr,Y_te,pred_train,pred_test)
    
    # 输出结果进行纵向拼接
    pred = np.vstack([pred_tr,pred_te])
    # 输出结果存储
    for i in range(pred.shape[1]):
        col_name = "{}_{}".format(col,i+1)
        W2V_HW_pred_df[col_name] = pred[:,i]
        
    # 打印存储对象情况
    print(W2V_HW_pred_df.columns)

    print("="*50)
# Out:
# Education	模型各层的参数状况
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_66 (Dense)             (None, 300)               30300
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 300)               0
# _________________________________________________________________
# activation_66 (Activation)   (None, 300)               0
# _________________________________________________________________
# dense_67 (Dense)             (None, 7)                 2107
# _________________________________________________________________
# activation_67 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 32,407
# Trainable params: 32,407
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 12355 samples, validate on 5296 samples
# Epoch 1/35
#  - 2s - loss: 1.1340 - acc: 0.5051 - val_loss: 1.2427 - val_acc: 0.4783
# Epoch 2/35
#  - 1s - loss: 1.0837 - acc: 0.5325 - val_loss: 1.0965 - val_acc: 0.5289
# Epoch 3/35
#  - 1s - loss: 1.0749 - acc: 0.5343 - val_loss: 1.0807 - val_acc: 0.5402
# Epoch 4/35
#  - 0s - loss: 1.0686 - acc: 0.5331 - val_loss: 1.1711 - val_acc: 0.4662
# Epoch 5/35
#  - 1s - loss: 1.0646 - acc: 0.5386 - val_loss: 1.1168 - val_acc: 0.5087
# Epoch 6/35
#  - 1s - loss: 1.0667 - acc: 0.5347 - val_loss: 1.1046 - val_acc: 0.5285
# Epoch 7/35
#  - 1s - loss: 1.0586 - acc: 0.5459 - val_loss: 1.0868 - val_acc: 0.5427
# Epoch 8/35
#  - 1s - loss: 1.0597 - acc: 0.5465 - val_loss: 1.0958 - val_acc: 0.5272
# Epoch 9/35
#  - 1s - loss: 1.0577 - acc: 0.5433 - val_loss: 1.0850 - val_acc: 0.5349
# Epoch 10/35
#  - 1s - loss: 1.0583 - acc: 0.5423 - val_loss: 1.0836 - val_acc: 0.5385
# Epoch 11/35
#  - 1s - loss: 1.0555 - acc: 0.5466 - val_loss: 1.1035 - val_acc: 0.5262
# Epoch 12/35
#  - 1s - loss: 1.0529 - acc: 0.5446 - val_loss: 1.0884 - val_acc: 0.5431
# Epoch 13/35
#  - 1s - loss: 1.0565 - acc: 0.5461 - val_loss: 1.1044 - val_acc: 0.5363
# Epoch 14/35
#  - 1s - loss: 1.0528 - acc: 0.5459 - val_loss: 1.0937 - val_acc: 0.5393
# Epoch 15/35
#  - 1s - loss: 1.0541 - acc: 0.5447 - val_loss: 1.0907 - val_acc: 0.5423
# Epoch 16/35
#  - 1s - loss: 1.0502 - acc: 0.5459 - val_loss: 1.0858 - val_acc: 0.5380
# Epoch 17/35
#  - 1s - loss: 1.0530 - acc: 0.5480 - val_loss: 1.1595 - val_acc: 0.5200
# Epoch 18/35
#  - 1s - loss: 1.0516 - acc: 0.5463 - val_loss: 1.1135 - val_acc: 0.5266
# Epoch 19/35
#  - 1s - loss: 1.0512 - acc: 0.5472 - val_loss: 1.1078 - val_acc: 0.5366
# Epoch 20/35
#  - 1s - loss: 1.0508 - acc: 0.5471 - val_loss: 1.1130 - val_acc: 0.5262
# Epoch 21/35
#  - 1s - loss: 1.0488 - acc: 0.5463 - val_loss: 1.0997 - val_acc: 0.5368
# Epoch 22/35
#  - 1s - loss: 1.0499 - acc: 0.5488 - val_loss: 1.1053 - val_acc: 0.5264
# Epoch 23/35
#  - 1s - loss: 1.0493 - acc: 0.5477 - val_loss: 1.1263 - val_acc: 0.5385
# Epoch 24/35
#  - 1s - loss: 1.0442 - acc: 0.5520 - val_loss: 1.0892 - val_acc: 0.5385
# Epoch 25/35
#  - 1s - loss: 1.0494 - acc: 0.5474 - val_loss: 1.0903 - val_acc: 0.5408
# Epoch 26/35
#  - 1s - loss: 1.0479 - acc: 0.5494 - val_loss: 1.1357 - val_acc: 0.5319
# Epoch 27/35
#  - 1s - loss: 1.0465 - acc: 0.5486 - val_loss: 1.1021 - val_acc: 0.5398
# Epoch 28/35
#  - 1s - loss: 1.0455 - acc: 0.5505 - val_loss: 1.1247 - val_acc: 0.5330
# Epoch 29/35
#  - 1s - loss: 1.0418 - acc: 0.5528 - val_loss: 1.0884 - val_acc: 0.5402
# Epoch 30/35
#  - 1s - loss: 1.0460 - acc: 0.5514 - val_loss: 1.1101 - val_acc: 0.5342
# Epoch 31/35
#  - 1s - loss: 1.0456 - acc: 0.5508 - val_loss: 1.1013 - val_acc: 0.5408
# Epoch 32/35
#  - 1s - loss: 1.0442 - acc: 0.5496 - val_loss: 1.1045 - val_acc: 0.5412
# Epoch 33/35
#  - 1s - loss: 1.0440 - acc: 0.5488 - val_loss: 1.0985 - val_acc: 0.5440
# Epoch 34/35
#  - 1s - loss: 1.0448 - acc: 0.5526 - val_loss: 1.1151 - val_acc: 0.5313
# Epoch 35/35
#  - 1s - loss: 1.0436 - acc: 0.5552 - val_loss: 1.0941 - val_acc: 0.5406
# 训练集准确度: 0.5592, 测试集准确度: 0.5406
# Index(['Education_1', 'Education_2', 'Education_3', 'Education_4',
#        'Education_5', 'Education_6', 'Education_7'],
#       dtype='object')
# ==================================================
# age	模型各层的参数状况
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_68 (Dense)             (None, 300)               30300
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 300)               0
# _________________________________________________________________
# activation_68 (Activation)   (None, 300)               0
# _________________________________________________________________
# dense_69 (Dense)             (None, 7)                 2107
# _________________________________________________________________
# activation_69 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 32,407
# Trainable params: 32,407
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 12355 samples, validate on 5296 samples
# Epoch 1/35
#  - 2s - loss: 1.2383 - acc: 0.4819 - val_loss: 1.1568 - val_acc: 0.5272
# Epoch 2/35
#  - 1s - loss: 1.1794 - acc: 0.5155 - val_loss: 1.1967 - val_acc: 0.4949
# Epoch 3/35
#  - 1s - loss: 1.1678 - acc: 0.5166 - val_loss: 1.1976 - val_acc: 0.5070
# Epoch 4/35
#  - 1s - loss: 1.1634 - acc: 0.5227 - val_loss: 1.1760 - val_acc: 0.5170
# Epoch 5/35
#  - 1s - loss: 1.1610 - acc: 0.5238 - val_loss: 1.1892 - val_acc: 0.5166
# Epoch 6/35
#  - 1s - loss: 1.1550 - acc: 0.5199 - val_loss: 1.2235 - val_acc: 0.4862
# Epoch 7/35
#  - 1s - loss: 1.1537 - acc: 0.5217 - val_loss: 1.2054 - val_acc: 0.4947
# Epoch 8/35
#  - 1s - loss: 1.1531 - acc: 0.5262 - val_loss: 1.1723 - val_acc: 0.5253
# Epoch 9/35
#  - 1s - loss: 1.1502 - acc: 0.5229 - val_loss: 1.1752 - val_acc: 0.5196
# Epoch 10/35
#  - 1s - loss: 1.1493 - acc: 0.5289 - val_loss: 1.1748 - val_acc: 0.5168
# Epoch 11/35
#  - 1s - loss: 1.1453 - acc: 0.5296 - val_loss: 1.1617 - val_acc: 0.5196
# Epoch 12/35
#  - 1s - loss: 1.1468 - acc: 0.5266 - val_loss: 1.1910 - val_acc: 0.5025
# Epoch 13/35
#  - 1s - loss: 1.1451 - acc: 0.5283 - val_loss: 1.1600 - val_acc: 0.5349
# Epoch 14/35
#  - 1s - loss: 1.1474 - acc: 0.5246 - val_loss: 1.1599 - val_acc: 0.5211
# Epoch 15/35
#  - 1s - loss: 1.1440 - acc: 0.5335 - val_loss: 1.1584 - val_acc: 0.5257
# Epoch 16/35
#  - 1s - loss: 1.1443 - acc: 0.5271 - val_loss: 1.1583 - val_acc: 0.5327
# Epoch 17/35
#  - 1s - loss: 1.1395 - acc: 0.5323 - val_loss: 1.1558 - val_acc: 0.5291
# Epoch 18/35
#  - 1s - loss: 1.1432 - acc: 0.5317 - val_loss: 1.1855 - val_acc: 0.5185
# Epoch 19/35
#  - 1s - loss: 1.1392 - acc: 0.5322 - val_loss: 1.1749 - val_acc: 0.5187
# Epoch 20/35
#  - 1s - loss: 1.1376 - acc: 0.5288 - val_loss: 1.1645 - val_acc: 0.5281
# Epoch 21/35
#  - 1s - loss: 1.1376 - acc: 0.5297 - val_loss: 1.1993 - val_acc: 0.5074
# Epoch 22/35
#  - 1s - loss: 1.1378 - acc: 0.5314 - val_loss: 1.1547 - val_acc: 0.5355
# Epoch 23/35
#  - 1s - loss: 1.1376 - acc: 0.5357 - val_loss: 1.1524 - val_acc: 0.5364
# Epoch 24/35
#  - 1s - loss: 1.1362 - acc: 0.5289 - val_loss: 1.1769 - val_acc: 0.5183
# Epoch 25/35
#  - 1s - loss: 1.1391 - acc: 0.5325 - val_loss: 1.1548 - val_acc: 0.5351
# Epoch 26/35
#  - 1s - loss: 1.1384 - acc: 0.5300 - val_loss: 1.1637 - val_acc: 0.5321
# Epoch 27/35
#  - 1s - loss: 1.1337 - acc: 0.5314 - val_loss: 1.1696 - val_acc: 0.5310
# Epoch 28/35
#  - 1s - loss: 1.1367 - acc: 0.5327 - val_loss: 1.1601 - val_acc: 0.5370
# Epoch 29/35
#  - 1s - loss: 1.1380 - acc: 0.5311 - val_loss: 1.1554 - val_acc: 0.5378
# Epoch 30/35
#  - 1s - loss: 1.1310 - acc: 0.5361 - val_loss: 1.1557 - val_acc: 0.5349
# Epoch 31/35
#  - 1s - loss: 1.1335 - acc: 0.5316 - val_loss: 1.1611 - val_acc: 0.5313
# Epoch 32/35
#  - 1s - loss: 1.1336 - acc: 0.5332 - val_loss: 1.1619 - val_acc: 0.5279
# Epoch 33/35
#  - 1s - loss: 1.1317 - acc: 0.5335 - val_loss: 1.1704 - val_acc: 0.5289
# Epoch 34/35
#  - 1s - loss: 1.1331 - acc: 0.5310 - val_loss: 1.1733 - val_acc: 0.5300
# Epoch 35/35
#  - 1s - loss: 1.1313 - acc: 0.5310 - val_loss: 1.1882 - val_acc: 0.5321
# 训练集准确度: 0.5335, 测试集准确度: 0.5321
# Index(['Education_1', 'Education_2', 'Education_3', 'Education_4',
#        'Education_5', 'Education_6', 'Education_7', 'age_1', 'age_2', 'age_3',
#        'age_4', 'age_5', 'age_6', 'age_7'],
#       dtype='object')
# ==================================================
# gender	模型各层的参数状况
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_70 (Dense)             (None, 300)               30300
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 300)               0
# _________________________________________________________________
# activation_70 (Activation)   (None, 300)               0
# _________________________________________________________________
# dense_71 (Dense)             (None, 3)                 903
# _________________________________________________________________
# activation_71 (Activation)   (None, 3)                 0
# =================================================================
# Total params: 31,203
# Trainable params: 31,203
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 12355 samples, validate on 5296 samples
# Epoch 1/35
#  - 2s - loss: 0.5523 - acc: 0.7289 - val_loss: 0.5532 - val_acc: 0.7270
# Epoch 2/35
#  - 1s - loss: 0.5223 - acc: 0.7478 - val_loss: 0.5795 - val_acc: 0.7113
# Epoch 3/35
#  - 1s - loss: 0.5189 - acc: 0.7564 - val_loss: 0.5100 - val_acc: 0.7689
# Epoch 4/35
#  - 1s - loss: 0.5152 - acc: 0.7564 - val_loss: 0.5031 - val_acc: 0.7747
# Epoch 5/35
#  - 1s - loss: 0.5135 - acc: 0.7565 - val_loss: 0.5418 - val_acc: 0.7411
# Epoch 6/35
#  - 1s - loss: 0.5116 - acc: 0.7599 - val_loss: 0.5126 - val_acc: 0.7679
# Epoch 7/35
#  - 1s - loss: 0.5098 - acc: 0.7588 - val_loss: 0.5656 - val_acc: 0.7256
# Epoch 8/35
#  - 1s - loss: 0.5104 - acc: 0.7615 - val_loss: 0.5051 - val_acc: 0.7721
# Epoch 9/35
#  - 1s - loss: 0.5098 - acc: 0.7602 - val_loss: 0.5047 - val_acc: 0.7727
# Epoch 10/35
#  - 1s - loss: 0.5085 - acc: 0.7625 - val_loss: 0.5212 - val_acc: 0.7570
# Epoch 11/35
#  - 1s - loss: 0.5074 - acc: 0.7631 - val_loss: 0.5040 - val_acc: 0.7728
# Epoch 12/35
#  - 1s - loss: 0.5082 - acc: 0.7609 - val_loss: 0.5129 - val_acc: 0.7627
# Epoch 13/35
#  - 1s - loss: 0.5068 - acc: 0.7632 - val_loss: 0.5121 - val_acc: 0.7672
# Epoch 14/35
#  - 1s - loss: 0.5066 - acc: 0.7624 - val_loss: 0.5137 - val_acc: 0.7649
# Epoch 15/35
#  - 1s - loss: 0.5055 - acc: 0.7633 - val_loss: 0.5048 - val_acc: 0.7702
# Epoch 16/35
#  - 1s - loss: 0.5069 - acc: 0.7605 - val_loss: 0.5040 - val_acc: 0.7749
# Epoch 17/35
#  - 1s - loss: 0.5060 - acc: 0.7656 - val_loss: 0.5024 - val_acc: 0.7740
# Epoch 18/35
#  - 0s - loss: 0.5046 - acc: 0.7641 - val_loss: 0.5029 - val_acc: 0.7736
# Epoch 19/35
#  - 0s - loss: 0.5037 - acc: 0.7663 - val_loss: 0.5508 - val_acc: 0.7428
# Epoch 20/35
#  - 1s - loss: 0.5062 - acc: 0.7641 - val_loss: 0.5103 - val_acc: 0.7723
# Epoch 21/35
#  - 0s - loss: 0.5034 - acc: 0.7620 - val_loss: 0.5043 - val_acc: 0.7749
# Epoch 22/35
#  - 1s - loss: 0.5031 - acc: 0.7654 - val_loss: 0.5118 - val_acc: 0.7742
# Epoch 23/35
#  - 0s - loss: 0.5038 - acc: 0.7642 - val_loss: 0.5037 - val_acc: 0.7730
# Epoch 24/35
#  - 0s - loss: 0.5016 - acc: 0.7675 - val_loss: 0.5056 - val_acc: 0.7717
# Epoch 25/35
#  - 0s - loss: 0.5034 - acc: 0.7630 - val_loss: 0.5178 - val_acc: 0.7727
# Epoch 26/35
#  - 0s - loss: 0.5019 - acc: 0.7653 - val_loss: 0.5389 - val_acc: 0.7481
# Epoch 27/35
#  - 0s - loss: 0.5030 - acc: 0.7658 - val_loss: 0.5189 - val_acc: 0.7611
# Epoch 28/35
#  - 0s - loss: 0.5032 - acc: 0.7655 - val_loss: 0.5089 - val_acc: 0.7715
# Epoch 29/35
#  - 1s - loss: 0.5027 - acc: 0.7654 - val_loss: 0.5217 - val_acc: 0.7638
# Epoch 30/35
#  - 0s - loss: 0.5012 - acc: 0.7679 - val_loss: 0.5121 - val_acc: 0.7736
# Epoch 31/35
#  - 1s - loss: 0.5014 - acc: 0.7626 - val_loss: 0.5099 - val_acc: 0.7736
# Epoch 32/35
#  - 0s - loss: 0.5016 - acc: 0.7644 - val_loss: 0.5073 - val_acc: 0.7670
# Epoch 33/35
#  - 1s - loss: 0.5006 - acc: 0.7679 - val_loss: 0.5210 - val_acc: 0.7591
# Epoch 34/35
#  - 0s - loss: 0.5017 - acc: 0.7668 - val_loss: 0.5042 - val_acc: 0.7711
# Epoch 35/35
#  - 1s - loss: 0.4996 - acc: 0.7673 - val_loss: 0.5115 - val_acc: 0.7715
# 训练集准确度: 0.7698, 测试集准确度: 0.7715
# Index(['Education_1', 'Education_2', 'Education_3', 'Education_4',
#        'Education_5', 'Education_6', 'Education_7', 'age_1', 'age_2', 'age_3',
#        'age_4', 'age_5', 'age_6', 'age_7', 'gender_1', 'gender_2', 'gender_3'],
#       dtype='object')
# ==================================================

# %%
# 保存模型输出结果
W2V_HW_pred_df.to_csv("W2V_HW_nn.csv",index=False)

# %%
W2V_nn_pred_df = pd.read_csv(config.FEData_path + "W2V_nn.csv")
W2V_HW_pred_df = pd.read_csv(config.FEData_path + "W2V_HW_nn.csv")
TFIDF_HW_pred_df = pd.read_csv(config.FEData_path + "TFIDF_HW_nn.csv")
TFIDF_nn_pred_df = pd.read_csv(config.FEData_path + "TFIDF_nn.csv")

# %%
X_tr, X_te, Y_tr, Y_te = get_train_test(np.array(pd.concat([data[['SpaceNum', 'SpaceRATIO','LinkNum', 'LinkRATIO', 'TextSum', 'TextMax', 'TextMin', 'TextMedian','TextMean', 'SearchNum']],
                                                            W2V_nn_pred_df,W2V_HW_pred_df,TFIDF_HW_pred_df,TFIDF_nn_pred_df],axis=1)),data["Education"])

# %%
X_tr, X_te, Y_tr, Y_te = get_train_test(W2V_nn_pred_df,data["Education"])

# %%
from sklearn import svm
# 模型实例化
clf = svm.SVC()

# %%
clf.fit(X_tr,Y_tr) # 模型训练
# Out:
# SVC()

# %%
# 预测
pred_train = clf.predict(X_tr)
pred_test = clf.predict(X_te)

#准确率
train_acc = accuracy_score(Y_tr, pred_train)
test_acc = accuracy_score(Y_te, pred_test)
print ("训练集准确率: {0:.4f}, 测试集准确率: {1:.4f}".format(train_acc, test_acc))
# Out:
# 训练集准确率: 0.3180, 测试集准确率: 0.0646

# %%
import xgboost as xgb

# %%
XGB_Model = xgb.XGBClassifier(use_label_encoder=False)

# %%
Y_tr[Y_tr==6] = 0
Y_te[Y_te==6] = 0

# %%
XGB_Model = XGB_Model.fit(X_tr,Y_tr)
XGB_Model
# Out:
# [14:44:01] WARNING: D:\Build\xgboost\xgboost-1.3.1.git\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=12, num_parallel_tree=1,
#               objective='multi:softprob', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=None, subsample=1,
#               tree_method='exact', use_label_encoder=False,
#               validate_parameters=1, verbosity=None)

# %%
XGB_Model.score(X_tr,Y_tr)
# Out:
# 0.9546742209631728

# %%
XGB_Model.score(X_te,Y_te)
# Out:
# 0.40823262839879154

# %%
np.argmax(XGB_Model.predict_proba(X_te),axis=1)
# Out:
# array([1, 1, 2, ..., 1, 1, 1], dtype=int64)

# %%
model_list = ["W2V","W2V_HW","TFIDF","TFIDF_HW"]
for i in model_list:
